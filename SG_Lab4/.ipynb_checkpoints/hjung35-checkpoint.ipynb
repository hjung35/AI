# %% [markdown]
# # Analyze customer data from Austin, TX.
#
# In this lab, we will analyze various features of customer energy usage data from the Pecan Street dataset. The dataset we aim to explore is for the month of January 2017 from various customers in Austin, TX.
#
# Distinguish which houses have rooftop photovoltaic (PV) panels and which ones do not. For the houses that do not have PV panels, try to predict how much money they would save, given Austin's retail energy rates.
#
# Given the temperature profile, can you predict which houses have AC?

# %%
# Start with customary imports.

import tensorflow as tf
import numpy as np
import pandas as pd
import random
import datetime
import math
from sklearn.model_selection import train_test_split
from sklearn import preprocessing, linear_model
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %% [markdown]
# ## Understand and parse the dataset
#
# There are two csv files that we will utilize in this lab:
# 1. 'dataport-metadata.csv': It contains the details of what data is available from each house in the entire Pecan Street dataset.
# 2. 'July2017.csv': It contains the energy data from houses in Austin for the month of July.
#
# ### Parse the metadata file.
#
# Only consider customers from Austin, TX for which electricity usage data is present.

# %%
# Load the 'metadata' file that contains information about individual houses into a pandas dataframe.
dfCityCustomers = pd.read_csv("dataport-metadata.csv", index_col=0)

# Only consider the houses that are in Austin and have power consumption data.
dfCityCustomers = dfCityCustomers.loc[(dfCityCustomers['city'] == 'Austin') & (dfCityCustomers['use'] == 'yes')]

# Restrict attention to useful columns.
dfCityCustomers = dfCityCustomers[['date_enrolled', 'date_withdrawn', 
                                   'building_type', 'total_square_footage', 'first_floor_square_footage',
                                   'pv', 'air1', 'air2', 'air3', 'airwindowunit1',
                                   'gen', 'use', 'grid']]

# Replace binary data with zeros and ones.
binaryColumns = ['pv', 'air1', 'air2', 'air3', 'airwindowunit1', 'gen', 'use', 'grid']
for bColumn in binaryColumns:
    dfCityCustomers[bColumn] = dfCityCustomers[bColumn].map({'yes' : 1}).fillna(0)

start_day = datetime.datetime.strptime('2017-07-01', '%Y-%m-%d').date()
    
dfCityCustomers['date_enrolled'] = [datetime.datetime.strptime(x, "%Y-%m-%d") 
                                    for x in dfCityCustomers['date_enrolled']]

dfCityCustomers = dfCityCustomers.loc[(dfCityCustomers['date_enrolled'] <= '2017-07-01')]
print("Parsed the metadata file successfully.")
# Out:
# Parsed the metadata file successfully.

# %% [markdown]
# ### Parse the energy usage data.
#
# Here, we shall clean the data.
#
# 1. The data downloaded from dataport.cloud has a mislabeled colmn. Correct that.
# 2. Split the 'localhour' field into two fiels: actual date and an hour of day.
# 3. Only choose data from households that are 'Single-Family Homes'.
# 4. Make sure there is data from 31 days.
# 5. Ensure that the metadata includes the square footage for the entire home and its first floor.
#
# Finally, create a pandas dataframe where indices are house id's.

# %%
# Load the data from Jan 2017 from houses in Texas.
dfData = pd.read_csv("July2017.csv")

# Cleanup item 1. Alter the column names because there is an error in the downloaded data. The column names
# 'dataid' and 'localhour' are switched in the .csv file. Correct it. 
# Cleanup item 2. Split the hour and the day in the field 'localhour' and convert the date to an 
# actual datetime object.

dfData.columns = [x.lstrip() for x in dfData.columns]
dfData = dfData[['dataid', 'localhour', 'use', 'grid', 'gen', 'air1', 'air2', 'air3', 'airwindowunit1']]
dfData.columns = ['date', 'dataid', 'use', 'grid', 'gen', 'air1', 'air2', 'air3', 'airwindowunit1']

dfData['hour'] = [datetime.datetime.strptime(x[:-3], "%Y-%m-%d %H:%M:%S").hour for x in dfData['date']]
dfData['date'] = [datetime.datetime.strptime(x[:-3], "%Y-%m-%d %H:%M:%S").date() for x in dfData['date']]

# Create a dataframe where indices are house id's.
dfData_houses = pd.DataFrame(columns=['ac', 'pv', 'area', 'area_floor', 'data'])

for house_id in dfData['dataid'].unique():
    
    # Make sure that each house with consumption data is also in metadata.
    if house_id in dfCityCustomers.index.values:
        dfData_one_house = dfData.loc[dfData['dataid'] == house_id]

        # Cleanup item 3, 4, 5.
        if ((len(dfData_one_house) >= 24 * 31) & 
        (np.sum(dfData_one_house['use'].values) != 0) & 
        (dfCityCustomers.loc[house_id, 'building_type'] == 'Single-Family Home') & 
        (np.isnan(dfCityCustomers.loc[house_id, 'total_square_footage']) == False) & 
        (np.isnan(dfCityCustomers.loc[house_id, 'first_floor_square_footage']) == False)):
            
            # Create a pandas dataframe with house id's as indices and has the following items: 
            # 1. Binary status: "ac", "pv".
            # 2. Total square footrage, and the square footage of the first floor.
            
            is_ac_in_house =  (dfCityCustomers.loc[house_id, 'air1'] 
                               or dfCityCustomers.loc[house_id, 'air2']
                               or dfCityCustomers.loc[house_id, 'air3']
                               or dfCityCustomers.loc[house_id, 'airwindowunit1']
                              )
            
            dfData_houses.loc[house_id] = [is_ac_in_house, 
                                           dfCityCustomers.loc[house_id, 'pv'],
                                           dfCityCustomers.loc[house_id, 'total_square_footage'],
                                           dfCityCustomers.loc[house_id, 'first_floor_square_footage'],
                                           dfData_one_house
                                          ]

# Define a function that retrieves the hourly energy profile from the column in "field" from a
# specific house and day. The day is measured as number of days since the start date of Jan 1, 2017.

def energy_day(house_id, day, field): 
    date_day = start_day + datetime.timedelta(days=day)
    dfData_house = dfData_houses.loc[house_id, 'data']
    return dfData_house.loc[dfData_house['date'] == date_day].sort_values(by=['hour'])[field].values

# Define a function that retrieves the aggregate energy consumed (or produced) as detailed in the column 
# named "field" from a specific house over all days.

def total_energy_all_days(house_id, field): 
    total_energy = 0
    for day in range(31):
        total_energy += np.sum(energy_day(house_id, day, field))
    return total_energy


# Cleanup item 4 continued: Delete data from houses where the date and hour do not perfectly 
# align with the 31 days in July, and hours being from 0 to 23.
house_ids_to_delete = []
for house_id in dfData_houses.index.values:
    for day in range(31):
        if len(energy_day(house_id, day, 'grid')) != 24:
            house_ids_to_delete.append(house_id)
            continue

dfData_houses.drop(house_ids_to_delete, inplace=True)

print("Data loaded and parsed successfully from %d single-family homes." % (len(dfData_houses)))

del dfData , dfCityCustomers
# Out:
# Data loaded and parsed successfully from 222 single-family homes.

# %% [markdown]
# ## Distinguish houses with rooftop solar panels from daily energy usage profile.
#
# Take data of energy drawn from the grid for 10 days and do logistic regression.
#
# ### Q1. Explain Logistic regression. (10 points)
# Logistic regression is the analytic regression method to estimate with given binary dependent variables.

# %%
print("Number of houses with PV panels = %d" % (len(dfData_houses.loc[dfData_houses['pv'] == 1])) )
print("Number of houses without PV panels = %d" % (len(dfData_houses.loc[dfData_houses['pv'] == 0])) )

XX = []
YY = []

days_data = random.sample(range(31), 10)

for house_id in dfData_houses.index.values:
    XX.append(np.ravel([energy_day(house_id, day, 'grid') for day in days_data]))
    YY.append(dfData_houses.loc[house_id, 'pv'])

YY = np.reshape(YY, (-1, 1))

train_X, test_X, train_Y, test_Y = train_test_split(XX, YY, test_size=.2, shuffle=True)

train_X = tf.dtypes.cast(train_X, tf.float32)
test_X = tf.dtypes.cast(test_X, tf.float32)
train_Y = tf.dtypes.cast(train_Y, tf.float32
test_Y = tf.dtypes.cast(test_Y, tf.float32)

del XX, YY
# Out:
# Number of houses with PV panels = 146
# Number of houses without PV panels = 76

# %% [markdown]
# ### Q2. Design the neural network. In the next cell, fill in the missing pieces. (30 points)

# %%
n_inputs = np.shape(train_X)[1]
n_outputs = np.shape(train_Y)[1]

weight = tf.Variable(tf.random.truncated_normal(shape=[n_inputs, n_outputs]))
bias = tf.Variable(tf.random.truncated_normal(shape=[n_outputs]))

@tf.function
def neuralNetworkModel(X):
    global weight, bias
    # enter code here (hint: tf.nn.sigmoid may be useful)
    out = tf.nn.sigmoid(tf.add(tf.matmul(X, weight), bias))
    return out

loss_fn = tf.losses.BinaryCrossentropy() #(hint: tf.losses.BinaryCrossentropy may be useful)
optimizer = tf.optimizers.Adam(learning_rate=0.0001) # Enter code here (hint: the learning rate may need to be small)

# Define number of epochs
nEpoch = 1000
trainable_variables = (weight, bias)

# Define the training scheme
def train(model, x_set, y_set):
    for epoch in range(nEpoch):
        # Fit the data and compute the gradients
        with tf.GradientTape() as tape:
            prediction = model(x_set)
            loss = loss_fn(y_true=y_set, y_pred=prediction)
            
            # Print update
            lossEpoch = loss.numpy()
            print("Epoch: %d, Loss: = %1.1f" % (epoch + 1, lossEpoch))
            
            # Optimize the weights
            gradients = tape.gradient(loss, trainable_variables)
            optimizer.apply_gradients(zip(gradients, trainable_variables))

# Train the model
print ("Start neural network training.")
train(neuralNetworkModel, train_X, train_Y)

test_prediction = tf.math.round(neuralNetworkModel(test_X))
test_accuracy = tf.math.reduce_mean(tf.dtypes.cast(tf.math.equal(test_Y, test_prediction), tf.float32))
print("Accuracy of logistic regression on test data = %.2f percent." % (test_accuracy * 100))
# Out:
# Start neural network training.
# Epoch: 1, Loss: = 6.3
# Epoch: 2, Loss: = 6.3
# Epoch: 3, Loss: = 6.3
# Epoch: 4, Loss: = 6.3
# Epoch: 5, Loss: = 6.3
# Epoch: 6, Loss: = 6.3
# Epoch: 7, Loss: = 6.3
# Epoch: 8, Loss: = 6.2
# Epoch: 9, Loss: = 6.2
# Epoch: 10, Loss: = 6.2
# Epoch: 11, Loss: = 6.2
# Epoch: 12, Loss: = 6.2
# Epoch: 13, Loss: = 6.2
# Epoch: 14, Loss: = 6.2
# Epoch: 15, Loss: = 6.2
# Epoch: 16, Loss: = 6.2
# Epoch: 17, Loss: = 6.2
# Epoch: 18, Loss: = 6.1
# Epoch: 19, Loss: = 6.1
# Epoch: 20, Loss: = 6.1
# Epoch: 21, Loss: = 6.1
# Epoch: 22, Loss: = 6.1
# Epoch: 23, Loss: = 6.1
# Epoch: 24, Loss: = 6.1
# Epoch: 25, Loss: = 6.1
# Epoch: 26, Loss: = 6.1
# Epoch: 27, Loss: = 6.1
# Epoch: 28, Loss: = 6.0
# Epoch: 29, Loss: = 6.0
# Epoch: 30, Loss: = 6.0
# Epoch: 31, Loss: = 6.0
# Epoch: 32, Loss: = 6.0
# Epoch: 33, Loss: = 6.0
# Epoch: 34, Loss: = 6.0
# Epoch: 35, Loss: = 6.0
# Epoch: 36, Loss: = 6.0
# Epoch: 37, Loss: = 6.0
# Epoch: 38, Loss: = 5.9
# Epoch: 39, Loss: = 5.9
# Epoch: 40, Loss: = 5.9
# Epoch: 41, Loss: = 5.9
# Epoch: 42, Loss: = 5.9
# Epoch: 43, Loss: = 5.9
# Epoch: 44, Loss: = 5.9
# Epoch: 45, Loss: = 5.9
# Epoch: 46, Loss: = 5.9
# Epoch: 47, Loss: = 5.8
# Epoch: 48, Loss: = 5.8
# Epoch: 49, Loss: = 5.8
# Epoch: 50, Loss: = 5.8
# Epoch: 51, Loss: = 5.8
# Epoch: 52, Loss: = 5.8
# Epoch: 53, Loss: = 5.8
# Epoch: 54, Loss: = 5.8
# Epoch: 55, Loss: = 5.8
# Epoch: 56, Loss: = 5.8
# Epoch: 57, Loss: = 5.7
# Epoch: 58, Loss: = 5.7
# Epoch: 59, Loss: = 5.7
# Epoch: 60, Loss: = 5.7
# Epoch: 61, Loss: = 5.7
# Epoch: 62, Loss: = 5.7
# Epoch: 63, Loss: = 5.7
# Epoch: 64, Loss: = 5.7
# Epoch: 65, Loss: = 5.7
# Epoch: 66, Loss: = 5.6
# Epoch: 67, Loss: = 5.6
# Epoch: 68, Loss: = 5.6
# Epoch: 69, Loss: = 5.6
# Epoch: 70, Loss: = 5.6
# Epoch: 71, Loss: = 5.6
# Epoch: 72, Loss: = 5.6
# Epoch: 73, Loss: = 5.6
# Epoch: 74, Loss: = 5.6
# Epoch: 75, Loss: = 5.6
# Epoch: 76, Loss: = 5.5
# Epoch: 77, Loss: = 5.5
# Epoch: 78, Loss: = 5.5
# Epoch: 79, Loss: = 5.5
# Epoch: 80, Loss: = 5.5
# Epoch: 81, Loss: = 5.5
# Epoch: 82, Loss: = 5.5
# Epoch: 83, Loss: = 5.5
# Epoch: 84, Loss: = 5.5
# Epoch: 85, Loss: = 5.5
# Epoch: 86, Loss: = 5.4
# Epoch: 87, Loss: = 5.4
# Epoch: 88, Loss: = 5.4
# Epoch: 89, Loss: = 5.4
# Epoch: 90, Loss: = 5.4
# Epoch: 91, Loss: = 5.4
# Epoch: 92, Loss: = 5.4
# Epoch: 93, Loss: = 5.4
# Epoch: 94, Loss: = 5.4
# Epoch: 95, Loss: = 5.4
# Epoch: 96, Loss: = 5.3
# Epoch: 97, Loss: = 5.3
# Epoch: 98, Loss: = 5.3
# Epoch: 99, Loss: = 5.3
# Epoch: 100, Loss: = 5.3
# Epoch: 101, Loss: = 5.3
# Epoch: 102, Loss: = 5.3
# Epoch: 103, Loss: = 5.3
# Epoch: 104, Loss: = 5.3
# Epoch: 105, Loss: = 5.2
# Epoch: 106, Loss: = 5.2
# Epoch: 107, Loss: = 5.2
# Epoch: 108, Loss: = 5.2
# Epoch: 109, Loss: = 5.2
# Epoch: 110, Loss: = 5.2
# Epoch: 111, Loss: = 5.2
# Epoch: 112, Loss: = 5.2
# Epoch: 113, Loss: = 5.2
# Epoch: 114, Loss: = 5.2
# Epoch: 115, Loss: = 5.1
# Epoch: 116, Loss: = 5.1
# Epoch: 117, Loss: = 5.1
# Epoch: 118, Loss: = 5.1
# Epoch: 119, Loss: = 5.1
# Epoch: 120, Loss: = 5.1
# Epoch: 121, Loss: = 5.1
# Epoch: 122, Loss: = 5.1
# Epoch: 123, Loss: = 5.1
# Epoch: 124, Loss: = 5.1
# Epoch: 125, Loss: = 5.0
# Epoch: 126, Loss: = 5.0
# Epoch: 127, Loss: = 5.0
# Epoch: 128, Loss: = 5.0
# Epoch: 129, Loss: = 5.0
# Epoch: 130, Loss: = 5.0
# Epoch: 131, Loss: = 5.0
# Epoch: 132, Loss: = 5.0
# Epoch: 133, Loss: = 5.0
# Epoch: 134, Loss: = 5.0
# Epoch: 135, Loss: = 5.0
# Epoch: 136, Loss: = 4.9
# Epoch: 137, Loss: = 4.9
# Epoch: 138, Loss: = 4.9
# Epoch: 139, Loss: = 4.9
# Epoch: 140, Loss: = 4.9
# Epoch: 141, Loss: = 4.9
# Epoch: 142, Loss: = 4.9
# Epoch: 143, Loss: = 4.9
# Epoch: 144, Loss: = 4.9
# Epoch: 145, Loss: = 4.9
# Epoch: 146, Loss: = 4.9
# Epoch: 147, Loss: = 4.8
# Epoch: 148, Loss: = 4.8
# Epoch: 149, Loss: = 4.8
# Epoch: 150, Loss: = 4.8
# Epoch: 151, Loss: = 4.8
# Epoch: 152, Loss: = 4.8
# Epoch: 153, Loss: = 4.8
# Epoch: 154, Loss: = 4.8
# Epoch: 155, Loss: = 4.8
# Epoch: 156, Loss: = 4.8
# Epoch: 157, Loss: = 4.8
# Epoch: 158, Loss: = 4.7
# Epoch: 159, Loss: = 4.7
# Epoch: 160, Loss: = 4.7
# Epoch: 161, Loss: = 4.7
# Epoch: 162, Loss: = 4.7
# Epoch: 163, Loss: = 4.7
# Epoch: 164, Loss: = 4.7
# Epoch: 165, Loss: = 4.7
# Epoch: 166, Loss: = 4.7
# Epoch: 167, Loss: = 4.7
# Epoch: 168, Loss: = 4.7
# Epoch: 169, Loss: = 4.7
# Epoch: 170, Loss: = 4.6
# Epoch: 171, Loss: = 4.6
# Epoch: 172, Loss: = 4.6
# Epoch: 173, Loss: = 4.6
# Epoch: 174, Loss: = 4.6
# Epoch: 175, Loss: = 4.6
# Epoch: 176, Loss: = 4.6
# Epoch: 177, Loss: = 4.6
# Epoch: 178, Loss: = 4.6
# Epoch: 179, Loss: = 4.6
# Epoch: 180, Loss: = 4.6
# Epoch: 181, Loss: = 4.6
# Epoch: 182, Loss: = 4.5
# Epoch: 183, Loss: = 4.5
# Epoch: 184, Loss: = 4.5
# Epoch: 185, Loss: = 4.5
# Epoch: 186, Loss: = 4.5
# Epoch: 187, Loss: = 4.5
# Epoch: 188, Loss: = 4.5
# Epoch: 189, Loss: = 4.5
# Epoch: 190, Loss: = 4.5
# Epoch: 191, Loss: = 4.5
# Epoch: 192, Loss: = 4.5
# Epoch: 193, Loss: = 4.5
# Epoch: 194, Loss: = 4.5
# Epoch: 195, Loss: = 4.4
# Epoch: 196, Loss: = 4.4
# Epoch: 197, Loss: = 4.4
# Epoch: 198, Loss: = 4.4
# Epoch: 199, Loss: = 4.4
# Epoch: 200, Loss: = 4.4
# Epoch: 201, Loss: = 4.4
# Epoch: 202, Loss: = 4.4
# Epoch: 203, Loss: = 4.4
# Epoch: 204, Loss: = 4.4
# Epoch: 205, Loss: = 4.4
# Epoch: 206, Loss: = 4.4
# Epoch: 207, Loss: = 4.3
# Epoch: 208, Loss: = 4.3
# Epoch: 209, Loss: = 4.3
# Epoch: 210, Loss: = 4.3
# Epoch: 211, Loss: = 4.3
# Epoch: 212, Loss: = 4.3
# Epoch: 213, Loss: = 4.3
# Epoch: 214, Loss: = 4.3
# Epoch: 215, Loss: = 4.3
# Epoch: 216, Loss: = 4.3
# Epoch: 217, Loss: = 4.3
# Epoch: 218, Loss: = 4.3
# Epoch: 219, Loss: = 4.2
# Epoch: 220, Loss: = 4.2
# Epoch: 221, Loss: = 4.2
# Epoch: 222, Loss: = 4.2
# Epoch: 223, Loss: = 4.2
# Epoch: 224, Loss: = 4.2
# Epoch: 225, Loss: = 4.2
# Epoch: 226, Loss: = 4.2
# Epoch: 227, Loss: = 4.2
# Epoch: 228, Loss: = 4.2
# Epoch: 229, Loss: = 4.2
# Epoch: 230, Loss: = 4.2
# Epoch: 231, Loss: = 4.1
# Epoch: 232, Loss: = 4.1
# Epoch: 233, Loss: = 4.1
# Epoch: 234, Loss: = 4.1
# Epoch: 235, Loss: = 4.1
# Epoch: 236, Loss: = 4.1
# Epoch: 237, Loss: = 4.1
# Epoch: 238, Loss: = 4.1
# Epoch: 239, Loss: = 4.1
# Epoch: 240, Loss: = 4.1
# Epoch: 241, Loss: = 4.1
# Epoch: 242, Loss: = 4.0
# Epoch: 243, Loss: = 4.0
# Epoch: 244, Loss: = 4.0
# Epoch: 245, Loss: = 4.0
# Epoch: 246, Loss: = 4.0
# Epoch: 247, Loss: = 4.0
# Epoch: 248, Loss: = 4.0
# Epoch: 249, Loss: = 4.0
# Epoch: 250, Loss: = 4.0
# Epoch: 251, Loss: = 4.0
# Epoch: 252, Loss: = 4.0
# Epoch: 253, Loss: = 3.9
# Epoch: 254, Loss: = 3.9
# Epoch: 255, Loss: = 3.9
# Epoch: 256, Loss: = 3.9
# Epoch: 257, Loss: = 3.9
# Epoch: 258, Loss: = 3.9
# Epoch: 259, Loss: = 3.9
# Epoch: 260, Loss: = 3.9
# Epoch: 261, Loss: = 3.9
# Epoch: 262, Loss: = 3.9
# Epoch: 263, Loss: = 3.9
# Epoch: 264, Loss: = 3.9
# Epoch: 265, Loss: = 3.8
# Epoch: 266, Loss: = 3.8
# Epoch: 267, Loss: = 3.8
# Epoch: 268, Loss: = 3.8
# Epoch: 269, Loss: = 3.8
# Epoch: 270, Loss: = 3.8
# Epoch: 271, Loss: = 3.8
# Epoch: 272, Loss: = 3.8
# Epoch: 273, Loss: = 3.8
# Epoch: 274, Loss: = 3.8
# Epoch: 275, Loss: = 3.8
# Epoch: 276, Loss: = 3.7
# Epoch: 277, Loss: = 3.7
# Epoch: 278, Loss: = 3.7
# Epoch: 279, Loss: = 3.7
# Epoch: 280, Loss: = 3.7
# Epoch: 281, Loss: = 3.7
# Epoch: 282, Loss: = 3.7
# Epoch: 283, Loss: = 3.7
# Epoch: 284, Loss: = 3.7
# Epoch: 285, Loss: = 3.7
# Epoch: 286, Loss: = 3.7
# Epoch: 287, Loss: = 3.7
# Epoch: 288, Loss: = 3.6
# Epoch: 289, Loss: = 3.6
# Epoch: 290, Loss: = 3.6
# Epoch: 291, Loss: = 3.6
# Epoch: 292, Loss: = 3.6
# Epoch: 293, Loss: = 3.6
# Epoch: 294, Loss: = 3.6
# Epoch: 295, Loss: = 3.6
# Epoch: 296, Loss: = 3.6
# Epoch: 297, Loss: = 3.6
# Epoch: 298, Loss: = 3.6
# Epoch: 299, Loss: = 3.6
# Epoch: 300, Loss: = 3.5
# Epoch: 301, Loss: = 3.5
# Epoch: 302, Loss: = 3.5
# Epoch: 303, Loss: = 3.5
# Epoch: 304, Loss: = 3.5
# Epoch: 305, Loss: = 3.5
# Epoch: 306, Loss: = 3.5
# Epoch: 307, Loss: = 3.5
# Epoch: 308, Loss: = 3.5
# Epoch: 309, Loss: = 3.5
# Epoch: 310, Loss: = 3.5
# Epoch: 311, Loss: = 3.5
# Epoch: 312, Loss: = 3.5
# Epoch: 313, Loss: = 3.4
# Epoch: 314, Loss: = 3.4
# Epoch: 315, Loss: = 3.4
# Epoch: 316, Loss: = 3.4
# Epoch: 317, Loss: = 3.4
# Epoch: 318, Loss: = 3.4
# Epoch: 319, Loss: = 3.4
# Epoch: 320, Loss: = 3.4
# Epoch: 321, Loss: = 3.4
# Epoch: 322, Loss: = 3.4
# Epoch: 323, Loss: = 3.4
# Epoch: 324, Loss: = 3.4
# Epoch: 325, Loss: = 3.4
# Epoch: 326, Loss: = 3.4
# Epoch: 327, Loss: = 3.3
# Epoch: 328, Loss: = 3.3
# Epoch: 329, Loss: = 3.3
# Epoch: 330, Loss: = 3.3
# Epoch: 331, Loss: = 3.3
# Epoch: 332, Loss: = 3.3
# Epoch: 333, Loss: = 3.3
# Epoch: 334, Loss: = 3.3
# Epoch: 335, Loss: = 3.3
# Epoch: 336, Loss: = 3.3
# Epoch: 337, Loss: = 3.3
# Epoch: 338, Loss: = 3.3
# Epoch: 339, Loss: = 3.3
# Epoch: 340, Loss: = 3.3
# Epoch: 341, Loss: = 3.2
# Epoch: 342, Loss: = 3.2
# Epoch: 343, Loss: = 3.2
# Epoch: 344, Loss: = 3.2
# Epoch: 345, Loss: = 3.2
# Epoch: 346, Loss: = 3.2
# Epoch: 347, Loss: = 3.2
# Epoch: 348, Loss: = 3.2
# Epoch: 349, Loss: = 3.2
# Epoch: 350, Loss: = 3.2
# Epoch: 351, Loss: = 3.2
# Epoch: 352, Loss: = 3.2
# Epoch: 353, Loss: = 3.2
# Epoch: 354, Loss: = 3.2
# Epoch: 355, Loss: = 3.2
# Epoch: 356, Loss: = 3.1
# Epoch: 357, Loss: = 3.1
# Epoch: 358, Loss: = 3.1
# Epoch: 359, Loss: = 3.1
# Epoch: 360, Loss: = 3.1
# Epoch: 361, Loss: = 3.1
# Epoch: 362, Loss: = 3.1
# Epoch: 363, Loss: = 3.1
# Epoch: 364, Loss: = 3.1
# Epoch: 365, Loss: = 3.1
# Epoch: 366, Loss: = 3.1
# Epoch: 367, Loss: = 3.1
# Epoch: 368, Loss: = 3.1
# Epoch: 369, Loss: = 3.1
# Epoch: 370, Loss: = 3.1
# Epoch: 371, Loss: = 3.1
# Epoch: 372, Loss: = 3.0
# Epoch: 373, Loss: = 3.0
# Epoch: 374, Loss: = 3.0
# Epoch: 375, Loss: = 3.0
# Epoch: 376, Loss: = 3.0
# Epoch: 377, Loss: = 3.0
# Epoch: 378, Loss: = 3.0
# Epoch: 379, Loss: = 3.0
# Epoch: 380, Loss: = 3.0
# Epoch: 381, Loss: = 3.0
# Epoch: 382, Loss: = 3.0
# Epoch: 383, Loss: = 3.0
# Epoch: 384, Loss: = 3.0
# Epoch: 385, Loss: = 3.0
# Epoch: 386, Loss: = 3.0
# Epoch: 387, Loss: = 3.0
# Epoch: 388, Loss: = 3.0
# Epoch: 389, Loss: = 3.0
# Epoch: 390, Loss: = 2.9
# Epoch: 391, Loss: = 2.9
# Epoch: 392, Loss: = 2.9
# Epoch: 393, Loss: = 2.9
# Epoch: 394, Loss: = 2.9
# Epoch: 395, Loss: = 2.9
# Epoch: 396, Loss: = 2.9
# Epoch: 397, Loss: = 2.9
# Epoch: 398, Loss: = 2.9
# Epoch: 399, Loss: = 2.9
# Epoch: 400, Loss: = 2.9
# Epoch: 401, Loss: = 2.9
# Epoch: 402, Loss: = 2.9
# Epoch: 403, Loss: = 2.9
# Epoch: 404, Loss: = 2.9
# Epoch: 405, Loss: = 2.9
# Epoch: 406, Loss: = 2.9
# Epoch: 407, Loss: = 2.9
# Epoch: 408, Loss: = 2.8
# Epoch: 409, Loss: = 2.8
# Epoch: 410, Loss: = 2.8
# Epoch: 411, Loss: = 2.8
# Epoch: 412, Loss: = 2.8
# Epoch: 413, Loss: = 2.8
# Epoch: 414, Loss: = 2.8
# Epoch: 415, Loss: = 2.8
# Epoch: 416, Loss: = 2.8
# Epoch: 417, Loss: = 2.8
# Epoch: 418, Loss: = 2.8
# Epoch: 419, Loss: = 2.8
# Epoch: 420, Loss: = 2.8
# Epoch: 421, Loss: = 2.8
# Epoch: 422, Loss: = 2.8
# Epoch: 423, Loss: = 2.8
# Epoch: 424, Loss: = 2.8
# Epoch: 425, Loss: = 2.8
# Epoch: 426, Loss: = 2.8
# Epoch: 427, Loss: = 2.8
# Epoch: 428, Loss: = 2.7
# Epoch: 429, Loss: = 2.7
# Epoch: 430, Loss: = 2.7
# Epoch: 431, Loss: = 2.7
# Epoch: 432, Loss: = 2.7
# Epoch: 433, Loss: = 2.7
# Epoch: 434, Loss: = 2.7
# Epoch: 435, Loss: = 2.7
# Epoch: 436, Loss: = 2.7
# Epoch: 437, Loss: = 2.7
# Epoch: 438, Loss: = 2.7
# Epoch: 439, Loss: = 2.7
# Epoch: 440, Loss: = 2.7
# Epoch: 441, Loss: = 2.7
# Epoch: 442, Loss: = 2.7
# Epoch: 443, Loss: = 2.7
# Epoch: 444, Loss: = 2.7
# Epoch: 445, Loss: = 2.7
# Epoch: 446, Loss: = 2.7
# Epoch: 447, Loss: = 2.7
# Epoch: 448, Loss: = 2.7
# Epoch: 449, Loss: = 2.7
# Epoch: 450, Loss: = 2.7
# Epoch: 451, Loss: = 2.6
# Epoch: 452, Loss: = 2.6
# Epoch: 453, Loss: = 2.6
# Epoch: 454, Loss: = 2.6
# Epoch: 455, Loss: = 2.6
# Epoch: 456, Loss: = 2.6
# Epoch: 457, Loss: = 2.6
# Epoch: 458, Loss: = 2.6
# Epoch: 459, Loss: = 2.6
# Epoch: 460, Loss: = 2.6
# Epoch: 461, Loss: = 2.6
# Epoch: 462, Loss: = 2.6
# Epoch: 463, Loss: = 2.6
# Epoch: 464, Loss: = 2.6
# Epoch: 465, Loss: = 2.6
# Epoch: 466, Loss: = 2.6
# Epoch: 467, Loss: = 2.6
# Epoch: 468, Loss: = 2.6
# Epoch: 469, Loss: = 2.6
# Epoch: 470, Loss: = 2.6
# Epoch: 471, Loss: = 2.6
# Epoch: 472, Loss: = 2.6
# Epoch: 473, Loss: = 2.6
# Epoch: 474, Loss: = 2.6
# Epoch: 475, Loss: = 2.6
# Epoch: 476, Loss: = 2.6
# Epoch: 477, Loss: = 2.5
# Epoch: 478, Loss: = 2.5
# Epoch: 479, Loss: = 2.5
# Epoch: 480, Loss: = 2.5
# Epoch: 481, Loss: = 2.5
# Epoch: 482, Loss: = 2.5
# Epoch: 483, Loss: = 2.5
# Epoch: 484, Loss: = 2.5
# Epoch: 485, Loss: = 2.5
# Epoch: 486, Loss: = 2.5
# Epoch: 487, Loss: = 2.5
# Epoch: 488, Loss: = 2.5
# Epoch: 489, Loss: = 2.5
# Epoch: 490, Loss: = 2.5
# Epoch: 491, Loss: = 2.5
# Epoch: 492, Loss: = 2.5
# Epoch: 493, Loss: = 2.5
# Epoch: 494, Loss: = 2.5
# Epoch: 495, Loss: = 2.5
# Epoch: 496, Loss: = 2.5
# Epoch: 497, Loss: = 2.5
# Epoch: 498, Loss: = 2.5
# Epoch: 499, Loss: = 2.5
# Epoch: 500, Loss: = 2.5
# Epoch: 501, Loss: = 2.5
# Epoch: 502, Loss: = 2.5
# Epoch: 503, Loss: = 2.5
# Epoch: 504, Loss: = 2.4
# Epoch: 505, Loss: = 2.4
# Epoch: 506, Loss: = 2.4
# Epoch: 507, Loss: = 2.4
# Epoch: 508, Loss: = 2.4
# Epoch: 509, Loss: = 2.4
# Epoch: 510, Loss: = 2.4
# Epoch: 511, Loss: = 2.4
# Epoch: 512, Loss: = 2.4
# Epoch: 513, Loss: = 2.4
# Epoch: 514, Loss: = 2.4
# Epoch: 515, Loss: = 2.4
# Epoch: 516, Loss: = 2.4
# Epoch: 517, Loss: = 2.4
# Epoch: 518, Loss: = 2.4
# Epoch: 519, Loss: = 2.4
# Epoch: 520, Loss: = 2.4
# Epoch: 521, Loss: = 2.4
# Epoch: 522, Loss: = 2.4
# Epoch: 523, Loss: = 2.4
# Epoch: 524, Loss: = 2.4
# Epoch: 525, Loss: = 2.4
# Epoch: 526, Loss: = 2.4
# Epoch: 527, Loss: = 2.4
# Epoch: 528, Loss: = 2.4
# Epoch: 529, Loss: = 2.4
# Epoch: 530, Loss: = 2.4
# Epoch: 531, Loss: = 2.4
# Epoch: 532, Loss: = 2.4
# Epoch: 533, Loss: = 2.4
# Epoch: 534, Loss: = 2.3
# Epoch: 535, Loss: = 2.3
# Epoch: 536, Loss: = 2.3
# Epoch: 537, Loss: = 2.3
# Epoch: 538, Loss: = 2.3
# Epoch: 539, Loss: = 2.3
# Epoch: 540, Loss: = 2.3
# Epoch: 541, Loss: = 2.3
# Epoch: 542, Loss: = 2.3
# Epoch: 543, Loss: = 2.3
# Epoch: 544, Loss: = 2.3
# Epoch: 545, Loss: = 2.3
# Epoch: 546, Loss: = 2.3
# Epoch: 547, Loss: = 2.3
# Epoch: 548, Loss: = 2.3
# Epoch: 549, Loss: = 2.3
# Epoch: 550, Loss: = 2.3
# Epoch: 551, Loss: = 2.3
# Epoch: 552, Loss: = 2.3
# Epoch: 553, Loss: = 2.3
# Epoch: 554, Loss: = 2.3
# Epoch: 555, Loss: = 2.3
# Epoch: 556, Loss: = 2.3
# Epoch: 557, Loss: = 2.3
# Epoch: 558, Loss: = 2.3
# Epoch: 559, Loss: = 2.3
# Epoch: 560, Loss: = 2.3
# Epoch: 561, Loss: = 2.3
# Epoch: 562, Loss: = 2.3
# Epoch: 563, Loss: = 2.3
# Epoch: 564, Loss: = 2.3
# Epoch: 565, Loss: = 2.2
# Epoch: 566, Loss: = 2.2
# Epoch: 567, Loss: = 2.2
# Epoch: 568, Loss: = 2.2
# Epoch: 569, Loss: = 2.2
# Epoch: 570, Loss: = 2.2
# Epoch: 571, Loss: = 2.2
# Epoch: 572, Loss: = 2.2
# Epoch: 573, Loss: = 2.2
# Epoch: 574, Loss: = 2.2
# Epoch: 575, Loss: = 2.2
# Epoch: 576, Loss: = 2.2
# Epoch: 577, Loss: = 2.2
# Epoch: 578, Loss: = 2.2
# Epoch: 579, Loss: = 2.2
# Epoch: 580, Loss: = 2.2
# Epoch: 581, Loss: = 2.2
# Epoch: 582, Loss: = 2.2
# Epoch: 583, Loss: = 2.2
# Epoch: 584, Loss: = 2.2
# Epoch: 585, Loss: = 2.2
# Epoch: 586, Loss: = 2.2
# Epoch: 587, Loss: = 2.2
# Epoch: 588, Loss: = 2.2
# Epoch: 589, Loss: = 2.2
# Epoch: 590, Loss: = 2.2
# Epoch: 591, Loss: = 2.2
# Epoch: 592, Loss: = 2.2
# Epoch: 593, Loss: = 2.2
# Epoch: 594, Loss: = 2.2
# Epoch: 595, Loss: = 2.2
# Epoch: 596, Loss: = 2.2
# Epoch: 597, Loss: = 2.2
# Epoch: 598, Loss: = 2.1
# Epoch: 599, Loss: = 2.1
# Epoch: 600, Loss: = 2.1
# Epoch: 601, Loss: = 2.1
# Epoch: 602, Loss: = 2.1
# Epoch: 603, Loss: = 2.1
# Epoch: 604, Loss: = 2.1
# Epoch: 605, Loss: = 2.1
# Epoch: 606, Loss: = 2.1
# Epoch: 607, Loss: = 2.1
# Epoch: 608, Loss: = 2.1
# Epoch: 609, Loss: = 2.1
# Epoch: 610, Loss: = 2.1
# Epoch: 611, Loss: = 2.1
# Epoch: 612, Loss: = 2.1
# Epoch: 613, Loss: = 2.1
# Epoch: 614, Loss: = 2.1
# Epoch: 615, Loss: = 2.1
# Epoch: 616, Loss: = 2.1
# Epoch: 617, Loss: = 2.1
# Epoch: 618, Loss: = 2.1
# Epoch: 619, Loss: = 2.1
# Epoch: 620, Loss: = 2.1
# Epoch: 621, Loss: = 2.1
# Epoch: 622, Loss: = 2.1
# Epoch: 623, Loss: = 2.1
# Epoch: 624, Loss: = 2.1
# Epoch: 625, Loss: = 2.1
# Epoch: 626, Loss: = 2.1
# Epoch: 627, Loss: = 2.1
# Epoch: 628, Loss: = 2.1
# Epoch: 629, Loss: = 2.1
# Epoch: 630, Loss: = 2.1
# Epoch: 631, Loss: = 2.1
# Epoch: 632, Loss: = 2.1
# Epoch: 633, Loss: = 2.1
# Epoch: 634, Loss: = 2.0
# Epoch: 635, Loss: = 2.0
# Epoch: 636, Loss: = 2.0
# Epoch: 637, Loss: = 2.0
# Epoch: 638, Loss: = 2.0
# Epoch: 639, Loss: = 2.0
# Epoch: 640, Loss: = 2.0
# Epoch: 641, Loss: = 2.0
# Epoch: 642, Loss: = 2.0
# Epoch: 643, Loss: = 2.0
# Epoch: 644, Loss: = 2.0
# Epoch: 645, Loss: = 2.0
# Epoch: 646, Loss: = 2.0
# Epoch: 647, Loss: = 2.0
# Epoch: 648, Loss: = 2.0
# Epoch: 649, Loss: = 2.0
# Epoch: 650, Loss: = 2.0
# Epoch: 651, Loss: = 2.0
# Epoch: 652, Loss: = 2.0
# Epoch: 653, Loss: = 2.0
# Epoch: 654, Loss: = 2.0
# Epoch: 655, Loss: = 2.0
# Epoch: 656, Loss: = 2.0
# Epoch: 657, Loss: = 2.0
# Epoch: 658, Loss: = 2.0
# Epoch: 659, Loss: = 2.0
# Epoch: 660, Loss: = 2.0
# Epoch: 661, Loss: = 2.0
# Epoch: 662, Loss: = 2.0
# Epoch: 663, Loss: = 2.0
# Epoch: 664, Loss: = 2.0
# Epoch: 665, Loss: = 2.0
# Epoch: 666, Loss: = 2.0
# Epoch: 667, Loss: = 2.0
# Epoch: 668, Loss: = 2.0
# Epoch: 669, Loss: = 2.0
# Epoch: 670, Loss: = 2.0
# Epoch: 671, Loss: = 2.0
# Epoch: 672, Loss: = 2.0
# Epoch: 673, Loss: = 2.0
# Epoch: 674, Loss: = 1.9
# Epoch: 675, Loss: = 1.9
# Epoch: 676, Loss: = 1.9
# Epoch: 677, Loss: = 1.9
# Epoch: 678, Loss: = 1.9
# Epoch: 679, Loss: = 1.9
# Epoch: 680, Loss: = 1.9
# Epoch: 681, Loss: = 1.9
# Epoch: 682, Loss: = 1.9
# Epoch: 683, Loss: = 1.9
# Epoch: 684, Loss: = 1.9
# Epoch: 685, Loss: = 1.9
# Epoch: 686, Loss: = 1.9
# Epoch: 687, Loss: = 1.9
# Epoch: 688, Loss: = 1.9
# Epoch: 689, Loss: = 1.9
# Epoch: 690, Loss: = 1.9
# Epoch: 691, Loss: = 1.9
# Epoch: 692, Loss: = 1.9
# Epoch: 693, Loss: = 1.9
# Epoch: 694, Loss: = 1.9
# Epoch: 695, Loss: = 1.9
# Epoch: 696, Loss: = 1.9
# Epoch: 697, Loss: = 1.9
# Epoch: 698, Loss: = 1.9
# Epoch: 699, Loss: = 1.9
# Epoch: 700, Loss: = 1.9
# Epoch: 701, Loss: = 1.9
# Epoch: 702, Loss: = 1.9
# Epoch: 703, Loss: = 1.9
# Epoch: 704, Loss: = 1.9
# Epoch: 705, Loss: = 1.9
# Epoch: 706, Loss: = 1.9
# Epoch: 707, Loss: = 1.9
# Epoch: 708, Loss: = 1.9
# Epoch: 709, Loss: = 1.9
# Epoch: 710, Loss: = 1.9
# Epoch: 711, Loss: = 1.9
# Epoch: 712, Loss: = 1.9
# Epoch: 713, Loss: = 1.9
# Epoch: 714, Loss: = 1.9
# Epoch: 715, Loss: = 1.9
# Epoch: 716, Loss: = 1.8
# Epoch: 717, Loss: = 1.8
# Epoch: 718, Loss: = 1.8
# Epoch: 719, Loss: = 1.8
# Epoch: 720, Loss: = 1.8
# Epoch: 721, Loss: = 1.8
# Epoch: 722, Loss: = 1.8
# Epoch: 723, Loss: = 1.8
# Epoch: 724, Loss: = 1.8
# Epoch: 725, Loss: = 1.8
# Epoch: 726, Loss: = 1.8
# Epoch: 727, Loss: = 1.8
# Epoch: 728, Loss: = 1.8
# Epoch: 729, Loss: = 1.8
# Epoch: 730, Loss: = 1.8
# Epoch: 731, Loss: = 1.8
# Epoch: 732, Loss: = 1.8
# Epoch: 733, Loss: = 1.8
# Epoch: 734, Loss: = 1.8
# Epoch: 735, Loss: = 1.8
# Epoch: 736, Loss: = 1.8
# Epoch: 737, Loss: = 1.8
# Epoch: 738, Loss: = 1.8
# Epoch: 739, Loss: = 1.8
# Epoch: 740, Loss: = 1.8
# Epoch: 741, Loss: = 1.8
# Epoch: 742, Loss: = 1.8
# Epoch: 743, Loss: = 1.8
# Epoch: 744, Loss: = 1.8
# Epoch: 745, Loss: = 1.8
# Epoch: 746, Loss: = 1.8
# Epoch: 747, Loss: = 1.8
# Epoch: 748, Loss: = 1.8
# Epoch: 749, Loss: = 1.8
# Epoch: 750, Loss: = 1.8
# Epoch: 751, Loss: = 1.8
# Epoch: 752, Loss: = 1.8
# Epoch: 753, Loss: = 1.8
# Epoch: 754, Loss: = 1.8
# Epoch: 755, Loss: = 1.8
# Epoch: 756, Loss: = 1.8
# Epoch: 757, Loss: = 1.8
# Epoch: 758, Loss: = 1.8
# Epoch: 759, Loss: = 1.7
# Epoch: 760, Loss: = 1.7
# Epoch: 761, Loss: = 1.7
# Epoch: 762, Loss: = 1.7
# Epoch: 763, Loss: = 1.7
# Epoch: 764, Loss: = 1.7
# Epoch: 765, Loss: = 1.7
# Epoch: 766, Loss: = 1.7
# Epoch: 767, Loss: = 1.7
# Epoch: 768, Loss: = 1.7
# Epoch: 769, Loss: = 1.7
# Epoch: 770, Loss: = 1.7
# Epoch: 771, Loss: = 1.7
# Epoch: 772, Loss: = 1.7
# Epoch: 773, Loss: = 1.7
# Epoch: 774, Loss: = 1.7
# Epoch: 775, Loss: = 1.7
# Epoch: 776, Loss: = 1.7
# Epoch: 777, Loss: = 1.7
# Epoch: 778, Loss: = 1.7
# Epoch: 779, Loss: = 1.7
# Epoch: 780, Loss: = 1.7
# Epoch: 781, Loss: = 1.7
# Epoch: 782, Loss: = 1.7
# Epoch: 783, Loss: = 1.7
# Epoch: 784, Loss: = 1.7
# Epoch: 785, Loss: = 1.7
# Epoch: 786, Loss: = 1.7
# Epoch: 787, Loss: = 1.7
# Epoch: 788, Loss: = 1.7
# Epoch: 789, Loss: = 1.7
# Epoch: 790, Loss: = 1.7
# Epoch: 791, Loss: = 1.7
# Epoch: 792, Loss: = 1.7
# Epoch: 793, Loss: = 1.7
# Epoch: 794, Loss: = 1.7
# Epoch: 795, Loss: = 1.7
# Epoch: 796, Loss: = 1.7
# Epoch: 797, Loss: = 1.7
# Epoch: 798, Loss: = 1.7
# Epoch: 799, Loss: = 1.7
# Epoch: 800, Loss: = 1.7
# Epoch: 801, Loss: = 1.7
# Epoch: 802, Loss: = 1.6
# Epoch: 803, Loss: = 1.6
# Epoch: 804, Loss: = 1.6
# Epoch: 805, Loss: = 1.6
# Epoch: 806, Loss: = 1.6
# Epoch: 807, Loss: = 1.6
# Epoch: 808, Loss: = 1.6
# Epoch: 809, Loss: = 1.6
# Epoch: 810, Loss: = 1.6
# Epoch: 811, Loss: = 1.6
# Epoch: 812, Loss: = 1.6
# Epoch: 813, Loss: = 1.6
# Epoch: 814, Loss: = 1.6
# Epoch: 815, Loss: = 1.6
# Epoch: 816, Loss: = 1.6
# Epoch: 817, Loss: = 1.6
# Epoch: 818, Loss: = 1.6
# Epoch: 819, Loss: = 1.6
# Epoch: 820, Loss: = 1.6
# Epoch: 821, Loss: = 1.6
# Epoch: 822, Loss: = 1.6
# Epoch: 823, Loss: = 1.6
# Epoch: 824, Loss: = 1.6
# Epoch: 825, Loss: = 1.6
# Epoch: 826, Loss: = 1.6
# Epoch: 827, Loss: = 1.6
# Epoch: 828, Loss: = 1.6
# Epoch: 829, Loss: = 1.6
# Epoch: 830, Loss: = 1.6
# Epoch: 831, Loss: = 1.6
# Epoch: 832, Loss: = 1.6
# Epoch: 833, Loss: = 1.6
# Epoch: 834, Loss: = 1.6
# Epoch: 835, Loss: = 1.6
# Epoch: 836, Loss: = 1.6
# Epoch: 837, Loss: = 1.6
# Epoch: 838, Loss: = 1.6
# Epoch: 839, Loss: = 1.6
# Epoch: 840, Loss: = 1.6
# Epoch: 841, Loss: = 1.6
# Epoch: 842, Loss: = 1.6
# Epoch: 843, Loss: = 1.6
# Epoch: 844, Loss: = 1.6
# Epoch: 845, Loss: = 1.6
# Epoch: 846, Loss: = 1.6
# Epoch: 847, Loss: = 1.6
# Epoch: 848, Loss: = 1.5
# Epoch: 849, Loss: = 1.5
# Epoch: 850, Loss: = 1.5
# Epoch: 851, Loss: = 1.5
# Epoch: 852, Loss: = 1.5
# Epoch: 853, Loss: = 1.5
# Epoch: 854, Loss: = 1.5
# Epoch: 855, Loss: = 1.5
# Epoch: 856, Loss: = 1.5
# Epoch: 857, Loss: = 1.5
# Epoch: 858, Loss: = 1.5
# Epoch: 859, Loss: = 1.5
# Epoch: 860, Loss: = 1.5
# Epoch: 861, Loss: = 1.5
# Epoch: 862, Loss: = 1.5
# Epoch: 863, Loss: = 1.5
# Epoch: 864, Loss: = 1.5
# Epoch: 865, Loss: = 1.5
# Epoch: 866, Loss: = 1.5
# Epoch: 867, Loss: = 1.5
# Epoch: 868, Loss: = 1.5
# Epoch: 869, Loss: = 1.5
# Epoch: 870, Loss: = 1.5
# Epoch: 871, Loss: = 1.5
# Epoch: 872, Loss: = 1.5
# Epoch: 873, Loss: = 1.5
# Epoch: 874, Loss: = 1.5
# Epoch: 875, Loss: = 1.5
# Epoch: 876, Loss: = 1.5
# Epoch: 877, Loss: = 1.5
# Epoch: 878, Loss: = 1.5
# Epoch: 879, Loss: = 1.5
# Epoch: 880, Loss: = 1.5
# Epoch: 881, Loss: = 1.5
# Epoch: 882, Loss: = 1.5
# Epoch: 883, Loss: = 1.5
# Epoch: 884, Loss: = 1.5
# Epoch: 885, Loss: = 1.5
# Epoch: 886, Loss: = 1.5
# Epoch: 887, Loss: = 1.5
# Epoch: 888, Loss: = 1.5
# Epoch: 889, Loss: = 1.5
# Epoch: 890, Loss: = 1.5
# Epoch: 891, Loss: = 1.5
# Epoch: 892, Loss: = 1.5
# Epoch: 893, Loss: = 1.5
# Epoch: 894, Loss: = 1.5
# Epoch: 895, Loss: = 1.5
# Epoch: 896, Loss: = 1.5
# Epoch: 897, Loss: = 1.5
# Epoch: 898, Loss: = 1.5
# Epoch: 899, Loss: = 1.5
# Epoch: 900, Loss: = 1.5
# Epoch: 901, Loss: = 1.4
# Epoch: 902, Loss: = 1.4
# Epoch: 903, Loss: = 1.4
# Epoch: 904, Loss: = 1.4
# Epoch: 905, Loss: = 1.4
# Epoch: 906, Loss: = 1.4
# Epoch: 907, Loss: = 1.4
# Epoch: 908, Loss: = 1.4
# Epoch: 909, Loss: = 1.4
# Epoch: 910, Loss: = 1.4
# Epoch: 911, Loss: = 1.4
# Epoch: 912, Loss: = 1.4
# Epoch: 913, Loss: = 1.4
# Epoch: 914, Loss: = 1.4
# Epoch: 915, Loss: = 1.4
# Epoch: 916, Loss: = 1.4
# Epoch: 917, Loss: = 1.4
# Epoch: 918, Loss: = 1.4
# Epoch: 919, Loss: = 1.4
# Epoch: 920, Loss: = 1.4
# Epoch: 921, Loss: = 1.4
# Epoch: 922, Loss: = 1.4
# Epoch: 923, Loss: = 1.4
# Epoch: 924, Loss: = 1.4
# Epoch: 925, Loss: = 1.4
# Epoch: 926, Loss: = 1.4
# Epoch: 927, Loss: = 1.4
# Epoch: 928, Loss: = 1.4
# Epoch: 929, Loss: = 1.4
# Epoch: 930, Loss: = 1.4
# Epoch: 931, Loss: = 1.4
# Epoch: 932, Loss: = 1.4
# Epoch: 933, Loss: = 1.4
# Epoch: 934, Loss: = 1.4
# Epoch: 935, Loss: = 1.4
# Epoch: 936, Loss: = 1.4
# Epoch: 937, Loss: = 1.4
# Epoch: 938, Loss: = 1.4
# Epoch: 939, Loss: = 1.4
# Epoch: 940, Loss: = 1.4
# Epoch: 941, Loss: = 1.4
# Epoch: 942, Loss: = 1.4
# Epoch: 943, Loss: = 1.4
# Epoch: 944, Loss: = 1.4
# Epoch: 945, Loss: = 1.4
# Epoch: 946, Loss: = 1.4
# Epoch: 947, Loss: = 1.4
# Epoch: 948, Loss: = 1.4
# Epoch: 949, Loss: = 1.4
# Epoch: 950, Loss: = 1.4
# Epoch: 951, Loss: = 1.4
# Epoch: 952, Loss: = 1.4
# Epoch: 953, Loss: = 1.4
# Epoch: 954, Loss: = 1.4
# Epoch: 955, Loss: = 1.4
# Epoch: 956, Loss: = 1.4
# Epoch: 957, Loss: = 1.4
# Epoch: 958, Loss: = 1.4
# Epoch: 959, Loss: = 1.4
# Epoch: 960, Loss: = 1.4
# Epoch: 961, Loss: = 1.4
# Epoch: 962, Loss: = 1.4
# Epoch: 963, Loss: = 1.3
# Epoch: 964, Loss: = 1.3
# Epoch: 965, Loss: = 1.3
# Epoch: 966, Loss: = 1.3
# Epoch: 967, Loss: = 1.3
# Epoch: 968, Loss: = 1.3
# Epoch: 969, Loss: = 1.3
# Epoch: 970, Loss: = 1.3
# Epoch: 971, Loss: = 1.3
# Epoch: 972, Loss: = 1.3
# Epoch: 973, Loss: = 1.3
# Epoch: 974, Loss: = 1.3
# Epoch: 975, Loss: = 1.3
# Epoch: 976, Loss: = 1.3
# Epoch: 977, Loss: = 1.3
# Epoch: 978, Loss: = 1.3
# Epoch: 979, Loss: = 1.3
# Epoch: 980, Loss: = 1.3
# Epoch: 981, Loss: = 1.3
# Epoch: 982, Loss: = 1.3
# Epoch: 983, Loss: = 1.3
# Epoch: 984, Loss: = 1.3
# Epoch: 985, Loss: = 1.3
# Epoch: 986, Loss: = 1.3
# Epoch: 987, Loss: = 1.3
# Epoch: 988, Loss: = 1.3
# Epoch: 989, Loss: = 1.3
# Epoch: 990, Loss: = 1.3
# Epoch: 991, Loss: = 1.3
# Epoch: 992, Loss: = 1.3
# Epoch: 993, Loss: = 1.3
# Epoch: 994, Loss: = 1.3
# Epoch: 995, Loss: = 1.3
# Epoch: 996, Loss: = 1.3
# Epoch: 997, Loss: = 1.3
# Epoch: 998, Loss: = 1.3
# Epoch: 999, Loss: = 1.3
# Epoch: 1000, Loss: = 1.3
# Accuracy of logistic regression on test data = 80.00 percent.

# %% [markdown]
# ### Q3.  Print the classification report on the test data. The function 'classification_report' from 'sklearn.metrics' might prove useful. (10 points)

# %%
print(classification_report(test_prediction, test_Y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.58      0.71        19
#          1.0       0.76      0.96      0.85        26
#
#     accuracy                           0.80        45
#    macro avg       0.84      0.77      0.78        45
# weighted avg       0.82      0.80      0.79        45

# %% [markdown]
# ### Q4. Based on the classification report you obtain, your classifier is better in which of the following tasks? (20 points)
# 1. If it identifies a house to have a PV panel, then it has a PV panel.
#
# 2. If there is a PV panel, then it identifies that it has a PV panel.
#
# Furthermore, complete the code below to plot the energy drawn from the grid from houses with and without PV panels.
#
#
#     Answer: As shown above table, task 1 has about 96% success rate and while task 2 has about 76% success rate. We could see that by reading precision and recall in the above table, task 1 is doing a better work which identifies a house to have a PV panel, then it has a PV panel.

# %%
# Plot energy drawn from grid for houses with PV's.
house_id_pv = random.sample(list(dfData_houses.loc[dfData_houses['pv'] == 1].index.values), 5)

fig, axs = plt.subplots(1, 5, sharey=True, figsize=(15,5))

for tt, house_id in enumerate(house_id_pv):
    for day in days_data:
        # Enter code here
        axs[tt].plot(energy_day(house_id, day, 'grid'))            
    axs[tt].set_title("House " + str(house_id))
fig.suptitle('Houses with PV panels.', fontsize=18)

for ax in axs.flat:
    ax.set(xlabel='Hour', ylabel='Energy in kWh')
for ax in axs.flat:
    ax.label_outer()

house_id_not_pv = random.sample(list(dfData_houses.loc[dfData_houses['pv'] == 0].index.values), 5)

fig, axs = plt.subplots(1, 5, sharey=True, figsize=(15,5))
axs = axs.ravel()

for tt, house_id in enumerate(house_id_not_pv):
    for day in days_data:
    # Enter code here
        axs[tt].plot(energy_day(house_id, day, 'grid'))
    axs[tt].set_title(house_id)

fig.suptitle('Houses without PV panels.', fontsize=18)        

for ax in axs.flat:
    ax.set(xlabel='Hour', ylabel='Energy in kWh')
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# ### Q5. Design a classifier to distinguish between houses with and without PV based on the plots. Print your classification report, and compare it with logistic regression. (10 points, bonus)

# %%
# Compare the performance of a neural network based classifier with an educated guess.
from sklearn.linear_model import LogisticRegression

LRModel = LogisticRegression(solver='liblinear')
LRModel.fit(train_X.numpy(), train_Y.numpy().ravel())
print(classification_report(LRModel.predict(test_X), test_Y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.75      0.86        16
#          1.0       0.88      1.00      0.94        29
#
#     accuracy                           0.91        45
#    macro avg       0.94      0.88      0.90        45
# weighted avg       0.92      0.91      0.91        45

# %% [markdown]
# ## What appliance consumes the most power?
#
# Thermal loads are almost always the appliances that consume the most power. The amount of power they draw also typically grows with the size of the house. In the following, we have two tasks:
# 1. What percentage of energy consumption is due to an air conditioner?
# 2. Can you derive a linear relationship between household square footage and power consumption from air conditions in July 2017?

# %%
for house_id in dfData_houses.index.values:
    dfData_houses.at[house_id, 'ac_usage'] = (total_energy_all_days(house_id, 'air1') + 
                                              total_energy_all_days(house_id, 'air2') + 
                                              total_energy_all_days(house_id, 'air3') +
                                              total_energy_all_days(house_id, 'airwindowunit1')
                                          )
    dfData_houses.at[house_id, 'total_usage'] = total_energy_all_days(house_id, 'use')

fig, axs = plt.subplots(1, 2, figsize=(15,5))

axs[0].scatter(dfData_houses['area'].values, 
               dfData_houses['ac_usage'].values, 
               c='r', marker='o', label='AC usage'
              )
axs[0].set_xlabel('Floor area of house (sq. ft.)')
axs[0].set_ylabel('Total AC Usage (kWh).')
axs[0].set_title('Power consumption from air conditioners July 2017.', fontsize=14)

axs[1].hist(x=np.divide(dfData_houses['ac_usage'], dfData_houses['total_usage']), bins=20, alpha=0.6, color='#0504aa', rwidth=0.85)
axs[1].set_xlabel('Fraction of AC usage over total power consumption')
axs[1].set_ylabel('Frequency')
axs[1].set_title('Histogram of AC usage as a fraction of total power consumption.', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Histogram of AC usage as a fraction of total power consumption.')

# %% [markdown]
# ### Q6. Based on the above analysis, will you expect the total power consumption from customers to be more or less in October as compared to that in July? How does the above analysis compare to your analysis in Lab 1 on aggregate load prediction in Texas? (10 points)
#
#     Because in common sense, July is much hotter than October due to the heat conduction in weather so I expect the AC usage fraction over the total power to be lower. For that reason, the majority AC usage contributes to the power consumption in July which I expect to be lower in October, I would expect that overall power consumption would be much lower in October than July.
#
# ### Q7. Can you think of a business case for the above histogram? (5 points, bonus)
#
#     The histogram on the right side can be used for marketing of the solar panel business with focusing on profitable asepct for future customers; AC operation cost is quite a lot such while the frequeent operating time is wheen the sun is out that we can use solar panels to capture and recyle its usage.

# %% [markdown]
# ### Compute monthly electric bills for each customer
#
# Your electricity bill consists of various charges. These charges depend on the utility company you pay your electricity bill to. In Champaign, IL, your distribution utility company is Ameren. In Austin, a major distribution utility company is Austin Energy. Their bill structure is discussed in the following link:
# https://austinenergy.com/ae/residential/rates/residential-electric-rates-and-line-items
#
# Calculate the monthly bill of each household.
#
# 1. For each customer, compute the total energy consumed, available in the data field "use" over the month. Use the tiered rate structure to compute the total power bill for energy consumption.
#
# 2. For customers with PV panels, compute the total energy produced by the PV panels. Assume that Ameren Energy pays 9.7 cents/kWh for such production, and subtract the amount for solar power production from the power bill.

# %%
# Define a function that computes the electricity bill according to the structure defined by Austin Energy.

def electricity_bill(consumption):
    customer_charge = 10
    power_supply_adjustment = 2.895 * consumption / 100.0
    community_benefit_charge = (0.154 + 0.124 + 0.335) * consumption / 100.0
    regulatory_charge = 1.342 * consumption / 100.0
    
    tier_rate = [2.801, 5.832, 7.814, 9.314, 10.814]    
    tier_limits = [0, 500, 1000, 1500, 2500, math.inf]
    n_tiers = 5
    
    energy_charge = 0
    
    for tier in range(n_tiers):
        consumption_tier = min(max(consumption, tier_limits[tier]), tier_limits[tier + 1]) - tier_limits[tier]
        energy_charge += consumption_tier * tier_rate[tier] / 100.0
        
    return float('%.2f'%(1.01 * (energy_charge + customer_charge + power_supply_adjustment + community_benefit_charge
                   + regulatory_charge)))

for house_id in dfData_houses.index.values:
    dfData_houses.at[house_id, 'consumption_bill'] = electricity_bill(dfData_houses.loc[house_id, 'total_usage'])
    dfData_houses.at[house_id, 'pv_savings'] = total_energy_all_days(house_id, 'gen') * 9.7 / 100.0
    dfData_houses.at[house_id, 'electricity_bill'] = dfData_houses.loc[house_id, 'consumption_bill'] 
    - dfData_houses.loc[house_id, 'pv_savings']
    
    
print("Electricity bill computed for all customers.")
# Out:
# Electricity bill computed for all customers.

# %% [markdown]
# ### What is a good indicator of electricity bill for consumption and savings from PV?
#
# Electricity consumption significantly depends on floor area of a house. The dependency is even stronger, if the house is equipped with central AC. A scatter plot of the consumption bill against floor area reveals this dependency.
#
# Monetary savings from PV panels depends on how many PV panels there are, which way they face, and how that relates to solar insolation. The number of panels installed largely depends on the roof area. The floor area of one of the floors is a good indicator.
#
# # My fix on the given code: axs[1] has to be a scatter of the 'area_floor' or not so I have fixed it from 'area' to 'area_floor'

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,4))

# Plot of electricity bill for consumption against the square footage of the house.

axs[0].scatter(dfData_houses['area'].values, 
               dfData_houses['consumption_bill'].values, 
               c='r', marker='o', label='Electricity bill from consumption'
           )
axs[0].set_xlabel('Floor area of house (sq. ft.)')
axs[0].set_ylabel('Energy bill (dollars).')
axs[0].set_title('Electricity bill from power consumption over July 2017.', fontsize=14)

# Plot monetary savings from PV against the area of the first floor.

houses_without_pv = dfData_houses.loc[dfData_houses['pv'] == 0].index.values
houses_with_pv = dfData_houses.loc[dfData_houses['pv'] == 1].index.values

axs[1].scatter(dfData_houses.loc[houses_with_pv, 'area_floor'].values, 
               dfData_houses.loc[houses_with_pv, 'pv_savings'].values, 
               c='g', marker='o', label='Savings from PV')

axs[1].set_xlabel('Area of first floor (sq. ft.)')
axs[1].set_ylabel('Monthly savings (dollars).')
axs[1].set_title('Monthly savings from PV panels over July 2017.', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Monthly savings from PV panels over July 2017.')

# %% [markdown]
# ### Given the square footage of the house and the first floor, compute the electricity bill with and without PV.
#
# Perform a linear regression on electricity bill and monthly savings from PV. Use the linear fits to compute the anticipated electricity bill with and without PV. Report your anticipated percentage savings with PV.
#
# Use the data:
# 1. Square footage of entire house = 2450 sq. ft.
# 2. Square footage of first floor = 1380 sq. ft.
#
# ### Q8. Fill in the gaps below. Let's say you have $\$18,000$ to spend on a PV and get $\$2,500 $ in solar rebate . How long will it take (in years) for you to recover the initial investment?  (20 points)

# %%
area_house = 2450
area_first_floor = 1380

XX = dfData_houses['area'].values.reshape(-1, 1) 
YY = dfData_houses['consumption_bill'].values.reshape(-1, 1)

model_consumption = linear_model.LinearRegression()
model_consumption.fit(XX, YY)

print("Predicted power bill = $%.2f" %  model_consumption.predict(np.array([area_house]).reshape(-1, 1)))

# Enter code here to compute predicted savings from PV 

XX = dfData_houses['area_floor'].values.reshape(-1, 1) 
YY = dfData_houses['pv_savings'].values.reshape(-1, 1)

model_consumption = linear_model.LinearRegression()
model_consumption.fit(XX, YY)

print("Predicted power bill = $%.2f" %  model_consumption.predict(np.array([area_first_floor]).reshape(-1, 1)))

N = 18000 - 2500
D = 12 * model_consumption.predict(np.array([area_first_floor]).reshape(-1, 1))[0][0]
print(math.ceil(N/D), "expected years until the first profit will be made to recover the initial investment")

del XX, YY
# Out:
# Predicted power bill = $221.84
# Predicted power bill = $47.89
# 27 expected years until the first profit will be made to recover the initial investment
