# %% [markdown]
# # Virtual bidding in NYISO's markets
#
#
# In this lab, we will implement a simple virtual trading strategy in New York
# ISO's electricity markets. The goal is to maximize profits. We shall train our
# model on price data from one year, and implement the strategy on the data from
# the next year. How much can you earn with a certain daily budget? Say \$250K?
#
# We will present a trading strategy. You are welcome to try other strategies and compare the gains over multiple runs.
#
# Let's start with customary imports.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import choice
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import pickle

from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## Load the day-ahead and real-time prices from 11 zones in New York.
#
# The day-ahead prices are defined every hour. The real-time market runs every 5 minutes. For each zone, an average of
# these prices over an hour is published.
#
# Store the list of zones in the variable 'listOfZones'. Also, store the number of options
# as the number of zones times the 24 hours available for trading. Finally create another
# list containing the option names (zone + hour).

# %%
listOfZones = ['CAPITL', 'CENTRL', 'DUNWOD', 'GENESE', 'HUD VL', 'LONGIL', 'MHK VL',
               'MILLWD', 'N.Y.C.', 'NORTH', 'WEST']

nOptions = len(listOfZones) * 24
optionNames = [zone + "_Hour_" + str(t) for zone in listOfZones for t in range(24)]

# %% [markdown]
# ## Parse the files with DA and RT prices along with DA load forecast.
#
# Define a function that parses three files containing DA and RT prices, along with DA load predictions from a year from all different zones in the list defined before. This function will be used for to both load the data for training the classifiers and testing them. This function has 3 outputs: they are DA prices, difference between DA and RT prices, and finally DA load predictions. The outputs are pandas data frames whose columns are the options, and rows are the days in the year.

# %%
def loadNYISOData(year):

    # Open the relevant files for DA prices, RT prices, DA load.

    dfPriceDA = pd.read_csv("DAM_NYISO_Zonal_LBMP_" + str(year) + ".csv")
    dfPriceRT = pd.read_csv("RTM_NYISO_Zonal_LBMP_" + str(year) + ".csv")
    dfLoadDA = pd.read_csv("DAM_NYISO_LoadForecast_" + str(year) + ".csv")

    # Collect the DA and RT prices from each zone from each hour and create a pandas list.
    # The data should have prices and loads from all days of a year, where each day
    # contributes 24 rows, corresponding to each hour.

    priceDA = pd.DataFrame({zone: (dfPriceDA.loc[dfPriceDA['Zone Name'] == zone,
                                                 'DAM Zonal LBMP']).values
                             for zone in listOfZones})
    priceRT = pd.DataFrame({zone: (dfPriceRT.loc[dfPriceRT['Zone Name'] == zone,
                                                 'TWI Zonal LBMP']).values
                             for zone in listOfZones})
    loadDA = pd.DataFrame({zone: (dfLoadDA.loc[dfLoadDA['Zone Name'] == zone,
                                               'DAM Forecast Load']).values
                            for zone in listOfZones})

    numberOfDays = int(len(priceDA.index)/24)

    # Compute the price differences between DA and RT prices for all options on
    # all days of the year. Store it as a pandas data frame where the 24 rows for
    # each day is flattened into one row. This operation essentially allows us to
    # independently think of each zone in each hour as a separate option. Also,
    # reshape the prices for the DA market in the same manner.

    priceDART = pd.DataFrame([priceRT.sub(priceDA).loc[day * 24:
                                                              (day + 1) * 24 - 1,
                              listOfZones].values.flatten()
                              for day in range(numberOfDays)],
                             columns=optionNames)

    priceDA = pd.DataFrame([priceDA.loc[day * 24: (day + 1) * 24 - 1,
                            listOfZones].values.flatten()
                            for day in range(numberOfDays)],
                           columns=optionNames)

    return priceDA, priceDART, loadDA

# %% [markdown]
# ## Create a function that creates the inputs for training a classifier
#
# Create a function that takes the price and load data and creates two arrays
# 'X' and 'Y'. Essentially, the rows of 'X' contains all information relevant to
#  predicting the sign of the price difference on the various options on the next day.
#  It takes as an input, three pandas frames corresponding to the DA prices, price
#  differences, and the DA load predictions, and produces three outputs:
#  the arrays 'X', 'Y', and the range of days from the year that were used to
#  create the data 'X' and 'Y'. This function will be used to both train and
#  test classifiers.

# %%
def createClassifierIO(priceDA, priceDART, loadDA):

    # Define how many past days of prices to use for classification.

    pastPrices = range(1, 3)

    # Define how many past days of load predictions to use for classification.

    pastLoad = range(1, 3)

    # Define a date range within the year to create the arrays 'X' and 'Y' in a way
    # that past price and load data for the first day is within the date range in the
    # pandas frames passed as inputs.

    rangeOfDays = range(3, len(priceDA.index))

    # 'X' will contain three sets of variables:
    #   1. the DA prices from past days in the list 'pastDays',
    #   2. the differences between DA and RT prices from the same past days,
    #   3. the load predictions from past days in the list 'pastLoad'

    X = [np.concatenate((
        priceDA.loc[[(day - h) for h in pastPrices]].values.flatten(),
        priceDART.loc[[(day - h) for h in pastPrices]].values.flatten(),
        loadDA.loc[[(day - h) for h in pastLoad]].values.flatten()
    )) for day in rangeOfDays]

    # Scale the array 'X' to make its data zero mean and unit variance.
    X = StandardScaler().fit_transform(X)

    # 'Y' will contain zeros and ones, where a one indicates that the price in DA is
    # higher than in RT for a particular option. Recall that an option corresponds to
    # a zone at a particular hour of the day.

    Y = np.array([(priceDART.loc[day].values > 0).astype(int)
                  for day in rangeOfDays])

    # Return the arrays 'X' and 'Y', and finally the range of days from the year that
    # will be utilized for training or testing the classifier.
    return X, Y, rangeOfDays

# %% [markdown]
# ## Design the training module.
#  The training module utilizes a year's worth of data to determine the following for
#  each option, i.e., for each zone for each hour of the day:
#    1. Classifiers that predict the sign of the difference between DA and RT prices.
#    2. Statistics of the mean of the price difference.
#    3. A quantile of the day-ahead prices that we will use as our bid for each option.
#  You will either train the classifiers here or load them from the folder './Classifiers'.
#  Storing the classifiers from time to time allows you to only vary the bidding strategy
#  and observe the annual reward rather than having to train the classifiers every time.
#
# ### Define and train the classifiers or load pre-trained classifiers.

# %%
classifiers = []

# We have two options here. Use previous training experience, or learn anew.
useSavedClassifiers = False

if not useSavedClassifiers:

    print("Starting training module...\n")
    trainPriceDA, trainPriceDART, trainLoadDA = loadNYISOData(2015)

    numberOfDays =  int(len(trainPriceDA.index))
    print("Loaded hourly prices from 2015 for %d days." % numberOfDays)

    # We will implement a trading strategy, where we bid a particular quantile of the past
    # DA prices for an option. If you do not know what a quantile means, refer to the Wikipedia
    # article on it. Essentially, a 95% quantile of the DA prices equals that value for which
    # 95% of the DA prices are below it. Store all quantiles starting from 50% in steps of
    # 5% in a dictionary. Store them in a pickle file.

    quantilesToStore = [0.70, 0.75, 0.80, 0.85, 0.90, 0.95]
    offerPrices = trainPriceDA.quantile(q=quantilesToStore).transpose().to_dict()
    pickle.dump(offerPrices, open("./Training/OfferPrices", 'wb'))

    # Calculate the average price spread for each option over the entire year. This will guide
    # us in choosing our portfolio. Store it as a dictionary. Our bid will choose those
    # options that our classifier indicates that they will be profitable and historically they
    # have higher average price differences, indicating that they have higher rate of return.
    # Store them using pickle.

    averagePriceSpread = trainPriceDART.mean(axis=0).transpose().to_dict()
    pickle.dump(averagePriceSpread, open("./Training/AveragePriceSpread", 'wb'))

    # Create the training dataset using the function 'createClassifierIO' on the prices and
    # loads, and store them in 'trainX', and 'trainY'.

    trainX, trainY, _ = createClassifierIO(trainPriceDA, trainPriceDART, trainLoadDA)

    # Define a collection of classifiers, one for each option. You can try different options, such
    # as that based on an SVM, logistic regression, multilayer perceptron based, etc. We will
    # measure training accuracy to indicate how well the classifier works on the training dataset.
    # However, good training accuracy does not always indicate good test performance.
    # Avoid over-fitting.


    classifiers = [MLPClassifier(hidden_layer_sizes=(20, 10), max_iter=200)
                   for _ in range(nOptions)]

    trainingAccuracy = 0

    for ii in range(nOptions):
        classifiers[ii].fit(trainX, trainY[:, ii])
        print("Classifier trained for option " + optionNames[ii])
        trainingAccuracy += classifiers[ii].score(trainX, trainY[:, ii])

        # Store the classifier.
        pickle.dump(classifiers[ii], open("./Training/Classifier_" + optionNames[ii], 'wb'))

    print("\nOverall training accuracy = %1.2f percent." % (100 * trainingAccuracy/nOptions))

    del numberOfDays, trainPriceDA, trainLoadDA, trainPriceDART, trainX, trainY
else:

    # Load the classifiers, the offer prices at various quantiles, and the average price spreads.

    print("Loading previously trained variables...\n")
    classifiers = [pickle.load(open("./Training/Classifier_" + optionNames[ii], 'rb'))
                   for ii in range(nOptions)]
    offerPrices = pickle.load(open("./Training/OfferPrices", 'rb'))
    averagePriceSpread = pickle.load(open("./Training/AveragePriceSpread", 'rb'))

    print("All training variables were loaded successfully...\n")
# Out:
# Starting training module...
#
# Loaded hourly prices from 2015 for 365 days.
# Classifier trained for option CAPITL_Hour_0
# Classifier trained for option CAPITL_Hour_1
# Classifier trained for option CAPITL_Hour_2
# Classifier trained for option CAPITL_Hour_3
# Classifier trained for option CAPITL_Hour_4
# Classifier trained for option CAPITL_Hour_5
# Classifier trained for option CAPITL_Hour_6
# Classifier trained for option CAPITL_Hour_7
# Classifier trained for option CAPITL_Hour_8
# Classifier trained for option CAPITL_Hour_9
# Classifier trained for option CAPITL_Hour_10
# Classifier trained for option CAPITL_Hour_11
# Classifier trained for option CAPITL_Hour_12
# Classifier trained for option CAPITL_Hour_13
# Classifier trained for option CAPITL_Hour_14
# Classifier trained for option CAPITL_Hour_15
# Classifier trained for option CAPITL_Hour_16
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option CAPITL_Hour_17
# Classifier trained for option CAPITL_Hour_18
# Classifier trained for option CAPITL_Hour_19
# Classifier trained for option CAPITL_Hour_20
# Classifier trained for option CAPITL_Hour_21
# Classifier trained for option CAPITL_Hour_22
# Classifier trained for option CAPITL_Hour_23
# Classifier trained for option CENTRL_Hour_0
# Classifier trained for option CENTRL_Hour_1
# Classifier trained for option CENTRL_Hour_2
# Classifier trained for option CENTRL_Hour_3
# Classifier trained for option CENTRL_Hour_4
# Classifier trained for option CENTRL_Hour_5
# Classifier trained for option CENTRL_Hour_6
# Classifier trained for option CENTRL_Hour_7
# Classifier trained for option CENTRL_Hour_8
# Classifier trained for option CENTRL_Hour_9
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option CENTRL_Hour_10
# Classifier trained for option CENTRL_Hour_11
# Classifier trained for option CENTRL_Hour_12
# Classifier trained for option CENTRL_Hour_13
# Classifier trained for option CENTRL_Hour_14
# Classifier trained for option CENTRL_Hour_15
# Classifier trained for option CENTRL_Hour_16
# Classifier trained for option CENTRL_Hour_17
# Classifier trained for option CENTRL_Hour_18
# Classifier trained for option CENTRL_Hour_19
# Classifier trained for option CENTRL_Hour_20
# Classifier trained for option CENTRL_Hour_21
# Classifier trained for option CENTRL_Hour_22
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option CENTRL_Hour_23
# Classifier trained for option DUNWOD_Hour_0
# Classifier trained for option DUNWOD_Hour_1
# Classifier trained for option DUNWOD_Hour_2
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option DUNWOD_Hour_3
# Classifier trained for option DUNWOD_Hour_4
# Classifier trained for option DUNWOD_Hour_5
# Classifier trained for option DUNWOD_Hour_6
# Classifier trained for option DUNWOD_Hour_7
# Classifier trained for option DUNWOD_Hour_8
# Classifier trained for option DUNWOD_Hour_9
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option DUNWOD_Hour_10
# Classifier trained for option DUNWOD_Hour_11
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option DUNWOD_Hour_12
# Classifier trained for option DUNWOD_Hour_13
# Classifier trained for option DUNWOD_Hour_14
# Classifier trained for option DUNWOD_Hour_15
# Classifier trained for option DUNWOD_Hour_16
# Classifier trained for option DUNWOD_Hour_17
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option DUNWOD_Hour_18
# Classifier trained for option DUNWOD_Hour_19
# Classifier trained for option DUNWOD_Hour_20
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option DUNWOD_Hour_21
# Classifier trained for option DUNWOD_Hour_22
# Classifier trained for option DUNWOD_Hour_23
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option GENESE_Hour_0
# Classifier trained for option GENESE_Hour_1
# Classifier trained for option GENESE_Hour_2
# Classifier trained for option GENESE_Hour_3
# Classifier trained for option GENESE_Hour_4
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option GENESE_Hour_5
# Classifier trained for option GENESE_Hour_6
# Classifier trained for option GENESE_Hour_7
# Classifier trained for option GENESE_Hour_8
# Classifier trained for option GENESE_Hour_9
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option GENESE_Hour_10
# Classifier trained for option GENESE_Hour_11
# Classifier trained for option GENESE_Hour_12
# Classifier trained for option GENESE_Hour_13
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option GENESE_Hour_14
# Classifier trained for option GENESE_Hour_15
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option GENESE_Hour_16
# Classifier trained for option GENESE_Hour_17
# Classifier trained for option GENESE_Hour_18
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option GENESE_Hour_19
# Classifier trained for option GENESE_Hour_20
# Classifier trained for option GENESE_Hour_21
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option GENESE_Hour_22
# Classifier trained for option GENESE_Hour_23
# Classifier trained for option HUD VL_Hour_0
# Classifier trained for option HUD VL_Hour_1
# Classifier trained for option HUD VL_Hour_2
# Classifier trained for option HUD VL_Hour_3
# Classifier trained for option HUD VL_Hour_4
# Classifier trained for option HUD VL_Hour_5
# Classifier trained for option HUD VL_Hour_6
# Classifier trained for option HUD VL_Hour_7
# Classifier trained for option HUD VL_Hour_8
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option HUD VL_Hour_9
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option HUD VL_Hour_10
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option HUD VL_Hour_11
# Classifier trained for option HUD VL_Hour_12
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option HUD VL_Hour_13
# Classifier trained for option HUD VL_Hour_14
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option HUD VL_Hour_15
# Classifier trained for option HUD VL_Hour_16
# Classifier trained for option HUD VL_Hour_17
# Classifier trained for option HUD VL_Hour_18
# Classifier trained for option HUD VL_Hour_19
# Classifier trained for option HUD VL_Hour_20
# Classifier trained for option HUD VL_Hour_21
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option HUD VL_Hour_22
# Classifier trained for option HUD VL_Hour_23
# Classifier trained for option LONGIL_Hour_0
# Classifier trained for option LONGIL_Hour_1
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option LONGIL_Hour_2
# Classifier trained for option LONGIL_Hour_3
# Classifier trained for option LONGIL_Hour_4
# Classifier trained for option LONGIL_Hour_5
# Classifier trained for option LONGIL_Hour_6
# Classifier trained for option LONGIL_Hour_7
# Classifier trained for option LONGIL_Hour_8
# Classifier trained for option LONGIL_Hour_9
# Classifier trained for option LONGIL_Hour_10
# Classifier trained for option LONGIL_Hour_11
# Classifier trained for option LONGIL_Hour_12
# Classifier trained for option LONGIL_Hour_13
# Classifier trained for option LONGIL_Hour_14
# Classifier trained for option LONGIL_Hour_15
# Classifier trained for option LONGIL_Hour_16
# Classifier trained for option LONGIL_Hour_17
# Classifier trained for option LONGIL_Hour_18
# Classifier trained for option LONGIL_Hour_19
# Classifier trained for option LONGIL_Hour_20
# Classifier trained for option LONGIL_Hour_21
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option LONGIL_Hour_22
# Classifier trained for option LONGIL_Hour_23
# Classifier trained for option MHK VL_Hour_0
# Classifier trained for option MHK VL_Hour_1
# Classifier trained for option MHK VL_Hour_2
# Classifier trained for option MHK VL_Hour_3
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MHK VL_Hour_4
# Classifier trained for option MHK VL_Hour_5
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MHK VL_Hour_6
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MHK VL_Hour_7
# Classifier trained for option MHK VL_Hour_8
# Classifier trained for option MHK VL_Hour_9
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MHK VL_Hour_10
# Classifier trained for option MHK VL_Hour_11
# Classifier trained for option MHK VL_Hour_12
# Classifier trained for option MHK VL_Hour_13
# Classifier trained for option MHK VL_Hour_14
# Classifier trained for option MHK VL_Hour_15
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MHK VL_Hour_16
# Classifier trained for option MHK VL_Hour_17
# Classifier trained for option MHK VL_Hour_18
# Classifier trained for option MHK VL_Hour_19
# Classifier trained for option MHK VL_Hour_20
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MHK VL_Hour_21
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MHK VL_Hour_22
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MHK VL_Hour_23
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MILLWD_Hour_0
# Classifier trained for option MILLWD_Hour_1
# Classifier trained for option MILLWD_Hour_2
# Classifier trained for option MILLWD_Hour_3
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MILLWD_Hour_4
# Classifier trained for option MILLWD_Hour_5
# Classifier trained for option MILLWD_Hour_6
# Classifier trained for option MILLWD_Hour_7
# Classifier trained for option MILLWD_Hour_8
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MILLWD_Hour_9
# Classifier trained for option MILLWD_Hour_10
# Classifier trained for option MILLWD_Hour_11
# Classifier trained for option MILLWD_Hour_12
# Classifier trained for option MILLWD_Hour_13
# Classifier trained for option MILLWD_Hour_14
# Classifier trained for option MILLWD_Hour_15
# Classifier trained for option MILLWD_Hour_16
# Classifier trained for option MILLWD_Hour_17
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MILLWD_Hour_18
# Classifier trained for option MILLWD_Hour_19
# Classifier trained for option MILLWD_Hour_20
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option MILLWD_Hour_21
# Classifier trained for option MILLWD_Hour_22
# Classifier trained for option MILLWD_Hour_23
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option N.Y.C._Hour_0
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option N.Y.C._Hour_1
# Classifier trained for option N.Y.C._Hour_2
# Classifier trained for option N.Y.C._Hour_3
# Classifier trained for option N.Y.C._Hour_4
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option N.Y.C._Hour_5
# Classifier trained for option N.Y.C._Hour_6
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option N.Y.C._Hour_7
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option N.Y.C._Hour_8
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option N.Y.C._Hour_9
# Classifier trained for option N.Y.C._Hour_10
# Classifier trained for option N.Y.C._Hour_11
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option N.Y.C._Hour_12
# Classifier trained for option N.Y.C._Hour_13
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option N.Y.C._Hour_14
# Classifier trained for option N.Y.C._Hour_15
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option N.Y.C._Hour_16
# Classifier trained for option N.Y.C._Hour_17
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option N.Y.C._Hour_18
# Classifier trained for option N.Y.C._Hour_19
# Classifier trained for option N.Y.C._Hour_20
# Classifier trained for option N.Y.C._Hour_21
# Classifier trained for option N.Y.C._Hour_22
# Classifier trained for option N.Y.C._Hour_23
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option NORTH_Hour_0
# Classifier trained for option NORTH_Hour_1
# Classifier trained for option NORTH_Hour_2
# Classifier trained for option NORTH_Hour_3
# Classifier trained for option NORTH_Hour_4
# Classifier trained for option NORTH_Hour_5
# Classifier trained for option NORTH_Hour_6
# Classifier trained for option NORTH_Hour_7
# Classifier trained for option NORTH_Hour_8
# Classifier trained for option NORTH_Hour_9
# Classifier trained for option NORTH_Hour_10
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option NORTH_Hour_11
# Classifier trained for option NORTH_Hour_12
# Classifier trained for option NORTH_Hour_13
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option NORTH_Hour_14
# Classifier trained for option NORTH_Hour_15
# Classifier trained for option NORTH_Hour_16
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option NORTH_Hour_17
# Classifier trained for option NORTH_Hour_18
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option NORTH_Hour_19
# Classifier trained for option NORTH_Hour_20
# Classifier trained for option NORTH_Hour_21
# Classifier trained for option NORTH_Hour_22
# Classifier trained for option NORTH_Hour_23
# Classifier trained for option WEST_Hour_0
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option WEST_Hour_1
# Classifier trained for option WEST_Hour_2
# Classifier trained for option WEST_Hour_3
# Classifier trained for option WEST_Hour_4
# Classifier trained for option WEST_Hour_5
# Classifier trained for option WEST_Hour_6
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option WEST_Hour_7
# Classifier trained for option WEST_Hour_8
# Classifier trained for option WEST_Hour_9
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option WEST_Hour_10
# Classifier trained for option WEST_Hour_11
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option WEST_Hour_12
# Classifier trained for option WEST_Hour_13
# Classifier trained for option WEST_Hour_14
# Classifier trained for option WEST_Hour_15
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option WEST_Hour_16
# Classifier trained for option WEST_Hour_17
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option WEST_Hour_18
# Classifier trained for option WEST_Hour_19
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Classifier trained for option WEST_Hour_20
# Classifier trained for option WEST_Hour_21
# Classifier trained for option WEST_Hour_22
# Classifier trained for option WEST_Hour_23
#
# Overall training accuracy = 99.94 percent.

# %% [markdown]
# ### Test the classifier's accuracy on test data.

# %%
# First, load the test data from NYISO for the year 2016. Again, utilize our function
# named 'loadNYISOData'.

print("Starting the testing module...\n")
testPriceDA, testPriceDART, testLoadDA = loadNYISOData(2016)

# Create the data for the classifier using the function 'createClassifierIO'.
testX, testY, rangeOfDays = createClassifierIO(testPriceDA, testPriceDART, testLoadDA)

# The next step is not useful for implementing the trading strategy, but quickly check how accurate
# your trained classifiers are for the test data. Training accuracy is not always indicative of
# test accuracy.

testingAccuracy = [classifiers[ii].score(testX, testY[:, ii]) for ii in range(nOptions)]
print("Test Accuracy Stats: Min = %.2f%%, Avg = %.2f%%, Max = %.2f%%" %
      (100 * np.min(testingAccuracy),
       100 * np.mean(testingAccuracy),
       100 * np.max(testingAccuracy)))

# Utilize the classifiers to predict the sign of DA - RT prices for each day in 'rangeOfDays' for
# the test data. Store the result in a pandas data frame with columns as the option names and the
# day in year as index.
predictedY = pd.DataFrame(np.column_stack([classifiers[ii].predict(testX) for ii in range(nOptions)]),
                          columns=optionNames, index=rangeOfDays)
# Out:
# Starting the testing module...
#
# Test Accuracy Stats: Min = 48.76%, Avg = 59.02%, Max = 70.80%

# %% [markdown]
# ## Design and implement the trading strategy.
#
# We define a fairly simple trading strategy. Define a total budget that you are willing to spend in the DA market. Recall that we only invest in
# options where we buy at the DA market and sell at the RT market. When your bid for one unit of an option
# clears in the DA market, you have to pay the DA price for that option. There are two possibilities:
#   1. Your bid clears: Therefore, your offer price was higher than the DA price.
#   2. Your bid does not clear: Then, the DA price was higher than your bid.
# In both these cases, the maximum you have to pay is your bid. Therefore, we will enforce that your bids
# across all options in a day does not exceed your total budget.
# Keep track of how rewards grow (or fall) through the year
# as you utilize your strategy. Also, keep track of how much rewards you get from each option. We shall
# visualize these results after implementing the trading strategy over the NYISO data for 2016.
#
# Choose the bid prices as a suitable quantile of the historical DA prices. The higher the quantile, the
# better your chances are that your bid will be cleared. However, a higher quantile also indicates that
# you are budgeting more money for each option, and hence, you will buy fewer options.

# %%
dailyBudget = 250000
quantileOffer =0.8

# Keep track of your rewards in each day, a cumulative reward over the year, and a total reward over the
# year. Also, keep track of the total reward from each option. Store them as dictionaries that are
# indexed by day of the year.
reward = {}
cumulativeReward = {}
totalReward = 0
optionReturn = dict((option, 0) for option in optionNames)

# Implement the trading strategy on each day!

for day in rangeOfDays:

    reward[day] = 0

    # Find the options that your classifier says that should be profitable. Store the profitable option
    # names in chosenOptions.
    chosenOptionNumbers = np.ravel(list(np.nonzero(predictedY.loc[day].values)))
    if np.size(chosenOptionNumbers) == 0:
        continue
    chosenOptions = [optionNames[i] for i in chosenOptionNumbers]

    # Design the portfolio based on average price spreads. Our strategy is that as long as you have not
    # exceeded your daily budget, pick an option from the list of 'chosenOptions' probabilistically, where
    # the probability of choosing it is proportional to exponential(historical rewards of that option). That
    # is, a historically profitable option is chosen more often than one that is not. Keep sampling and
    # decreasing your budget with each bid.

    # Start with an empty portfolio.

    portfolio = dict((option, 0) for option in chosenOptions)

    # Calculate the probabilities of choosing each option among the list 'chosenOptions'. Recall that
    # 'chosenOptions' contains the options that your classifier indicates as being profitable.
    priceSpreads = [1.0 * averagePriceSpread[option] for option in chosenOptions]
    probabilityOptions = [np.exp(p) for p in priceSpreads]
    probabilityOptions /= np.sum(probabilityOptions)

    # Start with your daily budget.
    budget = dailyBudget

    # Sampling among the profitable options and bid based on them.
    while budget > np.median([offerPrices[quantileOffer][option] for option in chosenOptions]):

        optionToBuy = choice(chosenOptions, p=probabilityOptions)

        if budget >= offerPrices[quantileOffer][optionToBuy]:
            portfolio[optionToBuy] += 1
            budget -= offerPrices[quantileOffer][optionToBuy]

    # Compute the reward from the day. Go through each of the options you have decided to buy.
    # If the DA price is lower than the bid price, then your bid is cleared. For each option you
    # have bought, you get a reward equal to the DA - RT price.

    for option in chosenOptions:
        if testPriceDA.at[day, option] < offerPrices[quantileOffer][option]:
            rewardOptionDay = testPriceDART.at[day, option] * portfolio[option]
            optionReturn[option] += rewardOptionDay
            reward[day] += rewardOptionDay

    totalReward += reward[day]

    # Calculate the cumulative reward in millions of dollars.
    cumulativeReward[day] = totalReward/1000000

    print("Day " + str(day) + ": Reward (in $) = " + "{0:,.0f}".format(reward[day]))

print("Total money earned over the year (in $) = " + "{0:,.0f}".format(totalReward))
# Out:
# Day 3: Reward (in $) = -84,518
# Day 4: Reward (in $) = 1,537,656
# Day 5: Reward (in $) = 4,594
# Day 6: Reward (in $) = -24,414
# Day 7: Reward (in $) = -22,944
# Day 8: Reward (in $) = 23,172
# Day 9: Reward (in $) = -15,484
# Day 10: Reward (in $) = -112,020
# Day 11: Reward (in $) = -78,105
# Day 12: Reward (in $) = -53,219
# Day 13: Reward (in $) = -18,144
# Day 14: Reward (in $) = -19,660
# Day 15: Reward (in $) = -608
# Day 16: Reward (in $) = 37,676
# Day 17: Reward (in $) = -64,691
# Day 18: Reward (in $) = -26,029
# Day 19: Reward (in $) = 22,098
# Day 20: Reward (in $) = -12,769
# Day 21: Reward (in $) = -20,516
# Day 22: Reward (in $) = 85,685
# Day 23: Reward (in $) = 32,472
# Day 24: Reward (in $) = -75,394
# Day 25: Reward (in $) = -75,704
# Day 26: Reward (in $) = -20,113
# Day 27: Reward (in $) = -7,776
# Day 28: Reward (in $) = -12,362
# Day 29: Reward (in $) = -32,296
# Day 30: Reward (in $) = -75,683
# Day 31: Reward (in $) = -23,200
# Day 32: Reward (in $) = -8,336
# Day 33: Reward (in $) = -198,109
# Day 34: Reward (in $) = -15,657
# Day 35: Reward (in $) = 6,369
# Day 36: Reward (in $) = -36,010
# Day 37: Reward (in $) = -40,425
# Day 38: Reward (in $) = 6,721
# Day 39: Reward (in $) = 4,217
# Day 40: Reward (in $) = -37,159
# Day 41: Reward (in $) = -42,013
# Day 42: Reward (in $) = -10,080
# Day 43: Reward (in $) = -51,450
# Day 44: Reward (in $) = -33,948
# Day 45: Reward (in $) = -13,137
# Day 46: Reward (in $) = 93,883
# Day 47: Reward (in $) = -236
# Day 48: Reward (in $) = -59,250
# Day 49: Reward (in $) = -59,673
# Day 50: Reward (in $) = -48,283
# Day 51: Reward (in $) = 9,172
# Day 52: Reward (in $) = -19,618
# Day 53: Reward (in $) = -15,448
# Day 54: Reward (in $) = 4,241
# Day 55: Reward (in $) = -3,106
# Day 56: Reward (in $) = -43,698
# Day 57: Reward (in $) = -28,229
# Day 58: Reward (in $) = -14,574
# Day 59: Reward (in $) = -14,874
# Day 60: Reward (in $) = -69,175
# Day 61: Reward (in $) = -1,059
# Day 62: Reward (in $) = -7,812
# Day 63: Reward (in $) = -26,612
# Day 64: Reward (in $) = 17,781
# Day 65: Reward (in $) = 8,518
# Day 66: Reward (in $) = 83,988
# Day 67: Reward (in $) = -105,188
# Day 68: Reward (in $) = -30,592
# Day 69: Reward (in $) = -32,191
# Day 70: Reward (in $) = 18,821
# Day 71: Reward (in $) = -6,768
# Day 72: Reward (in $) = -13,222
# Day 73: Reward (in $) = -110,430
# Day 74: Reward (in $) = 752,105
# Day 75: Reward (in $) = -15,466
# Day 76: Reward (in $) = -108,154
# Day 77: Reward (in $) = -5,220
# Day 78: Reward (in $) = -27,806
# Day 79: Reward (in $) = -26,850
# Day 80: Reward (in $) = -66,829
# Day 81: Reward (in $) = -17,634
# Day 82: Reward (in $) = 34,991
# Day 83: Reward (in $) = -16,332
# Day 84: Reward (in $) = -8,170
# Day 85: Reward (in $) = 24,612
# Day 86: Reward (in $) = -27,301
# Day 87: Reward (in $) = 2,805,209
# Day 88: Reward (in $) = 690,801
# Day 89: Reward (in $) = -24,141
# Day 90: Reward (in $) = -30,640
# Day 91: Reward (in $) = -7,080
# Day 92: Reward (in $) = -22,158
# Day 93: Reward (in $) = 7,887
# Day 94: Reward (in $) = 59,731
# Day 95: Reward (in $) = -30,711
# Day 96: Reward (in $) = 74,107
# Day 97: Reward (in $) = 15,178
# Day 98: Reward (in $) = 52
# Day 99: Reward (in $) = -6,734
# Day 100: Reward (in $) = -5,329
# Day 101: Reward (in $) = -71,457
# Day 102: Reward (in $) = -30,429
# Day 103: Reward (in $) = 127,719
# Day 104: Reward (in $) = -66,340
# Day 105: Reward (in $) = -39,391
# Day 106: Reward (in $) = 11,539
# Day 107: Reward (in $) = -18,892
# Day 108: Reward (in $) = 15,868
# Day 109: Reward (in $) = -29,991
# Day 110: Reward (in $) = -310
# Day 111: Reward (in $) = -51,148
# Day 112: Reward (in $) = 137,062
# Day 113: Reward (in $) = -44,717
# Day 114: Reward (in $) = -56,533
# Day 115: Reward (in $) = -26,446
# Day 116: Reward (in $) = 25,908
# Day 117: Reward (in $) = -16,908
# Day 118: Reward (in $) = 8,118
# Day 119: Reward (in $) = -744
# Day 120: Reward (in $) = 1,253
# Day 121: Reward (in $) = 53,363
# Day 122: Reward (in $) = -31,897
# Day 123: Reward (in $) = -490
# Day 124: Reward (in $) = 5,492
# Day 125: Reward (in $) = -9,547
# Day 126: Reward (in $) = -74,916
# Day 127: Reward (in $) = -39,118
# Day 128: Reward (in $) = -54,223
# Day 129: Reward (in $) = -73,149
# Day 130: Reward (in $) = -36,797
# Day 131: Reward (in $) = 18,199
# Day 132: Reward (in $) = 169,711
# Day 133: Reward (in $) = 27,588
# Day 134: Reward (in $) = -49,399
# Day 135: Reward (in $) = -20,031
# Day 136: Reward (in $) = -34,947
# Day 137: Reward (in $) = -39,617
# Day 138: Reward (in $) = -99,480
# Day 139: Reward (in $) = 1,202
# Day 140: Reward (in $) = -45,577
# Day 141: Reward (in $) = 21,733
# Day 142: Reward (in $) = 24,257
# Day 143: Reward (in $) = 5,152
# Day 144: Reward (in $) = -22,612
# Day 145: Reward (in $) = -53,950
# Day 146: Reward (in $) = -20,361
# Day 147: Reward (in $) = -69,187
# Day 148: Reward (in $) = 374,847
# Day 149: Reward (in $) = 91,086
# Day 150: Reward (in $) = 48,147
# Day 151: Reward (in $) = 532,593
# Day 152: Reward (in $) = 515,125
# Day 153: Reward (in $) = 196,146
# Day 154: Reward (in $) = 28,632
# Day 155: Reward (in $) = -43,253
# Day 156: Reward (in $) = -39,732
# Day 157: Reward (in $) = -130,296
# Day 158: Reward (in $) = -12,037
# Day 159: Reward (in $) = -51,877
# Day 160: Reward (in $) = -130,430
# Day 161: Reward (in $) = -1,811
# Day 162: Reward (in $) = 171,788
# Day 163: Reward (in $) = -13,609
# Day 164: Reward (in $) = -66,580
# Day 165: Reward (in $) = 481,445
# Day 166: Reward (in $) = -27,130
# Day 167: Reward (in $) = 22,717
# Day 168: Reward (in $) = -1,380
# Day 169: Reward (in $) = 6,706
# Day 170: Reward (in $) = -41,473
# Day 171: Reward (in $) = -3,630
# Day 172: Reward (in $) = -6,947
# Day 173: Reward (in $) = 179,532
# Day 174: Reward (in $) = -9,650
# Day 175: Reward (in $) = 37,417
# Day 176: Reward (in $) = -26,715
# Day 177: Reward (in $) = -39,599
# Day 178: Reward (in $) = -13,757
# Day 179: Reward (in $) = -42,759
# Day 180: Reward (in $) = -19,663
# Day 181: Reward (in $) = -22,004
# Day 182: Reward (in $) = -52,058
# Day 183: Reward (in $) = -83,325
# Day 184: Reward (in $) = -79,410
# Day 185: Reward (in $) = -32,373
# Day 186: Reward (in $) = 98,414
# Day 187: Reward (in $) = 6,848
# Day 188: Reward (in $) = 3,048
# Day 189: Reward (in $) = -1,054
# Day 190: Reward (in $) = -102,290
# Day 191: Reward (in $) = -17,770
# Day 192: Reward (in $) = -30,737
# Day 193: Reward (in $) = -26,940
# Day 194: Reward (in $) = -2,089
# Day 195: Reward (in $) = 2,576
# Day 196: Reward (in $) = 6,900
# Day 197: Reward (in $) = 7,583
# Day 198: Reward (in $) = -11,861
# Day 199: Reward (in $) = -1,556
# Day 200: Reward (in $) = -99,558
# Day 201: Reward (in $) = -15,709
# Day 202: Reward (in $) = 1,665
# Day 203: Reward (in $) = 1,003
# Day 204: Reward (in $) = -11,819
# Day 205: Reward (in $) = -31,416
# Day 206: Reward (in $) = -2,556
# Day 207: Reward (in $) = -4,528
# Day 208: Reward (in $) = 1,755
# Day 209: Reward (in $) = 5,982
# Day 210: Reward (in $) = 111,332
# Day 211: Reward (in $) = 44,714
# Day 212: Reward (in $) = 100,221
# Day 213: Reward (in $) = -380
# Day 214: Reward (in $) = -87,746
# Day 215: Reward (in $) = -47,019
# Day 216: Reward (in $) = 6,135
# Day 217: Reward (in $) = 3,541
# Day 218: Reward (in $) = 26,910
# Day 219: Reward (in $) = -24,080
# Day 220: Reward (in $) = -2,686
# Day 221: Reward (in $) = -30,047
# Day 222: Reward (in $) = 18,266
# Day 223: Reward (in $) = 9,699
# Day 224: Reward (in $) = -49
# Day 225: Reward (in $) = 3,453
# Day 226: Reward (in $) = -21,829
# Day 227: Reward (in $) = -1,552
# Day 228: Reward (in $) = 171,689
# Day 229: Reward (in $) = -1,651
# Day 230: Reward (in $) = -2,979
# Day 231: Reward (in $) = 1,217
# Day 232: Reward (in $) = -45,532
# Day 233: Reward (in $) = -91,494
# Day 234: Reward (in $) = -94,926
# Day 235: Reward (in $) = -129,937
# Day 236: Reward (in $) = 26,061
# Day 237: Reward (in $) = 51,989
# Day 238: Reward (in $) = -1,207
# Day 239: Reward (in $) = -5,287
# Day 240: Reward (in $) = -6,227
# Day 241: Reward (in $) = -661
# Day 242: Reward (in $) = 53,153
# Day 243: Reward (in $) = -3,063
# Day 244: Reward (in $) = -3,511
# Day 245: Reward (in $) = -81,039
# Day 246: Reward (in $) = -51,434
# Day 247: Reward (in $) = -15,071
# Day 248: Reward (in $) = -32,558
# Day 249: Reward (in $) = -4,222
# Day 250: Reward (in $) = -20,518
# Day 251: Reward (in $) = 1,040
# Day 252: Reward (in $) = 4,368
# Day 253: Reward (in $) = 207,496
# Day 254: Reward (in $) = -12,343
# Day 255: Reward (in $) = -6,654
# Day 256: Reward (in $) = -4,298
# Day 257: Reward (in $) = -3,966
# Day 258: Reward (in $) = -23,444
# Day 259: Reward (in $) = -43,437
# Day 260: Reward (in $) = -19,560
# Day 261: Reward (in $) = 25,967
# Day 262: Reward (in $) = 151
# Day 263: Reward (in $) = -60,669
# Day 264: Reward (in $) = -40,241
# Day 265: Reward (in $) = -46,293
# Day 266: Reward (in $) = -68,855
# Day 267: Reward (in $) = -8,547
# Day 268: Reward (in $) = -24,275
# Day 269: Reward (in $) = -83,722
# Day 270: Reward (in $) = -77,886
# Day 271: Reward (in $) = -7,054
# Day 272: Reward (in $) = -34,080
# Day 273: Reward (in $) = -32,408
# Day 274: Reward (in $) = 18,692
# Day 275: Reward (in $) = 23,389
# Day 276: Reward (in $) = -7,202
# Day 277: Reward (in $) = 59,755
# Day 278: Reward (in $) = 165,880
# Day 279: Reward (in $) = -37,154
# Day 280: Reward (in $) = 11,175
# Day 281: Reward (in $) = -11,687
# Day 282: Reward (in $) = -201
# Day 283: Reward (in $) = -2,470
# Day 284: Reward (in $) = 20,967
# Day 285: Reward (in $) = -59,346
# Day 286: Reward (in $) = -62,160
# Day 287: Reward (in $) = -43,753
# Day 288: Reward (in $) = 12,635
# Day 289: Reward (in $) = 22,185
# Day 290: Reward (in $) = 6,360
# Day 291: Reward (in $) = -10,047
# Day 292: Reward (in $) = -2,683
# Day 293: Reward (in $) = -33,990
# Day 294: Reward (in $) = -24,786
# Day 295: Reward (in $) = -12,298
# Day 296: Reward (in $) = -63,668
# Day 297: Reward (in $) = -39,688
# Day 298: Reward (in $) = -15,372
# Day 299: Reward (in $) = -55,716
# Day 300: Reward (in $) = -28,555
# Day 301: Reward (in $) = -8,520
# Day 302: Reward (in $) = -6,155
# Day 303: Reward (in $) = -18
# Day 304: Reward (in $) = -53,475
# Day 305: Reward (in $) = -15,812
# Day 306: Reward (in $) = 149,050
# Day 307: Reward (in $) = 177,636
# Day 308: Reward (in $) = -49,006
# Day 309: Reward (in $) = 46,669
# Day 310: Reward (in $) = -5,354
# Day 311: Reward (in $) = 8,834
# Day 312: Reward (in $) = 42,238
# Day 313: Reward (in $) = -16,226
# Day 314: Reward (in $) = -32,142
# Day 315: Reward (in $) = -58,402
# Day 316: Reward (in $) = -25,312
# Day 317: Reward (in $) = -30,702
# Day 318: Reward (in $) = -11,681
# Day 319: Reward (in $) = 2,893
# Day 320: Reward (in $) = 12,663
# Day 321: Reward (in $) = 11,918
# Day 322: Reward (in $) = 1,549
# Day 323: Reward (in $) = 7,493
# Day 324: Reward (in $) = 15,640
# Day 325: Reward (in $) = -26,043
# Day 326: Reward (in $) = -11,116
# Day 327: Reward (in $) = 27,482
# Day 328: Reward (in $) = 138,208
# Day 329: Reward (in $) = 34,671
# Day 330: Reward (in $) = 5,608
# Day 331: Reward (in $) = -8,525
# Day 332: Reward (in $) = -61,952
# Day 333: Reward (in $) = -69,155
# Day 334: Reward (in $) = -8,803
# Day 335: Reward (in $) = -21,234
# Day 336: Reward (in $) = -16,808
# Day 337: Reward (in $) = 30,933
# Day 338: Reward (in $) = -10,424
# Day 339: Reward (in $) = -30,681
# Day 340: Reward (in $) = 11
# Day 341: Reward (in $) = -36,420
# Day 342: Reward (in $) = -21,283
# Day 343: Reward (in $) = -18,304
# Day 344: Reward (in $) = 278,188
# Day 345: Reward (in $) = 95,421
# Day 346: Reward (in $) = 1,987
# Day 347: Reward (in $) = 27,154
# Day 348: Reward (in $) = -57,760
# Day 349: Reward (in $) = 41,116
# Day 350: Reward (in $) = -3,636
# Day 351: Reward (in $) = 269,016
# Day 352: Reward (in $) = -13,726
# Day 353: Reward (in $) = -11,705
# Day 354: Reward (in $) = -41,076
# Day 355: Reward (in $) = 2,946
# Day 356: Reward (in $) = -37,991
# Day 357: Reward (in $) = -53,083
# Day 358: Reward (in $) = -29,087
# Day 359: Reward (in $) = -14,417
# Day 360: Reward (in $) = -55,329
# Day 361: Reward (in $) = -82,214
# Day 362: Reward (in $) = 17,084
# Day 363: Reward (in $) = -51,075
# Day 364: Reward (in $) = -33,671
# Day 365: Reward (in $) = -26,542
# Total money earned over the year (in $) = 4,414,066

# %% [markdown]
# ### Task1:  Visualize the rewards (25 points)
#
# We would like to plot the cumulative reward over the year 2016. By cumulative reward on a particular date, we mean the total reward from the start of the year till that date.
#
# Also, plot a heat map of the returns from each option.
#
# #### Fill in the missing lines below.

# %%
# Plot the cumulative reward over the year 2016. Also, plot a heat map of the returns from
# each option.

fig, axs = plt.subplots(2, 1, tight_layout=True)
axs = axs.ravel()


## Enter code here where you plot in axs[0].
axs[0] = plt.plot(cumulativeReward.keys(), cumulativeReward.values())
plt.title('Cumulative Reward over the year 2016')
plt.xlabel('Days')
plt.ylabel('Cumulative Reward')
plt.show()


axs[1] = sns.heatmap(np.reshape(list(optionReturn.values()), (len(listOfZones), 24)),
                     linewidth=0.5,
                     cmap="YlGnBu")
axs[1].set_yticklabels(listOfZones, rotation=0)
axs[1].set_xticklabels(range(24), rotation=90)
axs[1].set_title('Returns on different options')
plt.show()

# %% [markdown]
# ### Task 2: Choosing a classifier (25 points)
#
# We used a multilayer perceptron classifier. Your task is to try out SVM and logistic regression classifiers, and explore which one leads to more profits. Use the relevant functions from 'sklearn'.
#
# #### (comments here, add a new code cell below)
#
# NN Profits: $4,414,066
#
# SVM Profits: $1,567,256
#
# Logistic Regression Profit: $3,103,216
#
# I have used the same codes above and manipulate the classifier to figure out which one gives more profit and found out that Logistic Regression profits yields more profit.

# %%
classifiers = []

# We have two options here. Use previous training experience, or learn anew.
useSavedClassifiers = False

if not useSavedClassifiers:

    print("Starting training module...\n")
    trainPriceDA, trainPriceDART, trainLoadDA = loadNYISOData(2015)

    numberOfDays =  int(len(trainPriceDA.index))
    print("Loaded hourly prices from 2015 for %d days." % numberOfDays)

    # We will implement a trading strategy, where we bid a particular quantile of the past
    # DA prices for an option. If you do not know what a quantile means, refer to the Wikipedia
    # article on it. Essentially, a 95% quantile of the DA prices equals that value for which
    # 95% of the DA prices are below it. Store all quantiles starting from 50% in steps of
    # 5% in a dictionary. Store them in a pickle file.

    quantilesToStore = [0.70, 0.75, 0.80, 0.85, 0.90, 0.95]
    offerPrices = trainPriceDA.quantile(q=quantilesToStore).transpose().to_dict()
    pickle.dump(offerPrices, open("./Training/OfferPrices", 'wb'))

    # Calculate the average price spread for each option over the entire year. This will guide
    # us in choosing our portfolio. Store it as a dictionary. Our bid will choose those
    # options that our classifier indicates that they will be profitable and historically they
    # have higher average price differences, indicating that they have higher rate of return.
    # Store them using pickle.

    averagePriceSpread = trainPriceDART.mean(axis=0).transpose().to_dict()
    pickle.dump(averagePriceSpread, open("./Training/AveragePriceSpread", 'wb'))

    # Create the training dataset using the function 'createClassifierIO' on the prices and
    # loads, and store them in 'trainX', and 'trainY'.

    trainX, trainY, _ = createClassifierIO(trainPriceDA, trainPriceDART, trainLoadDA)

    # Define a collection of classifiers, one for each option. You can try different options, such
    # as that based on an SVM, logistic regression, multilayer perceptron based, etc. We will
    # measure training accuracy to indicate how well the classifier works on the training dataset.
    # However, good training accuracy does not always indicate good test performance.
    # Avoid over-fitting.


    classifiers = [LogisticRegression(C=0.9, max_iter=400, solver='liblinear')
                   for _ in range(nOptions)]

    trainingAccuracy = 0

    for ii in range(nOptions):
        classifiers[ii].fit(trainX, trainY[:, ii])
        print("Classifier trained for option " + optionNames[ii])
        trainingAccuracy += classifiers[ii].score(trainX, trainY[:, ii])

        # Store the classifier.
        pickle.dump(classifiers[ii], open("./Training/Classifier_" + optionNames[ii], 'wb'))

    print("\nOverall training accuracy = %1.2f percent." % (100 * trainingAccuracy/nOptions))

    del numberOfDays, trainPriceDA, trainLoadDA, trainPriceDART, trainX, trainY
else:

    # Load the classifiers, the offer prices at various quantiles, and the average price spreads.

    print("Loading previously trained variables...\n")
    classifiers = [pickle.load(open("./Training/Classifier_" + optionNames[ii], 'rb'))
                   for ii in range(nOptions)]
    offerPrices = pickle.load(open("./Training/OfferPrices", 'rb'))
    averagePriceSpread = pickle.load(open("./Training/AveragePriceSpread", 'rb'))

    print("All training variables were loaded successfully...\n")
# Out:
# Starting training module...
#
# Loaded hourly prices from 2015 for 365 days.
# Classifier trained for option CAPITL_Hour_0
# Classifier trained for option CAPITL_Hour_1
# Classifier trained for option CAPITL_Hour_2
# Classifier trained for option CAPITL_Hour_3
# Classifier trained for option CAPITL_Hour_4
# Classifier trained for option CAPITL_Hour_5
# Classifier trained for option CAPITL_Hour_6
# Classifier trained for option CAPITL_Hour_7
# Classifier trained for option CAPITL_Hour_8
# Classifier trained for option CAPITL_Hour_9
# Classifier trained for option CAPITL_Hour_10
# Classifier trained for option CAPITL_Hour_11
# Classifier trained for option CAPITL_Hour_12
# Classifier trained for option CAPITL_Hour_13
# Classifier trained for option CAPITL_Hour_14
# Classifier trained for option CAPITL_Hour_15
# Classifier trained for option CAPITL_Hour_16
# Classifier trained for option CAPITL_Hour_17
# Classifier trained for option CAPITL_Hour_18
# Classifier trained for option CAPITL_Hour_19
# Classifier trained for option CAPITL_Hour_20
# Classifier trained for option CAPITL_Hour_21
# Classifier trained for option CAPITL_Hour_22
# Classifier trained for option CAPITL_Hour_23
# Classifier trained for option CENTRL_Hour_0
# Classifier trained for option CENTRL_Hour_1
# Classifier trained for option CENTRL_Hour_2
# Classifier trained for option CENTRL_Hour_3
# Classifier trained for option CENTRL_Hour_4
# Classifier trained for option CENTRL_Hour_5
# Classifier trained for option CENTRL_Hour_6
# Classifier trained for option CENTRL_Hour_7
# Classifier trained for option CENTRL_Hour_8
# Classifier trained for option CENTRL_Hour_9
# Classifier trained for option CENTRL_Hour_10
# Classifier trained for option CENTRL_Hour_11
# Classifier trained for option CENTRL_Hour_12
# Classifier trained for option CENTRL_Hour_13
# Classifier trained for option CENTRL_Hour_14
# Classifier trained for option CENTRL_Hour_15
# Classifier trained for option CENTRL_Hour_16
# Classifier trained for option CENTRL_Hour_17
# Classifier trained for option CENTRL_Hour_18
# Classifier trained for option CENTRL_Hour_19
# Classifier trained for option CENTRL_Hour_20
# Classifier trained for option CENTRL_Hour_21
# Classifier trained for option CENTRL_Hour_22
# Classifier trained for option CENTRL_Hour_23
# Classifier trained for option DUNWOD_Hour_0
# Classifier trained for option DUNWOD_Hour_1
# Classifier trained for option DUNWOD_Hour_2
# Classifier trained for option DUNWOD_Hour_3
# Classifier trained for option DUNWOD_Hour_4
# Classifier trained for option DUNWOD_Hour_5
# Classifier trained for option DUNWOD_Hour_6
# Classifier trained for option DUNWOD_Hour_7
# Classifier trained for option DUNWOD_Hour_8
# Classifier trained for option DUNWOD_Hour_9
# Classifier trained for option DUNWOD_Hour_10
# Classifier trained for option DUNWOD_Hour_11
# Classifier trained for option DUNWOD_Hour_12
# Classifier trained for option DUNWOD_Hour_13
# Classifier trained for option DUNWOD_Hour_14
# Classifier trained for option DUNWOD_Hour_15
# Classifier trained for option DUNWOD_Hour_16
# Classifier trained for option DUNWOD_Hour_17
# Classifier trained for option DUNWOD_Hour_18
# Classifier trained for option DUNWOD_Hour_19
# Classifier trained for option DUNWOD_Hour_20
# Classifier trained for option DUNWOD_Hour_21
# Classifier trained for option DUNWOD_Hour_22
# Classifier trained for option DUNWOD_Hour_23
# Classifier trained for option GENESE_Hour_0
# Classifier trained for option GENESE_Hour_1
# Classifier trained for option GENESE_Hour_2
# Classifier trained for option GENESE_Hour_3
# Classifier trained for option GENESE_Hour_4
# Classifier trained for option GENESE_Hour_5
# Classifier trained for option GENESE_Hour_6
# Classifier trained for option GENESE_Hour_7
# Classifier trained for option GENESE_Hour_8
# Classifier trained for option GENESE_Hour_9
# Classifier trained for option GENESE_Hour_10
# Classifier trained for option GENESE_Hour_11
# Classifier trained for option GENESE_Hour_12
# Classifier trained for option GENESE_Hour_13
# Classifier trained for option GENESE_Hour_14
# Classifier trained for option GENESE_Hour_15
# Classifier trained for option GENESE_Hour_16
# Classifier trained for option GENESE_Hour_17
# Classifier trained for option GENESE_Hour_18
# Classifier trained for option GENESE_Hour_19
# Classifier trained for option GENESE_Hour_20
# Classifier trained for option GENESE_Hour_21
# Classifier trained for option GENESE_Hour_22
# Classifier trained for option GENESE_Hour_23
# Classifier trained for option HUD VL_Hour_0
# Classifier trained for option HUD VL_Hour_1
# Classifier trained for option HUD VL_Hour_2
# Classifier trained for option HUD VL_Hour_3
# Classifier trained for option HUD VL_Hour_4
# Classifier trained for option HUD VL_Hour_5
# Classifier trained for option HUD VL_Hour_6
# Classifier trained for option HUD VL_Hour_7
# Classifier trained for option HUD VL_Hour_8
# Classifier trained for option HUD VL_Hour_9
# Classifier trained for option HUD VL_Hour_10
# Classifier trained for option HUD VL_Hour_11
# Classifier trained for option HUD VL_Hour_12
# Classifier trained for option HUD VL_Hour_13
# Classifier trained for option HUD VL_Hour_14
# Classifier trained for option HUD VL_Hour_15
# Classifier trained for option HUD VL_Hour_16
# Classifier trained for option HUD VL_Hour_17
# Classifier trained for option HUD VL_Hour_18
# Classifier trained for option HUD VL_Hour_19
# Classifier trained for option HUD VL_Hour_20
# Classifier trained for option HUD VL_Hour_21
# Classifier trained for option HUD VL_Hour_22
# Classifier trained for option HUD VL_Hour_23
# Classifier trained for option LONGIL_Hour_0
# Classifier trained for option LONGIL_Hour_1
# Classifier trained for option LONGIL_Hour_2
# Classifier trained for option LONGIL_Hour_3
# Classifier trained for option LONGIL_Hour_4
# Classifier trained for option LONGIL_Hour_5
# Classifier trained for option LONGIL_Hour_6
# Classifier trained for option LONGIL_Hour_7
# Classifier trained for option LONGIL_Hour_8
# Classifier trained for option LONGIL_Hour_9
# Classifier trained for option LONGIL_Hour_10
# Classifier trained for option LONGIL_Hour_11
# Classifier trained for option LONGIL_Hour_12
# Classifier trained for option LONGIL_Hour_13
# Classifier trained for option LONGIL_Hour_14
# Classifier trained for option LONGIL_Hour_15
# Classifier trained for option LONGIL_Hour_16
# Classifier trained for option LONGIL_Hour_17
# Classifier trained for option LONGIL_Hour_18
# Classifier trained for option LONGIL_Hour_19
# Classifier trained for option LONGIL_Hour_20
# Classifier trained for option LONGIL_Hour_21
# Classifier trained for option LONGIL_Hour_22
# Classifier trained for option LONGIL_Hour_23
# Classifier trained for option MHK VL_Hour_0
# Classifier trained for option MHK VL_Hour_1
# Classifier trained for option MHK VL_Hour_2
# Classifier trained for option MHK VL_Hour_3
# Classifier trained for option MHK VL_Hour_4
# Classifier trained for option MHK VL_Hour_5
# Classifier trained for option MHK VL_Hour_6
# Classifier trained for option MHK VL_Hour_7
# Classifier trained for option MHK VL_Hour_8
# Classifier trained for option MHK VL_Hour_9
# Classifier trained for option MHK VL_Hour_10
# Classifier trained for option MHK VL_Hour_11
# Classifier trained for option MHK VL_Hour_12
# Classifier trained for option MHK VL_Hour_13
# Classifier trained for option MHK VL_Hour_14
# Classifier trained for option MHK VL_Hour_15
# Classifier trained for option MHK VL_Hour_16
# Classifier trained for option MHK VL_Hour_17
# Classifier trained for option MHK VL_Hour_18
# Classifier trained for option MHK VL_Hour_19
# Classifier trained for option MHK VL_Hour_20
# Classifier trained for option MHK VL_Hour_21
# Classifier trained for option MHK VL_Hour_22
# Classifier trained for option MHK VL_Hour_23
# Classifier trained for option MILLWD_Hour_0
# Classifier trained for option MILLWD_Hour_1
# Classifier trained for option MILLWD_Hour_2
# Classifier trained for option MILLWD_Hour_3
# Classifier trained for option MILLWD_Hour_4
# Classifier trained for option MILLWD_Hour_5
# Classifier trained for option MILLWD_Hour_6
# Classifier trained for option MILLWD_Hour_7
# Classifier trained for option MILLWD_Hour_8
# Classifier trained for option MILLWD_Hour_9
# Classifier trained for option MILLWD_Hour_10
# Classifier trained for option MILLWD_Hour_11
# Classifier trained for option MILLWD_Hour_12
# Classifier trained for option MILLWD_Hour_13
# Classifier trained for option MILLWD_Hour_14
# Classifier trained for option MILLWD_Hour_15
# Classifier trained for option MILLWD_Hour_16
# Classifier trained for option MILLWD_Hour_17
# Classifier trained for option MILLWD_Hour_18
# Classifier trained for option MILLWD_Hour_19
# Classifier trained for option MILLWD_Hour_20
# Classifier trained for option MILLWD_Hour_21
# Classifier trained for option MILLWD_Hour_22
# Classifier trained for option MILLWD_Hour_23
# Classifier trained for option N.Y.C._Hour_0
# Classifier trained for option N.Y.C._Hour_1
# Classifier trained for option N.Y.C._Hour_2
# Classifier trained for option N.Y.C._Hour_3
# Classifier trained for option N.Y.C._Hour_4
# Classifier trained for option N.Y.C._Hour_5
# Classifier trained for option N.Y.C._Hour_6
# Classifier trained for option N.Y.C._Hour_7
# Classifier trained for option N.Y.C._Hour_8
# Classifier trained for option N.Y.C._Hour_9
# Classifier trained for option N.Y.C._Hour_10
# Classifier trained for option N.Y.C._Hour_11
# Classifier trained for option N.Y.C._Hour_12
# Classifier trained for option N.Y.C._Hour_13
# Classifier trained for option N.Y.C._Hour_14
# Classifier trained for option N.Y.C._Hour_15
# Classifier trained for option N.Y.C._Hour_16
# Classifier trained for option N.Y.C._Hour_17
# Classifier trained for option N.Y.C._Hour_18
# Classifier trained for option N.Y.C._Hour_19
# Classifier trained for option N.Y.C._Hour_20
# Classifier trained for option N.Y.C._Hour_21
# Classifier trained for option N.Y.C._Hour_22
# Classifier trained for option N.Y.C._Hour_23
# Classifier trained for option NORTH_Hour_0
# Classifier trained for option NORTH_Hour_1
# Classifier trained for option NORTH_Hour_2
# Classifier trained for option NORTH_Hour_3
# Classifier trained for option NORTH_Hour_4
# Classifier trained for option NORTH_Hour_5
# Classifier trained for option NORTH_Hour_6
# Classifier trained for option NORTH_Hour_7
# Classifier trained for option NORTH_Hour_8
# Classifier trained for option NORTH_Hour_9
# Classifier trained for option NORTH_Hour_10
# Classifier trained for option NORTH_Hour_11
# Classifier trained for option NORTH_Hour_12
# Classifier trained for option NORTH_Hour_13
# Classifier trained for option NORTH_Hour_14
# Classifier trained for option NORTH_Hour_15
# Classifier trained for option NORTH_Hour_16
# Classifier trained for option NORTH_Hour_17
# Classifier trained for option NORTH_Hour_18
# Classifier trained for option NORTH_Hour_19
# Classifier trained for option NORTH_Hour_20
# Classifier trained for option NORTH_Hour_21
# Classifier trained for option NORTH_Hour_22
# Classifier trained for option NORTH_Hour_23
# Classifier trained for option WEST_Hour_0
# Classifier trained for option WEST_Hour_1
# Classifier trained for option WEST_Hour_2
# Classifier trained for option WEST_Hour_3
# Classifier trained for option WEST_Hour_4
# Classifier trained for option WEST_Hour_5
# Classifier trained for option WEST_Hour_6
# Classifier trained for option WEST_Hour_7
# Classifier trained for option WEST_Hour_8
# Classifier trained for option WEST_Hour_9
# Classifier trained for option WEST_Hour_10
# Classifier trained for option WEST_Hour_11
# Classifier trained for option WEST_Hour_12
# Classifier trained for option WEST_Hour_13
# Classifier trained for option WEST_Hour_14
# Classifier trained for option WEST_Hour_15
# Classifier trained for option WEST_Hour_16
# Classifier trained for option WEST_Hour_17
# Classifier trained for option WEST_Hour_18
# Classifier trained for option WEST_Hour_19
# Classifier trained for option WEST_Hour_20
# Classifier trained for option WEST_Hour_21
# Classifier trained for option WEST_Hour_22
# Classifier trained for option WEST_Hour_23
#
# Overall training accuracy = 98.71 percent.

# %%
# First, load the test data from NYISO for the year 2016. Again, utilize our function
# named 'loadNYISOData'.

print("Starting the testing module...\n")
testPriceDA, testPriceDART, testLoadDA = loadNYISOData(2016)

# Create the data for the classifier using the function 'createClassifierIO'.
testX, testY, rangeOfDays = createClassifierIO(testPriceDA, testPriceDART, testLoadDA)

# The next step is not useful for implementing the trading strategy, but quickly check how accurate
# your trained classifiers are for the test data. Training accuracy is not always indicative of
# test accuracy.

testingAccuracy = [classifiers[ii].score(testX, testY[:, ii]) for ii in range(nOptions)]
print("Test Accuracy Stats: Min = %.2f%%, Avg = %.2f%%, Max = %.2f%%" %
      (100 * np.min(testingAccuracy),
       100 * np.mean(testingAccuracy),
       100 * np.max(testingAccuracy)))

# Utilize the classifiers to predict the sign of DA - RT prices for each day in 'rangeOfDays' for
# the test data. Store the result in a pandas data frame with columns as the option names and the
# day in year as index.
predictedY = pd.DataFrame(np.column_stack([classifiers[ii].predict(testX) for ii in range(nOptions)]),
                          columns=optionNames, index=rangeOfDays)
# Out:
# Starting the testing module...
#
# Test Accuracy Stats: Min = 46.83%, Avg = 57.17%, Max = 67.22%

# %%
dailyBudget = 250000
quantileOffer =0.8

# Keep track of your rewards in each day, a cumulative reward over the year, and a total reward over the
# year. Also, keep track of the total reward from each option. Store them as dictionaries that are
# indexed by day of the year.
reward = {}
cumulativeReward = {}
totalReward = 0
optionReturn = dict((option, 0) for option in optionNames)

# Implement the trading strategy on each day!

for day in rangeOfDays:

    reward[day] = 0

    # Find the options that your classifier says that should be profitable. Store the profitable option
    # names in chosenOptions.
    chosenOptionNumbers = np.ravel(list(np.nonzero(predictedY.loc[day].values)))
    if np.size(chosenOptionNumbers) == 0:
        continue
    chosenOptions = [optionNames[i] for i in chosenOptionNumbers]

    # Design the portfolio based on average price spreads. Our strategy is that as long as you have not
    # exceeded your daily budget, pick an option from the list of 'chosenOptions' probabilistically, where
    # the probability of choosing it is proportional to exponential(historical rewards of that option). That
    # is, a historically profitable option is chosen more often than one that is not. Keep sampling and
    # decreasing your budget with each bid.

    # Start with an empty portfolio.

    portfolio = dict((option, 0) for option in chosenOptions)

    # Calculate the probabilities of choosing each option among the list 'chosenOptions'. Recall that
    # 'chosenOptions' contains the options that your classifier indicates as being profitable.
    priceSpreads = [1.0 * averagePriceSpread[option] for option in chosenOptions]
    probabilityOptions = [np.exp(p) for p in priceSpreads]
    probabilityOptions /= np.sum(probabilityOptions)

    # Start with your daily budget.
    budget = dailyBudget

    # Sampling among the profitable options and bid based on them.
    while budget > np.median([offerPrices[quantileOffer][option] for option in chosenOptions]):

        optionToBuy = choice(chosenOptions, p=probabilityOptions)

        if budget >= offerPrices[quantileOffer][optionToBuy]:
            portfolio[optionToBuy] += 1
            budget -= offerPrices[quantileOffer][optionToBuy]

    # Compute the reward from the day. Go through each of the options you have decided to buy.
    # If the DA price is lower than the bid price, then your bid is cleared. For each option you
    # have bought, you get a reward equal to the DA - RT price.

    for option in chosenOptions:
        if testPriceDA.at[day, option] < offerPrices[quantileOffer][option]:
            rewardOptionDay = testPriceDART.at[day, option] * portfolio[option]
            optionReturn[option] += rewardOptionDay
            reward[day] += rewardOptionDay

    totalReward += reward[day]

    # Calculate the cumulative reward in millions of dollars.
    cumulativeReward[day] = totalReward/1000000

    print("Day " + str(day) + ": Reward (in $) = " + "{0:,.0f}".format(reward[day]))

print("Total money earned over the year (in $) = " + "{0:,.0f}".format(totalReward))
# Out:
# Day 3: Reward (in $) = -67,805
# Day 4: Reward (in $) = 1,485,251
# Day 5: Reward (in $) = 25,078
# Day 6: Reward (in $) = -11,452
# Day 7: Reward (in $) = -33,281
# Day 8: Reward (in $) = -578
# Day 9: Reward (in $) = -41,153
# Day 10: Reward (in $) = -104,263
# Day 11: Reward (in $) = -67,634
# Day 12: Reward (in $) = -19,529
# Day 13: Reward (in $) = -29,218
# Day 14: Reward (in $) = -38,815
# Day 15: Reward (in $) = -251
# Day 16: Reward (in $) = 45,331
# Day 17: Reward (in $) = -68,398
# Day 18: Reward (in $) = -22,082
# Day 19: Reward (in $) = 20,870
# Day 20: Reward (in $) = -5,200
# Day 21: Reward (in $) = 31,202
# Day 22: Reward (in $) = 120,445
# Day 23: Reward (in $) = 28,213
# Day 24: Reward (in $) = -86,298
# Day 25: Reward (in $) = -88,209
# Day 26: Reward (in $) = -19,117
# Day 27: Reward (in $) = -6,825
# Day 28: Reward (in $) = -12,562
# Day 29: Reward (in $) = -22,138
# Day 30: Reward (in $) = -35,167
# Day 31: Reward (in $) = -47,267
# Day 32: Reward (in $) = -11,389
# Day 33: Reward (in $) = -57,989
# Day 34: Reward (in $) = 8,209
# Day 35: Reward (in $) = 14,033
# Day 36: Reward (in $) = -40,211
# Day 37: Reward (in $) = -41,353
# Day 38: Reward (in $) = 27,651
# Day 39: Reward (in $) = 19,597
# Day 40: Reward (in $) = -31,176
# Day 41: Reward (in $) = 8,787
# Day 42: Reward (in $) = -15,844
# Day 43: Reward (in $) = -31,967
# Day 44: Reward (in $) = -24,828
# Day 45: Reward (in $) = -17,706
# Day 46: Reward (in $) = 86,140
# Day 47: Reward (in $) = 55,861
# Day 48: Reward (in $) = -56,207
# Day 49: Reward (in $) = -46,034
# Day 50: Reward (in $) = -48,691
# Day 51: Reward (in $) = -638
# Day 52: Reward (in $) = -25,241
# Day 53: Reward (in $) = -15,127
# Day 54: Reward (in $) = -472
# Day 55: Reward (in $) = -4,917
# Day 56: Reward (in $) = -43,743
# Day 57: Reward (in $) = -28,252
# Day 58: Reward (in $) = -25,588
# Day 59: Reward (in $) = -15,968
# Day 60: Reward (in $) = -8,446
# Day 61: Reward (in $) = -116,807
# Day 62: Reward (in $) = -14,377
# Day 63: Reward (in $) = -18,895
# Day 64: Reward (in $) = -46,225
# Day 65: Reward (in $) = 37,520
# Day 66: Reward (in $) = 71,344
# Day 67: Reward (in $) = -52,819
# Day 68: Reward (in $) = -64,377
# Day 69: Reward (in $) = -29,294
# Day 70: Reward (in $) = 136,651
# Day 71: Reward (in $) = -5,680
# Day 72: Reward (in $) = -8,369
# Day 73: Reward (in $) = -55,168
# Day 74: Reward (in $) = -43,297
# Day 75: Reward (in $) = -3,683
# Day 76: Reward (in $) = -95,596
# Day 77: Reward (in $) = -15,712
# Day 78: Reward (in $) = -34,132
# Day 79: Reward (in $) = -40,869
# Day 80: Reward (in $) = -39,935
# Day 81: Reward (in $) = 31,192
# Day 82: Reward (in $) = 27,029
# Day 83: Reward (in $) = -11,539
# Day 84: Reward (in $) = -4,888
# Day 85: Reward (in $) = 22,023
# Day 86: Reward (in $) = -28,941
# Day 87: Reward (in $) = 2,689,171
# Day 88: Reward (in $) = 914,423
# Day 89: Reward (in $) = -24,757
# Day 90: Reward (in $) = -8,713
# Day 91: Reward (in $) = -112,713
# Day 92: Reward (in $) = 77,371
# Day 93: Reward (in $) = -1,197
# Day 94: Reward (in $) = 6,470
# Day 95: Reward (in $) = -25,125
# Day 96: Reward (in $) = 67,203
# Day 97: Reward (in $) = 23,737
# Day 98: Reward (in $) = -4,571
# Day 99: Reward (in $) = -24,082
# Day 100: Reward (in $) = -36,260
# Day 101: Reward (in $) = -19,680
# Day 102: Reward (in $) = -39,467
# Day 103: Reward (in $) = 76,970
# Day 104: Reward (in $) = -33,833
# Day 105: Reward (in $) = -72,234
# Day 106: Reward (in $) = -12,284
# Day 107: Reward (in $) = -23,968
# Day 108: Reward (in $) = 28,163
# Day 109: Reward (in $) = -2,617
# Day 110: Reward (in $) = -39,927
# Day 111: Reward (in $) = -31,494
# Day 112: Reward (in $) = 110,833
# Day 113: Reward (in $) = -40,578
# Day 114: Reward (in $) = -61,674
# Day 115: Reward (in $) = -118,381
# Day 116: Reward (in $) = 7,732
# Day 117: Reward (in $) = -16,999
# Day 118: Reward (in $) = 5,083
# Day 119: Reward (in $) = -9,209
# Day 120: Reward (in $) = 15,304
# Day 121: Reward (in $) = 52,336
# Day 122: Reward (in $) = -28,708
# Day 123: Reward (in $) = -16,038
# Day 124: Reward (in $) = -40,362
# Day 125: Reward (in $) = -31,069
# Day 126: Reward (in $) = -7,952
# Day 127: Reward (in $) = -38,250
# Day 128: Reward (in $) = -32,985
# Day 129: Reward (in $) = -39,272
# Day 130: Reward (in $) = -10,823
# Day 131: Reward (in $) = 11,809
# Day 132: Reward (in $) = 53,031
# Day 133: Reward (in $) = 58,143
# Day 134: Reward (in $) = -50,051
# Day 135: Reward (in $) = -16,031
# Day 136: Reward (in $) = -41,988
# Day 137: Reward (in $) = -47,455
# Day 138: Reward (in $) = -102,632
# Day 139: Reward (in $) = -1,822
# Day 140: Reward (in $) = -49,749
# Day 141: Reward (in $) = 26,638
# Day 142: Reward (in $) = 26,097
# Day 143: Reward (in $) = -11,020
# Day 144: Reward (in $) = -38,139
# Day 145: Reward (in $) = -46,793
# Day 146: Reward (in $) = -8,131
# Day 147: Reward (in $) = -70,785
# Day 148: Reward (in $) = -13,718
# Day 149: Reward (in $) = -7,864
# Day 150: Reward (in $) = 55,239
# Day 151: Reward (in $) = 503,611
# Day 152: Reward (in $) = 380,716
# Day 153: Reward (in $) = 125,983
# Day 154: Reward (in $) = 3,317
# Day 155: Reward (in $) = -44,571
# Day 156: Reward (in $) = -32,155
# Day 157: Reward (in $) = -129,355
# Day 158: Reward (in $) = -74,169
# Day 159: Reward (in $) = -36,083
# Day 160: Reward (in $) = -118,226
# Day 161: Reward (in $) = -44,974
# Day 162: Reward (in $) = 451,318
# Day 163: Reward (in $) = -13,076
# Day 164: Reward (in $) = -13,013
# Day 165: Reward (in $) = 608,881
# Day 166: Reward (in $) = -21,356
# Day 167: Reward (in $) = 8,749
# Day 168: Reward (in $) = 1,034
# Day 169: Reward (in $) = 7,521
# Day 170: Reward (in $) = -32,645
# Day 171: Reward (in $) = -3,445
# Day 172: Reward (in $) = -11,717
# Day 173: Reward (in $) = 17,277
# Day 174: Reward (in $) = 15,253
# Day 175: Reward (in $) = 18,169
# Day 176: Reward (in $) = -16,208
# Day 177: Reward (in $) = -29,344
# Day 178: Reward (in $) = -23,231
# Day 179: Reward (in $) = -16,903
# Day 180: Reward (in $) = -351
# Day 181: Reward (in $) = -8,475
# Day 182: Reward (in $) = -14,579
# Day 183: Reward (in $) = -70,171
# Day 184: Reward (in $) = -101,537
# Day 185: Reward (in $) = -46,869
# Day 186: Reward (in $) = 30,148
# Day 187: Reward (in $) = 15,147
# Day 188: Reward (in $) = 2,113
# Day 189: Reward (in $) = -5,884
# Day 190: Reward (in $) = -99,626
# Day 191: Reward (in $) = -23,860
# Day 192: Reward (in $) = -23,401
# Day 193: Reward (in $) = -81,504
# Day 194: Reward (in $) = -673
# Day 195: Reward (in $) = 5,635
# Day 196: Reward (in $) = 11,333
# Day 197: Reward (in $) = 12,192
# Day 198: Reward (in $) = 38,468
# Day 199: Reward (in $) = -4,649
# Day 200: Reward (in $) = -78,504
# Day 201: Reward (in $) = -7,761
# Day 202: Reward (in $) = -6,066
# Day 203: Reward (in $) = 15,280
# Day 204: Reward (in $) = 4,686
# Day 205: Reward (in $) = -26,295
# Day 206: Reward (in $) = -2,230
# Day 207: Reward (in $) = -4,441
# Day 208: Reward (in $) = 21,245
# Day 209: Reward (in $) = 23,448
# Day 210: Reward (in $) = 207,795
# Day 211: Reward (in $) = 45,914
# Day 212: Reward (in $) = 57,362
# Day 213: Reward (in $) = -6,266
# Day 214: Reward (in $) = -70,555
# Day 215: Reward (in $) = -70,936
# Day 216: Reward (in $) = 1,073
# Day 217: Reward (in $) = 2,109
# Day 218: Reward (in $) = 25,455
# Day 219: Reward (in $) = -28,647
# Day 220: Reward (in $) = -3,585
# Day 221: Reward (in $) = -29,288
# Day 222: Reward (in $) = 17,792
# Day 223: Reward (in $) = 5,442
# Day 224: Reward (in $) = -219
# Day 225: Reward (in $) = 458
# Day 226: Reward (in $) = -40,540
# Day 227: Reward (in $) = -1,140
# Day 228: Reward (in $) = 15,860
# Day 229: Reward (in $) = -5,850
# Day 230: Reward (in $) = -3,267
# Day 231: Reward (in $) = -1,613
# Day 232: Reward (in $) = -64,575
# Day 233: Reward (in $) = -50,479
# Day 234: Reward (in $) = -81,796
# Day 235: Reward (in $) = -130,573
# Day 236: Reward (in $) = 18,787
# Day 237: Reward (in $) = 56,766
# Day 238: Reward (in $) = -2,458
# Day 239: Reward (in $) = -40,356
# Day 240: Reward (in $) = -19,996
# Day 241: Reward (in $) = -639
# Day 242: Reward (in $) = 58,694
# Day 243: Reward (in $) = -1,757
# Day 244: Reward (in $) = 5,679
# Day 245: Reward (in $) = -70,206
# Day 246: Reward (in $) = -36,519
# Day 247: Reward (in $) = -5,698
# Day 248: Reward (in $) = -33,417
# Day 249: Reward (in $) = -784
# Day 250: Reward (in $) = -19,090
# Day 251: Reward (in $) = 279
# Day 252: Reward (in $) = -2,485
# Day 253: Reward (in $) = 137,917
# Day 254: Reward (in $) = -12,355
# Day 255: Reward (in $) = -58,310
# Day 256: Reward (in $) = -4,041
# Day 257: Reward (in $) = 32,512
# Day 258: Reward (in $) = -23,399
# Day 259: Reward (in $) = -38,887
# Day 260: Reward (in $) = -31,076
# Day 261: Reward (in $) = 70,332
# Day 262: Reward (in $) = -8,992
# Day 263: Reward (in $) = -61,575
# Day 264: Reward (in $) = -39,606
# Day 265: Reward (in $) = -4,708
# Day 266: Reward (in $) = -86,799
# Day 267: Reward (in $) = -8,481
# Day 268: Reward (in $) = -22,429
# Day 269: Reward (in $) = -84,145
# Day 270: Reward (in $) = -68,970
# Day 271: Reward (in $) = -9,181
# Day 272: Reward (in $) = -26,390
# Day 273: Reward (in $) = -42,868
# Day 274: Reward (in $) = 22,615
# Day 275: Reward (in $) = 23,689
# Day 276: Reward (in $) = -20,980
# Day 277: Reward (in $) = 41,526
# Day 278: Reward (in $) = 137,120
# Day 279: Reward (in $) = 3,515
# Day 280: Reward (in $) = -26,650
# Day 281: Reward (in $) = -11,256
# Day 282: Reward (in $) = 12,467
# Day 283: Reward (in $) = -5,994
# Day 284: Reward (in $) = -33,329
# Day 285: Reward (in $) = 16,384
# Day 286: Reward (in $) = -54,740
# Day 287: Reward (in $) = -62,777
# Day 288: Reward (in $) = 4,750
# Day 289: Reward (in $) = 5,525
# Day 290: Reward (in $) = 8,261
# Day 291: Reward (in $) = -6,525
# Day 292: Reward (in $) = -1,323
# Day 293: Reward (in $) = 66,105
# Day 294: Reward (in $) = -10,992
# Day 295: Reward (in $) = 6,116
# Day 296: Reward (in $) = -49,683
# Day 297: Reward (in $) = -32,271
# Day 298: Reward (in $) = 131,465
# Day 299: Reward (in $) = -60,406
# Day 300: Reward (in $) = -14,827
# Day 301: Reward (in $) = -7,653
# Day 302: Reward (in $) = -21,864
# Day 303: Reward (in $) = 13,766
# Day 304: Reward (in $) = -55,016
# Day 305: Reward (in $) = -15,159
# Day 306: Reward (in $) = -16,699
# Day 307: Reward (in $) = -7,351
# Day 308: Reward (in $) = -44,759
# Day 309: Reward (in $) = 3,339
# Day 310: Reward (in $) = -5,213
# Day 311: Reward (in $) = -33,082
# Day 312: Reward (in $) = 45,829
# Day 313: Reward (in $) = -2,020
# Day 314: Reward (in $) = -59,569
# Day 315: Reward (in $) = -48,024
# Day 316: Reward (in $) = -11,753
# Day 317: Reward (in $) = -34,070
# Day 318: Reward (in $) = -17,426
# Day 319: Reward (in $) = 2,487
# Day 320: Reward (in $) = 15,996
# Day 321: Reward (in $) = 10,207
# Day 322: Reward (in $) = -5,399
# Day 323: Reward (in $) = 7,547
# Day 324: Reward (in $) = 15,614
# Day 325: Reward (in $) = -26,348
# Day 326: Reward (in $) = -10,118
# Day 327: Reward (in $) = -12,111
# Day 328: Reward (in $) = 58,502
# Day 329: Reward (in $) = 37,809
# Day 330: Reward (in $) = 5,893
# Day 331: Reward (in $) = -11,863
# Day 332: Reward (in $) = -45,423
# Day 333: Reward (in $) = -41,601
# Day 334: Reward (in $) = -2,201
# Day 335: Reward (in $) = -20,624
# Day 336: Reward (in $) = -17,332
# Day 337: Reward (in $) = 18,843
# Day 338: Reward (in $) = -8,772
# Day 339: Reward (in $) = -28,711
# Day 340: Reward (in $) = -28,994
# Day 341: Reward (in $) = -51,285
# Day 342: Reward (in $) = -106,618
# Day 343: Reward (in $) = -125,750
# Day 344: Reward (in $) = 167,893
# Day 345: Reward (in $) = 76,288
# Day 346: Reward (in $) = -24,193
# Day 347: Reward (in $) = 7,381
# Day 348: Reward (in $) = -35,301
# Day 349: Reward (in $) = 78,455
# Day 350: Reward (in $) = -4,296
# Day 351: Reward (in $) = 78,606
# Day 352: Reward (in $) = 44,115
# Day 353: Reward (in $) = 9,308
# Day 354: Reward (in $) = -44,509
# Day 355: Reward (in $) = -59,866
# Day 356: Reward (in $) = -22,998
# Day 357: Reward (in $) = -30,457
# Day 358: Reward (in $) = -11,825
# Day 359: Reward (in $) = -11,899
# Day 360: Reward (in $) = -32,006
# Day 361: Reward (in $) = -70,750
# Day 362: Reward (in $) = 25,474
# Day 363: Reward (in $) = 270,363
# Day 364: Reward (in $) = 1,518
# Day 365: Reward (in $) = -15,486
# Total money earned over the year (in $) = 3,103,216

# %% [markdown]
# ### Task 3: Quantile (25 points)
#
# For the best classifier, try different quanltile choices from the following list: 0.70, 0.75, 0.80, 0.85, 0.90, 0.95. Rank them in terms of profits (low to high).
#
# How do you expect the quantile to affect the portfolio?
#
# #### (comments here, add a new code cell below)
#
# 0.70: $3,608,945
#
# 0.75: $3,453,180
#
# 0.80: $3,103,216
#
# 0.85: $2,435,304
#
# 0.90: $1,658,829
#
# 0.95: $1,825,928
#
# 0.9 < 0.95 < 0.85 < 0.80 < 0.75 < 0.70 in terms of profits from low to high and as we can see above, 0.7 gives the best maximum profit. From this observation, lower quantile value yields better profit using linear regresssion classifier.

# %%
classifiers = []

# We have two options here. Use previous training experience, or learn anew.
useSavedClassifiers = False

if not useSavedClassifiers:

    print("Starting training module...\n")
    trainPriceDA, trainPriceDART, trainLoadDA = loadNYISOData(2015)

    numberOfDays =  int(len(trainPriceDA.index))
    print("Loaded hourly prices from 2015 for %d days." % numberOfDays)

    # We will implement a trading strategy, where we bid a particular quantile of the past
    # DA prices for an option. If you do not know what a quantile means, refer to the Wikipedia
    # article on it. Essentially, a 95% quantile of the DA prices equals that value for which
    # 95% of the DA prices are below it. Store all quantiles starting from 50% in steps of
    # 5% in a dictionary. Store them in a pickle file.

    quantilesToStore = [0.70, 0.75, 0.80, 0.85, 0.90, 0.95]
    offerPrices = trainPriceDA.quantile(q=quantilesToStore).transpose().to_dict()
    pickle.dump(offerPrices, open("./Training/OfferPrices", 'wb'))

    # Calculate the average price spread for each option over the entire year. This will guide
    # us in choosing our portfolio. Store it as a dictionary. Our bid will choose those
    # options that our classifier indicates that they will be profitable and historically they
    # have higher average price differences, indicating that they have higher rate of return.
    # Store them using pickle.

    averagePriceSpread = trainPriceDART.mean(axis=0).transpose().to_dict()
    pickle.dump(averagePriceSpread, open("./Training/AveragePriceSpread", 'wb'))

    # Create the training dataset using the function 'createClassifierIO' on the prices and
    # loads, and store them in 'trainX', and 'trainY'.

    trainX, trainY, _ = createClassifierIO(trainPriceDA, trainPriceDART, trainLoadDA)

    # Define a collection of classifiers, one for each option. You can try different options, such
    # as that based on an SVM, logistic regression, multilayer perceptron based, etc. We will
    # measure training accuracy to indicate how well the classifier works on the training dataset.
    # However, good training accuracy does not always indicate good test performance.
    # Avoid over-fitting.


    classifiers = [LogisticRegression(C=0.9, max_iter=400, solver='liblinear')
                   for _ in range(nOptions)]

    trainingAccuracy = 0

    for ii in range(nOptions):
        classifiers[ii].fit(trainX, trainY[:, ii])
        print("Classifier trained for option " + optionNames[ii])
        trainingAccuracy += classifiers[ii].score(trainX, trainY[:, ii])

        # Store the classifier.
        pickle.dump(classifiers[ii], open("./Training/Classifier_" + optionNames[ii], 'wb'))

    print("\nOverall training accuracy = %1.2f percent." % (100 * trainingAccuracy/nOptions))

    del numberOfDays, trainPriceDA, trainLoadDA, trainPriceDART, trainX, trainY
else:

    # Load the classifiers, the offer prices at various quantiles, and the average price spreads.

    print("Loading previously trained variables...\n")
    classifiers = [pickle.load(open("./Training/Classifier_" + optionNames[ii], 'rb'))
                   for ii in range(nOptions)]
    offerPrices = pickle.load(open("./Training/OfferPrices", 'rb'))
    averagePriceSpread = pickle.load(open("./Training/AveragePriceSpread", 'rb'))

    print("All training variables were loaded successfully...\n")
# Out:
# Starting training module...
#
# Loaded hourly prices from 2015 for 365 days.
# Classifier trained for option CAPITL_Hour_0
# Classifier trained for option CAPITL_Hour_1
# Classifier trained for option CAPITL_Hour_2
# Classifier trained for option CAPITL_Hour_3
# Classifier trained for option CAPITL_Hour_4
# Classifier trained for option CAPITL_Hour_5
# Classifier trained for option CAPITL_Hour_6
# Classifier trained for option CAPITL_Hour_7
# Classifier trained for option CAPITL_Hour_8
# Classifier trained for option CAPITL_Hour_9
# Classifier trained for option CAPITL_Hour_10
# Classifier trained for option CAPITL_Hour_11
# Classifier trained for option CAPITL_Hour_12
# Classifier trained for option CAPITL_Hour_13
# Classifier trained for option CAPITL_Hour_14
# Classifier trained for option CAPITL_Hour_15
# Classifier trained for option CAPITL_Hour_16
# Classifier trained for option CAPITL_Hour_17
# Classifier trained for option CAPITL_Hour_18
# Classifier trained for option CAPITL_Hour_19
# Classifier trained for option CAPITL_Hour_20
# Classifier trained for option CAPITL_Hour_21
# Classifier trained for option CAPITL_Hour_22
# Classifier trained for option CAPITL_Hour_23
# Classifier trained for option CENTRL_Hour_0
# Classifier trained for option CENTRL_Hour_1
# Classifier trained for option CENTRL_Hour_2
# Classifier trained for option CENTRL_Hour_3
# Classifier trained for option CENTRL_Hour_4
# Classifier trained for option CENTRL_Hour_5
# Classifier trained for option CENTRL_Hour_6
# Classifier trained for option CENTRL_Hour_7
# Classifier trained for option CENTRL_Hour_8
# Classifier trained for option CENTRL_Hour_9
# Classifier trained for option CENTRL_Hour_10
# Classifier trained for option CENTRL_Hour_11
# Classifier trained for option CENTRL_Hour_12
# Classifier trained for option CENTRL_Hour_13
# Classifier trained for option CENTRL_Hour_14
# Classifier trained for option CENTRL_Hour_15
# Classifier trained for option CENTRL_Hour_16
# Classifier trained for option CENTRL_Hour_17
# Classifier trained for option CENTRL_Hour_18
# Classifier trained for option CENTRL_Hour_19
# Classifier trained for option CENTRL_Hour_20
# Classifier trained for option CENTRL_Hour_21
# Classifier trained for option CENTRL_Hour_22
# Classifier trained for option CENTRL_Hour_23
# Classifier trained for option DUNWOD_Hour_0
# Classifier trained for option DUNWOD_Hour_1
# Classifier trained for option DUNWOD_Hour_2
# Classifier trained for option DUNWOD_Hour_3
# Classifier trained for option DUNWOD_Hour_4
# Classifier trained for option DUNWOD_Hour_5
# Classifier trained for option DUNWOD_Hour_6
# Classifier trained for option DUNWOD_Hour_7
# Classifier trained for option DUNWOD_Hour_8
# Classifier trained for option DUNWOD_Hour_9
# Classifier trained for option DUNWOD_Hour_10
# Classifier trained for option DUNWOD_Hour_11
# Classifier trained for option DUNWOD_Hour_12
# Classifier trained for option DUNWOD_Hour_13
# Classifier trained for option DUNWOD_Hour_14
# Classifier trained for option DUNWOD_Hour_15
# Classifier trained for option DUNWOD_Hour_16
# Classifier trained for option DUNWOD_Hour_17
# Classifier trained for option DUNWOD_Hour_18
# Classifier trained for option DUNWOD_Hour_19
# Classifier trained for option DUNWOD_Hour_20
# Classifier trained for option DUNWOD_Hour_21
# Classifier trained for option DUNWOD_Hour_22
# Classifier trained for option DUNWOD_Hour_23
# Classifier trained for option GENESE_Hour_0
# Classifier trained for option GENESE_Hour_1
# Classifier trained for option GENESE_Hour_2
# Classifier trained for option GENESE_Hour_3
# Classifier trained for option GENESE_Hour_4
# Classifier trained for option GENESE_Hour_5
# Classifier trained for option GENESE_Hour_6
# Classifier trained for option GENESE_Hour_7
# Classifier trained for option GENESE_Hour_8
# Classifier trained for option GENESE_Hour_9
# Classifier trained for option GENESE_Hour_10
# Classifier trained for option GENESE_Hour_11
# Classifier trained for option GENESE_Hour_12
# Classifier trained for option GENESE_Hour_13
# Classifier trained for option GENESE_Hour_14
# Classifier trained for option GENESE_Hour_15
# Classifier trained for option GENESE_Hour_16
# Classifier trained for option GENESE_Hour_17
# Classifier trained for option GENESE_Hour_18
# Classifier trained for option GENESE_Hour_19
# Classifier trained for option GENESE_Hour_20
# Classifier trained for option GENESE_Hour_21
# Classifier trained for option GENESE_Hour_22
# Classifier trained for option GENESE_Hour_23
# Classifier trained for option HUD VL_Hour_0
# Classifier trained for option HUD VL_Hour_1
# Classifier trained for option HUD VL_Hour_2
# Classifier trained for option HUD VL_Hour_3
# Classifier trained for option HUD VL_Hour_4
# Classifier trained for option HUD VL_Hour_5
# Classifier trained for option HUD VL_Hour_6
# Classifier trained for option HUD VL_Hour_7
# Classifier trained for option HUD VL_Hour_8
# Classifier trained for option HUD VL_Hour_9
# Classifier trained for option HUD VL_Hour_10
# Classifier trained for option HUD VL_Hour_11
# Classifier trained for option HUD VL_Hour_12
# Classifier trained for option HUD VL_Hour_13
# Classifier trained for option HUD VL_Hour_14
# Classifier trained for option HUD VL_Hour_15
# Classifier trained for option HUD VL_Hour_16
# Classifier trained for option HUD VL_Hour_17
# Classifier trained for option HUD VL_Hour_18
# Classifier trained for option HUD VL_Hour_19
# Classifier trained for option HUD VL_Hour_20
# Classifier trained for option HUD VL_Hour_21
# Classifier trained for option HUD VL_Hour_22
# Classifier trained for option HUD VL_Hour_23
# Classifier trained for option LONGIL_Hour_0
# Classifier trained for option LONGIL_Hour_1
# Classifier trained for option LONGIL_Hour_2
# Classifier trained for option LONGIL_Hour_3
# Classifier trained for option LONGIL_Hour_4
# Classifier trained for option LONGIL_Hour_5
# Classifier trained for option LONGIL_Hour_6
# Classifier trained for option LONGIL_Hour_7
# Classifier trained for option LONGIL_Hour_8
# Classifier trained for option LONGIL_Hour_9
# Classifier trained for option LONGIL_Hour_10
# Classifier trained for option LONGIL_Hour_11
# Classifier trained for option LONGIL_Hour_12
# Classifier trained for option LONGIL_Hour_13
# Classifier trained for option LONGIL_Hour_14
# Classifier trained for option LONGIL_Hour_15
# Classifier trained for option LONGIL_Hour_16
# Classifier trained for option LONGIL_Hour_17
# Classifier trained for option LONGIL_Hour_18
# Classifier trained for option LONGIL_Hour_19
# Classifier trained for option LONGIL_Hour_20
# Classifier trained for option LONGIL_Hour_21
# Classifier trained for option LONGIL_Hour_22
# Classifier trained for option LONGIL_Hour_23
# Classifier trained for option MHK VL_Hour_0
# Classifier trained for option MHK VL_Hour_1
# Classifier trained for option MHK VL_Hour_2
# Classifier trained for option MHK VL_Hour_3
# Classifier trained for option MHK VL_Hour_4
# Classifier trained for option MHK VL_Hour_5
# Classifier trained for option MHK VL_Hour_6
# Classifier trained for option MHK VL_Hour_7
# Classifier trained for option MHK VL_Hour_8
# Classifier trained for option MHK VL_Hour_9
# Classifier trained for option MHK VL_Hour_10
# Classifier trained for option MHK VL_Hour_11
# Classifier trained for option MHK VL_Hour_12
# Classifier trained for option MHK VL_Hour_13
# Classifier trained for option MHK VL_Hour_14
# Classifier trained for option MHK VL_Hour_15
# Classifier trained for option MHK VL_Hour_16
# Classifier trained for option MHK VL_Hour_17
# Classifier trained for option MHK VL_Hour_18
# Classifier trained for option MHK VL_Hour_19
# Classifier trained for option MHK VL_Hour_20
# Classifier trained for option MHK VL_Hour_21
# Classifier trained for option MHK VL_Hour_22
# Classifier trained for option MHK VL_Hour_23
# Classifier trained for option MILLWD_Hour_0
# Classifier trained for option MILLWD_Hour_1
# Classifier trained for option MILLWD_Hour_2
# Classifier trained for option MILLWD_Hour_3
# Classifier trained for option MILLWD_Hour_4
# Classifier trained for option MILLWD_Hour_5
# Classifier trained for option MILLWD_Hour_6
# Classifier trained for option MILLWD_Hour_7
# Classifier trained for option MILLWD_Hour_8
# Classifier trained for option MILLWD_Hour_9
# Classifier trained for option MILLWD_Hour_10
# Classifier trained for option MILLWD_Hour_11
# Classifier trained for option MILLWD_Hour_12
# Classifier trained for option MILLWD_Hour_13
# Classifier trained for option MILLWD_Hour_14
# Classifier trained for option MILLWD_Hour_15
# Classifier trained for option MILLWD_Hour_16
# Classifier trained for option MILLWD_Hour_17
# Classifier trained for option MILLWD_Hour_18
# Classifier trained for option MILLWD_Hour_19
# Classifier trained for option MILLWD_Hour_20
# Classifier trained for option MILLWD_Hour_21
# Classifier trained for option MILLWD_Hour_22
# Classifier trained for option MILLWD_Hour_23
# Classifier trained for option N.Y.C._Hour_0
# Classifier trained for option N.Y.C._Hour_1
# Classifier trained for option N.Y.C._Hour_2
# Classifier trained for option N.Y.C._Hour_3
# Classifier trained for option N.Y.C._Hour_4
# Classifier trained for option N.Y.C._Hour_5
# Classifier trained for option N.Y.C._Hour_6
# Classifier trained for option N.Y.C._Hour_7
# Classifier trained for option N.Y.C._Hour_8
# Classifier trained for option N.Y.C._Hour_9
# Classifier trained for option N.Y.C._Hour_10
# Classifier trained for option N.Y.C._Hour_11
# Classifier trained for option N.Y.C._Hour_12
# Classifier trained for option N.Y.C._Hour_13
# Classifier trained for option N.Y.C._Hour_14
# Classifier trained for option N.Y.C._Hour_15
# Classifier trained for option N.Y.C._Hour_16
# Classifier trained for option N.Y.C._Hour_17
# Classifier trained for option N.Y.C._Hour_18
# Classifier trained for option N.Y.C._Hour_19
# Classifier trained for option N.Y.C._Hour_20
# Classifier trained for option N.Y.C._Hour_21
# Classifier trained for option N.Y.C._Hour_22
# Classifier trained for option N.Y.C._Hour_23
# Classifier trained for option NORTH_Hour_0
# Classifier trained for option NORTH_Hour_1
# Classifier trained for option NORTH_Hour_2
# Classifier trained for option NORTH_Hour_3
# Classifier trained for option NORTH_Hour_4
# Classifier trained for option NORTH_Hour_5
# Classifier trained for option NORTH_Hour_6
# Classifier trained for option NORTH_Hour_7
# Classifier trained for option NORTH_Hour_8
# Classifier trained for option NORTH_Hour_9
# Classifier trained for option NORTH_Hour_10
# Classifier trained for option NORTH_Hour_11
# Classifier trained for option NORTH_Hour_12
# Classifier trained for option NORTH_Hour_13
# Classifier trained for option NORTH_Hour_14
# Classifier trained for option NORTH_Hour_15
# Classifier trained for option NORTH_Hour_16
# Classifier trained for option NORTH_Hour_17
# Classifier trained for option NORTH_Hour_18
# Classifier trained for option NORTH_Hour_19
# Classifier trained for option NORTH_Hour_20
# Classifier trained for option NORTH_Hour_21
# Classifier trained for option NORTH_Hour_22
# Classifier trained for option NORTH_Hour_23
# Classifier trained for option WEST_Hour_0
# Classifier trained for option WEST_Hour_1
# Classifier trained for option WEST_Hour_2
# Classifier trained for option WEST_Hour_3
# Classifier trained for option WEST_Hour_4
# Classifier trained for option WEST_Hour_5
# Classifier trained for option WEST_Hour_6
# Classifier trained for option WEST_Hour_7
# Classifier trained for option WEST_Hour_8
# Classifier trained for option WEST_Hour_9
# Classifier trained for option WEST_Hour_10
# Classifier trained for option WEST_Hour_11
# Classifier trained for option WEST_Hour_12
# Classifier trained for option WEST_Hour_13
# Classifier trained for option WEST_Hour_14
# Classifier trained for option WEST_Hour_15
# Classifier trained for option WEST_Hour_16
# Classifier trained for option WEST_Hour_17
# Classifier trained for option WEST_Hour_18
# Classifier trained for option WEST_Hour_19
# Classifier trained for option WEST_Hour_20
# Classifier trained for option WEST_Hour_21
# Classifier trained for option WEST_Hour_22
# Classifier trained for option WEST_Hour_23
#
# Overall training accuracy = 98.71 percent.

# %%
# First, load the test data from NYISO for the year 2016. Again, utilize our function
# named 'loadNYISOData'.

print("Starting the testing module...\n")
testPriceDA, testPriceDART, testLoadDA = loadNYISOData(2016)

# Create the data for the classifier using the function 'createClassifierIO'.
testX, testY, rangeOfDays = createClassifierIO(testPriceDA, testPriceDART, testLoadDA)

# The next step is not useful for implementing the trading strategy, but quickly check how accurate
# your trained classifiers are for the test data. Training accuracy is not always indicative of
# test accuracy.

testingAccuracy = [classifiers[ii].score(testX, testY[:, ii]) for ii in range(nOptions)]
print("Test Accuracy Stats: Min = %.2f%%, Avg = %.2f%%, Max = %.2f%%" %
      (100 * np.min(testingAccuracy),
       100 * np.mean(testingAccuracy),
       100 * np.max(testingAccuracy)))

# Utilize the classifiers to predict the sign of DA - RT prices for each day in 'rangeOfDays' for
# the test data. Store the result in a pandas data frame with columns as the option names and the
# day in year as index.
predictedY = pd.DataFrame(np.column_stack([classifiers[ii].predict(testX) for ii in range(nOptions)]),
                          columns=optionNames, index=rangeOfDays)
# Out:
# Starting the testing module...
#
# Test Accuracy Stats: Min = 46.83%, Avg = 57.17%, Max = 67.22%

# %%
dailyBudget = 250000
quantileOffer =0.95

# Keep track of your rewards in each day, a cumulative reward over the year, and a total reward over the
# year. Also, keep track of the total reward from each option. Store them as dictionaries that are
# indexed by day of the year.
reward = {}
cumulativeReward = {}
totalReward = 0
optionReturn = dict((option, 0) for option in optionNames)

# Implement the trading strategy on each day!

for day in rangeOfDays:

    reward[day] = 0

    # Find the options that your classifier says that should be profitable. Store the profitable option
    # names in chosenOptions.
    chosenOptionNumbers = np.ravel(list(np.nonzero(predictedY.loc[day].values)))
    if np.size(chosenOptionNumbers) == 0:
        continue
    chosenOptions = [optionNames[i] for i in chosenOptionNumbers]

    # Design the portfolio based on average price spreads. Our strategy is that as long as you have not
    # exceeded your daily budget, pick an option from the list of 'chosenOptions' probabilistically, where
    # the probability of choosing it is proportional to exponential(historical rewards of that option). That
    # is, a historically profitable option is chosen more often than one that is not. Keep sampling and
    # decreasing your budget with each bid.

    # Start with an empty portfolio.

    portfolio = dict((option, 0) for option in chosenOptions)

    # Calculate the probabilities of choosing each option among the list 'chosenOptions'. Recall that
    # 'chosenOptions' contains the options that your classifier indicates as being profitable.
    priceSpreads = [1.0 * averagePriceSpread[option] for option in chosenOptions]
    probabilityOptions = [np.exp(p) for p in priceSpreads]
    probabilityOptions /= np.sum(probabilityOptions)

    # Start with your daily budget.
    budget = dailyBudget

    # Sampling among the profitable options and bid based on them.
    while budget > np.median([offerPrices[quantileOffer][option] for option in chosenOptions]):

        optionToBuy = choice(chosenOptions, p=probabilityOptions)

        if budget >= offerPrices[quantileOffer][optionToBuy]:
            portfolio[optionToBuy] += 1
            budget -= offerPrices[quantileOffer][optionToBuy]

    # Compute the reward from the day. Go through each of the options you have decided to buy.
    # If the DA price is lower than the bid price, then your bid is cleared. For each option you
    # have bought, you get a reward equal to the DA - RT price.

    for option in chosenOptions:
        if testPriceDA.at[day, option] < offerPrices[quantileOffer][option]:
            rewardOptionDay = testPriceDART.at[day, option] * portfolio[option]
            optionReturn[option] += rewardOptionDay
            reward[day] += rewardOptionDay

    totalReward += reward[day]

    # Calculate the cumulative reward in millions of dollars.
    cumulativeReward[day] = totalReward/1000000

    print("Day " + str(day) + ": Reward (in $) = " + "{0:,.0f}".format(reward[day]))

print("Total money earned over the year (in $) = " + "{0:,.0f}".format(totalReward))
# Out:
# Day 3: Reward (in $) = 47,832
# Day 4: Reward (in $) = 956,372
# Day 5: Reward (in $) = 15,999
# Day 6: Reward (in $) = -43,063
# Day 7: Reward (in $) = -20,311
# Day 8: Reward (in $) = 504
# Day 9: Reward (in $) = -25,729
# Day 10: Reward (in $) = -66,725
# Day 11: Reward (in $) = -42,890
# Day 12: Reward (in $) = -6,864
# Day 13: Reward (in $) = -16,461
# Day 14: Reward (in $) = -24,537
# Day 15: Reward (in $) = -361
# Day 16: Reward (in $) = 20,806
# Day 17: Reward (in $) = -42,332
# Day 18: Reward (in $) = -14,554
# Day 19: Reward (in $) = 8,574
# Day 20: Reward (in $) = -583
# Day 21: Reward (in $) = 10,112
# Day 22: Reward (in $) = 79,836
# Day 23: Reward (in $) = 22,402
# Day 24: Reward (in $) = -58,065
# Day 25: Reward (in $) = -57,971
# Day 26: Reward (in $) = -11,780
# Day 27: Reward (in $) = -2,986
# Day 28: Reward (in $) = -8,156
# Day 29: Reward (in $) = -13,201
# Day 30: Reward (in $) = -22,896
# Day 31: Reward (in $) = -31,253
# Day 32: Reward (in $) = -6,962
# Day 33: Reward (in $) = -34,980
# Day 34: Reward (in $) = 2,895
# Day 35: Reward (in $) = 6,822
# Day 36: Reward (in $) = -17,631
# Day 37: Reward (in $) = -25,546
# Day 38: Reward (in $) = 17,379
# Day 39: Reward (in $) = 12,633
# Day 40: Reward (in $) = -14,464
# Day 41: Reward (in $) = 14,108
# Day 42: Reward (in $) = -9,179
# Day 43: Reward (in $) = -27,834
# Day 44: Reward (in $) = -14,269
# Day 45: Reward (in $) = -11,493
# Day 46: Reward (in $) = 55,534
# Day 47: Reward (in $) = 35,509
# Day 48: Reward (in $) = -36,170
# Day 49: Reward (in $) = -26,126
# Day 50: Reward (in $) = -21,882
# Day 51: Reward (in $) = -310
# Day 52: Reward (in $) = -15,280
# Day 53: Reward (in $) = -9,123
# Day 54: Reward (in $) = -733
# Day 55: Reward (in $) = -2,258
# Day 56: Reward (in $) = -26,758
# Day 57: Reward (in $) = -17,344
# Day 58: Reward (in $) = -14,133
# Day 59: Reward (in $) = -10,394
# Day 60: Reward (in $) = -8,219
# Day 61: Reward (in $) = -69,733
# Day 62: Reward (in $) = -35,045
# Day 63: Reward (in $) = -9,330
# Day 64: Reward (in $) = -28,030
# Day 65: Reward (in $) = 23,265
# Day 66: Reward (in $) = 42,626
# Day 67: Reward (in $) = -29,829
# Day 68: Reward (in $) = -36,859
# Day 69: Reward (in $) = -12,616
# Day 70: Reward (in $) = 83,877
# Day 71: Reward (in $) = -3,442
# Day 72: Reward (in $) = -6,390
# Day 73: Reward (in $) = -35,540
# Day 74: Reward (in $) = -19,975
# Day 75: Reward (in $) = -2,219
# Day 76: Reward (in $) = -60,086
# Day 77: Reward (in $) = -11,520
# Day 78: Reward (in $) = -14,897
# Day 79: Reward (in $) = -18,789
# Day 80: Reward (in $) = -26,074
# Day 81: Reward (in $) = 20,806
# Day 82: Reward (in $) = 16,131
# Day 83: Reward (in $) = -4,257
# Day 84: Reward (in $) = -1,729
# Day 85: Reward (in $) = 10,602
# Day 86: Reward (in $) = -17,355
# Day 87: Reward (in $) = 1,589,056
# Day 88: Reward (in $) = 580,666
# Day 89: Reward (in $) = -8,871
# Day 90: Reward (in $) = 68,206
# Day 91: Reward (in $) = -67,742
# Day 92: Reward (in $) = 44,764
# Day 93: Reward (in $) = -975
# Day 94: Reward (in $) = -4,204
# Day 95: Reward (in $) = -55,634
# Day 96: Reward (in $) = 49,964
# Day 97: Reward (in $) = 8,991
# Day 98: Reward (in $) = -3,181
# Day 99: Reward (in $) = -69,645
# Day 100: Reward (in $) = -22,338
# Day 101: Reward (in $) = -9,433
# Day 102: Reward (in $) = -48,982
# Day 103: Reward (in $) = 372,157
# Day 104: Reward (in $) = -21,044
# Day 105: Reward (in $) = -43,029
# Day 106: Reward (in $) = -8,532
# Day 107: Reward (in $) = -15,993
# Day 108: Reward (in $) = -2,744
# Day 109: Reward (in $) = -39,168
# Day 110: Reward (in $) = -17,739
# Day 111: Reward (in $) = -16,106
# Day 112: Reward (in $) = 72,390
# Day 113: Reward (in $) = -22,157
# Day 114: Reward (in $) = -31,769
# Day 115: Reward (in $) = -68,188
# Day 116: Reward (in $) = 4,643
# Day 117: Reward (in $) = -7,425
# Day 118: Reward (in $) = 2,810
# Day 119: Reward (in $) = -4,128
# Day 120: Reward (in $) = 9,190
# Day 121: Reward (in $) = 30,720
# Day 122: Reward (in $) = -58,345
# Day 123: Reward (in $) = -85,862
# Day 124: Reward (in $) = -21,446
# Day 125: Reward (in $) = -17,497
# Day 126: Reward (in $) = -2,435
# Day 127: Reward (in $) = -19,746
# Day 128: Reward (in $) = -14,253
# Day 129: Reward (in $) = -18,911
# Day 130: Reward (in $) = -5,189
# Day 131: Reward (in $) = 4,941
# Day 132: Reward (in $) = 35,018
# Day 133: Reward (in $) = 23,706
# Day 134: Reward (in $) = -29,405
# Day 135: Reward (in $) = -7,779
# Day 136: Reward (in $) = -25,312
# Day 137: Reward (in $) = -28,696
# Day 138: Reward (in $) = -66,158
# Day 139: Reward (in $) = -1,349
# Day 140: Reward (in $) = -35,721
# Day 141: Reward (in $) = 16,252
# Day 142: Reward (in $) = 16,386
# Day 143: Reward (in $) = -5,980
# Day 144: Reward (in $) = -22,290
# Day 145: Reward (in $) = -22,695
# Day 146: Reward (in $) = -5,417
# Day 147: Reward (in $) = -42,485
# Day 148: Reward (in $) = -7,945
# Day 149: Reward (in $) = -4,338
# Day 150: Reward (in $) = 33,675
# Day 151: Reward (in $) = 511,640
# Day 152: Reward (in $) = 229,131
# Day 153: Reward (in $) = 47,433
# Day 154: Reward (in $) = 1,530
# Day 155: Reward (in $) = -25,702
# Day 156: Reward (in $) = -18,628
# Day 157: Reward (in $) = -87,248
# Day 158: Reward (in $) = -33,238
# Day 159: Reward (in $) = -22,998
# Day 160: Reward (in $) = -71,263
# Day 161: Reward (in $) = -24,970
# Day 162: Reward (in $) = 273,052
# Day 163: Reward (in $) = -9,107
# Day 164: Reward (in $) = -5,572
# Day 165: Reward (in $) = 331,160
# Day 166: Reward (in $) = 245,868
# Day 167: Reward (in $) = 267,436
# Day 168: Reward (in $) = -27,990
# Day 169: Reward (in $) = -83,271
# Day 170: Reward (in $) = -50,741
# Day 171: Reward (in $) = -2,722
# Day 172: Reward (in $) = -15,975
# Day 173: Reward (in $) = 7,178
# Day 174: Reward (in $) = -16,390
# Day 175: Reward (in $) = -16,666
# Day 176: Reward (in $) = -14,716
# Day 177: Reward (in $) = -16,740
# Day 178: Reward (in $) = -14,588
# Day 179: Reward (in $) = -85,499
# Day 180: Reward (in $) = -50,074
# Day 181: Reward (in $) = -100,741
# Day 182: Reward (in $) = -6,055
# Day 183: Reward (in $) = -42,677
# Day 184: Reward (in $) = -67,640
# Day 185: Reward (in $) = -27,874
# Day 186: Reward (in $) = 20,325
# Day 187: Reward (in $) = 10,352
# Day 188: Reward (in $) = -7,501
# Day 189: Reward (in $) = -12,067
# Day 190: Reward (in $) = -62,022
# Day 191: Reward (in $) = -10,903
# Day 192: Reward (in $) = -10,233
# Day 193: Reward (in $) = -47,957
# Day 194: Reward (in $) = -25,680
# Day 195: Reward (in $) = 3,168
# Day 196: Reward (in $) = 165
# Day 197: Reward (in $) = 7,134
# Day 198: Reward (in $) = 17,284
# Day 199: Reward (in $) = -44,811
# Day 200: Reward (in $) = -52,415
# Day 201: Reward (in $) = -43,562
# Day 202: Reward (in $) = -8,153
# Day 203: Reward (in $) = 13,552
# Day 204: Reward (in $) = 7,877
# Day 205: Reward (in $) = -14,811
# Day 206: Reward (in $) = -7,967
# Day 207: Reward (in $) = 86,719
# Day 208: Reward (in $) = 6,400
# Day 209: Reward (in $) = 10,495
# Day 210: Reward (in $) = 114,472
# Day 211: Reward (in $) = 25,572
# Day 212: Reward (in $) = 34,732
# Day 213: Reward (in $) = -112,506
# Day 214: Reward (in $) = -39,994
# Day 215: Reward (in $) = -44,589
# Day 216: Reward (in $) = -44,388
# Day 217: Reward (in $) = -27,724
# Day 218: Reward (in $) = 15,898
# Day 219: Reward (in $) = -18,199
# Day 220: Reward (in $) = -33,079
# Day 221: Reward (in $) = -14,920
# Day 222: Reward (in $) = 24,815
# Day 223: Reward (in $) = 71,339
# Day 224: Reward (in $) = 13,984
# Day 225: Reward (in $) = 118,956
# Day 226: Reward (in $) = -32,378
# Day 227: Reward (in $) = 43,873
# Day 228: Reward (in $) = -20,330
# Day 229: Reward (in $) = -29,500
# Day 230: Reward (in $) = -656
# Day 231: Reward (in $) = -2,803
# Day 232: Reward (in $) = -33,735
# Day 233: Reward (in $) = -30,481
# Day 234: Reward (in $) = -46,616
# Day 235: Reward (in $) = -84,496
# Day 236: Reward (in $) = 13,076
# Day 237: Reward (in $) = 23,471
# Day 238: Reward (in $) = 6,078
# Day 239: Reward (in $) = -22,928
# Day 240: Reward (in $) = -10,170
# Day 241: Reward (in $) = -3,303
# Day 242: Reward (in $) = 24,620
# Day 243: Reward (in $) = -96,397
# Day 244: Reward (in $) = 2,191
# Day 245: Reward (in $) = -40,992
# Day 246: Reward (in $) = -18,724
# Day 247: Reward (in $) = -2,640
# Day 248: Reward (in $) = -20,596
# Day 249: Reward (in $) = -11,230
# Day 250: Reward (in $) = -40,469
# Day 251: Reward (in $) = -6,417
# Day 252: Reward (in $) = 127
# Day 253: Reward (in $) = 72,482
# Day 254: Reward (in $) = -8,955
# Day 255: Reward (in $) = -90,403
# Day 256: Reward (in $) = -102,393
# Day 257: Reward (in $) = 55,755
# Day 258: Reward (in $) = -13,287
# Day 259: Reward (in $) = -18,313
# Day 260: Reward (in $) = -19,646
# Day 261: Reward (in $) = 41,162
# Day 262: Reward (in $) = -40,504
# Day 263: Reward (in $) = -963
# Day 264: Reward (in $) = -65,083
# Day 265: Reward (in $) = -4,962
# Day 266: Reward (in $) = -65,256
# Day 267: Reward (in $) = -4,948
# Day 268: Reward (in $) = -13,880
# Day 269: Reward (in $) = -52,143
# Day 270: Reward (in $) = -40,929
# Day 271: Reward (in $) = -4,919
# Day 272: Reward (in $) = -12,963
# Day 273: Reward (in $) = -26,334
# Day 274: Reward (in $) = 13,736
# Day 275: Reward (in $) = 14,122
# Day 276: Reward (in $) = -13,339
# Day 277: Reward (in $) = 23,645
# Day 278: Reward (in $) = 81,652
# Day 279: Reward (in $) = -734
# Day 280: Reward (in $) = -87,035
# Day 281: Reward (in $) = -7,159
# Day 282: Reward (in $) = 7,550
# Day 283: Reward (in $) = -10,650
# Day 284: Reward (in $) = -16,230
# Day 285: Reward (in $) = 7,184
# Day 286: Reward (in $) = -31,411
# Day 287: Reward (in $) = -36,475
# Day 288: Reward (in $) = 2,595
# Day 289: Reward (in $) = 3,173
# Day 290: Reward (in $) = -25,621
# Day 291: Reward (in $) = -91,556
# Day 292: Reward (in $) = 90,666
# Day 293: Reward (in $) = 46,155
# Day 294: Reward (in $) = -7,247
# Day 295: Reward (in $) = 3,688
# Day 296: Reward (in $) = -32,646
# Day 297: Reward (in $) = -18,549
# Day 298: Reward (in $) = 92,565
# Day 299: Reward (in $) = -37,039
# Day 300: Reward (in $) = -10,069
# Day 301: Reward (in $) = -4,215
# Day 302: Reward (in $) = -13,259
# Day 303: Reward (in $) = 8,406
# Day 304: Reward (in $) = -56,742
# Day 305: Reward (in $) = -9,186
# Day 306: Reward (in $) = -10,710
# Day 307: Reward (in $) = -4,843
# Day 308: Reward (in $) = -28,646
# Day 309: Reward (in $) = 2,410
# Day 310: Reward (in $) = -3,309
# Day 311: Reward (in $) = -21,841
# Day 312: Reward (in $) = 31,396
# Day 313: Reward (in $) = -1,184
# Day 314: Reward (in $) = -38,275
# Day 315: Reward (in $) = -30,910
# Day 316: Reward (in $) = -7,433
# Day 317: Reward (in $) = -21,042
# Day 318: Reward (in $) = -11,273
# Day 319: Reward (in $) = 1,773
# Day 320: Reward (in $) = 9,691
# Day 321: Reward (in $) = 6,523
# Day 322: Reward (in $) = -3,265
# Day 323: Reward (in $) = 4,557
# Day 324: Reward (in $) = 9,983
# Day 325: Reward (in $) = -15,801
# Day 326: Reward (in $) = -6,459
# Day 327: Reward (in $) = -7,112
# Day 328: Reward (in $) = 37,200
# Day 329: Reward (in $) = 22,988
# Day 330: Reward (in $) = 3,822
# Day 331: Reward (in $) = -7,820
# Day 332: Reward (in $) = -29,371
# Day 333: Reward (in $) = -26,231
# Day 334: Reward (in $) = -976
# Day 335: Reward (in $) = -13,464
# Day 336: Reward (in $) = -11,405
# Day 337: Reward (in $) = 11,861
# Day 338: Reward (in $) = -5,597
# Day 339: Reward (in $) = -20,788
# Day 340: Reward (in $) = -22,847
# Day 341: Reward (in $) = -31,860
# Day 342: Reward (in $) = -58,777
# Day 343: Reward (in $) = -59,109
# Day 344: Reward (in $) = 98,536
# Day 345: Reward (in $) = 41,183
# Day 346: Reward (in $) = 315
# Day 347: Reward (in $) = 2,585
# Day 348: Reward (in $) = -24,864
# Day 349: Reward (in $) = 48,796
# Day 350: Reward (in $) = 4,928
# Day 351: Reward (in $) = 47,792
# Day 352: Reward (in $) = 33,206
# Day 353: Reward (in $) = -11,651
# Day 354: Reward (in $) = -28,810
# Day 355: Reward (in $) = -30,939
# Day 356: Reward (in $) = -15,118
# Day 357: Reward (in $) = -22,578
# Day 358: Reward (in $) = -3,039
# Day 359: Reward (in $) = -6,743
# Day 360: Reward (in $) = -20,203
# Day 361: Reward (in $) = -41,238
# Day 362: Reward (in $) = 11,986
# Day 363: Reward (in $) = 162,475
# Day 364: Reward (in $) = -430
# Day 365: Reward (in $) = -9,646
# Total money earned over the year (in $) = 1,825,928

# %% [markdown]
# ### Task 4: Daily budget (25 points)
#
# We used a daily budget of 250,000. Try different budgets, let's say, 100,000, 150,000, 200,000, and 300,000. Rank them in terms of profits (low to high). Fix the quantile to the one that led to maximum profits in the previous task.
#
# #### (comments here, add a new code cell below)
# 100,000: $1,431,493
#
# 150,000: $2,127,473
#
# 200,000: $2,809,937
#
# 300,000: $4,276,427
#
# 100,000 < 150,000 < 200,000 < 300,000 in terms of profits from low to high. As we have observed, dailyBudget increases, corresponding profit also follows its trend and becomes larger.

# %%
dailyBudget = 100000
quantileOffer =0.70

# Keep track of your rewards in each day, a cumulative reward over the year, and a total reward over the
# year. Also, keep track of the total reward from each option. Store them as dictionaries that are
# indexed by day of the year.
reward = {}
cumulativeReward = {}
totalReward = 0
optionReturn = dict((option, 0) for option in optionNames)

# Implement the trading strategy on each day!

for day in rangeOfDays:

    reward[day] = 0

    # Find the options that your classifier says that should be profitable. Store the profitable option
    # names in chosenOptions.
    chosenOptionNumbers = np.ravel(list(np.nonzero(predictedY.loc[day].values)))
    if np.size(chosenOptionNumbers) == 0:
        continue
    chosenOptions = [optionNames[i] for i in chosenOptionNumbers]

    # Design the portfolio based on average price spreads. Our strategy is that as long as you have not
    # exceeded your daily budget, pick an option from the list of 'chosenOptions' probabilistically, where
    # the probability of choosing it is proportional to exponential(historical rewards of that option). That
    # is, a historically profitable option is chosen more often than one that is not. Keep sampling and
    # decreasing your budget with each bid.

    # Start with an empty portfolio.

    portfolio = dict((option, 0) for option in chosenOptions)

    # Calculate the probabilities of choosing each option among the list 'chosenOptions'. Recall that
    # 'chosenOptions' contains the options that your classifier indicates as being profitable.
    priceSpreads = [1.0 * averagePriceSpread[option] for option in chosenOptions]
    probabilityOptions = [np.exp(p) for p in priceSpreads]
    probabilityOptions /= np.sum(probabilityOptions)

    # Start with your daily budget.
    budget = dailyBudget

    # Sampling among the profitable options and bid based on them.
    while budget > np.median([offerPrices[quantileOffer][option] for option in chosenOptions]):

        optionToBuy = choice(chosenOptions, p=probabilityOptions)

        if budget >= offerPrices[quantileOffer][optionToBuy]:
            portfolio[optionToBuy] += 1
            budget -= offerPrices[quantileOffer][optionToBuy]

    # Compute the reward from the day. Go through each of the options you have decided to buy.
    # If the DA price is lower than the bid price, then your bid is cleared. For each option you
    # have bought, you get a reward equal to the DA - RT price.

    for option in chosenOptions:
        if testPriceDA.at[day, option] < offerPrices[quantileOffer][option]:
            rewardOptionDay = testPriceDART.at[day, option] * portfolio[option]
            optionReturn[option] += rewardOptionDay
            reward[day] += rewardOptionDay

    totalReward += reward[day]

    # Calculate the cumulative reward in millions of dollars.
    cumulativeReward[day] = totalReward/1000000

    print("Day " + str(day) + ": Reward (in $) = " + "{0:,.0f}".format(reward[day]))

print("Total money earned over the year (in $) = " + "{0:,.0f}".format(totalReward))
# Out:
# Day 3: Reward (in $) = -21,263
# Day 4: Reward (in $) = 657,567
# Day 5: Reward (in $) = 12,023
# Day 6: Reward (in $) = -1,337
# Day 7: Reward (in $) = -13,941
# Day 8: Reward (in $) = 7
# Day 9: Reward (in $) = -18,421
# Day 10: Reward (in $) = -46,573
# Day 11: Reward (in $) = -29,081
# Day 12: Reward (in $) = -2,496
# Day 13: Reward (in $) = -13,922
# Day 14: Reward (in $) = -17,294
# Day 15: Reward (in $) = -454
# Day 16: Reward (in $) = 24,548
# Day 17: Reward (in $) = -30,610
# Day 18: Reward (in $) = -10,272
# Day 19: Reward (in $) = 218
# Day 20: Reward (in $) = -3,092
# Day 21: Reward (in $) = 12,223
# Day 22: Reward (in $) = 53,451
# Day 23: Reward (in $) = 12,361
# Day 24: Reward (in $) = -37,965
# Day 25: Reward (in $) = -39,352
# Day 26: Reward (in $) = -8,508
# Day 27: Reward (in $) = -3,017
# Day 28: Reward (in $) = -5,514
# Day 29: Reward (in $) = -9,787
# Day 30: Reward (in $) = -15,706
# Day 31: Reward (in $) = -20,947
# Day 32: Reward (in $) = -5,117
# Day 33: Reward (in $) = -25,881
# Day 34: Reward (in $) = 4,284
# Day 35: Reward (in $) = 6,566
# Day 36: Reward (in $) = -12,914
# Day 37: Reward (in $) = -17,469
# Day 38: Reward (in $) = 12,941
# Day 39: Reward (in $) = 8,343
# Day 40: Reward (in $) = -15,342
# Day 41: Reward (in $) = 1,595
# Day 42: Reward (in $) = -6,286
# Day 43: Reward (in $) = -13,010
# Day 44: Reward (in $) = -9,179
# Day 45: Reward (in $) = -9,482
# Day 46: Reward (in $) = 35,781
# Day 47: Reward (in $) = 24,079
# Day 48: Reward (in $) = -22,351
# Day 49: Reward (in $) = -20,699
# Day 50: Reward (in $) = -23,664
# Day 51: Reward (in $) = -232
# Day 52: Reward (in $) = -11,096
# Day 53: Reward (in $) = -6,491
# Day 54: Reward (in $) = -596
# Day 55: Reward (in $) = -1,592
# Day 56: Reward (in $) = -19,503
# Day 57: Reward (in $) = -12,733
# Day 58: Reward (in $) = -11,669
# Day 59: Reward (in $) = -7,268
# Day 60: Reward (in $) = -5,667
# Day 61: Reward (in $) = -8,286
# Day 62: Reward (in $) = -796
# Day 63: Reward (in $) = -2,750
# Day 64: Reward (in $) = -6,723
# Day 65: Reward (in $) = 16,775
# Day 66: Reward (in $) = 33,180
# Day 67: Reward (in $) = -24,227
# Day 68: Reward (in $) = -29,359
# Day 69: Reward (in $) = -14,540
# Day 70: Reward (in $) = 61,788
# Day 71: Reward (in $) = -2,616
# Day 72: Reward (in $) = -4,082
# Day 73: Reward (in $) = -23,165
# Day 74: Reward (in $) = -20,933
# Day 75: Reward (in $) = -1,397
# Day 76: Reward (in $) = -42,397
# Day 77: Reward (in $) = -6,930
# Day 78: Reward (in $) = -17,276
# Day 79: Reward (in $) = -17,763
# Day 80: Reward (in $) = -18,466
# Day 81: Reward (in $) = 14,034
# Day 82: Reward (in $) = 11,106
# Day 83: Reward (in $) = -4,982
# Day 84: Reward (in $) = -2,425
# Day 85: Reward (in $) = 10,752
# Day 86: Reward (in $) = -12,958
# Day 87: Reward (in $) = 1,208,708
# Day 88: Reward (in $) = 412,298
# Day 89: Reward (in $) = -10,415
# Day 90: Reward (in $) = 3,359
# Day 91: Reward (in $) = -51,695
# Day 92: Reward (in $) = 34,797
# Day 93: Reward (in $) = -256
# Day 94: Reward (in $) = 4,133
# Day 95: Reward (in $) = -10,417
# Day 96: Reward (in $) = 29,203
# Day 97: Reward (in $) = 13,479
# Day 98: Reward (in $) = -3,360
# Day 99: Reward (in $) = -11,058
# Day 100: Reward (in $) = -16,381
# Day 101: Reward (in $) = -10,038
# Day 102: Reward (in $) = -17,833
# Day 103: Reward (in $) = 28,356
# Day 104: Reward (in $) = -15,130
# Day 105: Reward (in $) = -31,664
# Day 106: Reward (in $) = -6,862
# Day 107: Reward (in $) = -11,014
# Day 108: Reward (in $) = 12,020
# Day 109: Reward (in $) = -133
# Day 110: Reward (in $) = -13,673
# Day 111: Reward (in $) = -15,028
# Day 112: Reward (in $) = 50,365
# Day 113: Reward (in $) = -18,283
# Day 114: Reward (in $) = -28,411
# Day 115: Reward (in $) = -54,952
# Day 116: Reward (in $) = 10,443
# Day 117: Reward (in $) = -5,640
# Day 118: Reward (in $) = 2,141
# Day 119: Reward (in $) = -2
# Day 120: Reward (in $) = 7,202
# Day 121: Reward (in $) = 23,509
# Day 122: Reward (in $) = 414
# Day 123: Reward (in $) = -7,696
# Day 124: Reward (in $) = -18,761
# Day 125: Reward (in $) = -14,187
# Day 126: Reward (in $) = -3,065
# Day 127: Reward (in $) = -17,442
# Day 128: Reward (in $) = -15,962
# Day 129: Reward (in $) = -19,281
# Day 130: Reward (in $) = -5,650
# Day 131: Reward (in $) = 6,054
# Day 132: Reward (in $) = 24,057
# Day 133: Reward (in $) = 29,676
# Day 134: Reward (in $) = -22,619
# Day 135: Reward (in $) = -7,942
# Day 136: Reward (in $) = -19,746
# Day 137: Reward (in $) = -21,813
# Day 138: Reward (in $) = -45,855
# Day 139: Reward (in $) = -1,071
# Day 140: Reward (in $) = -21,881
# Day 141: Reward (in $) = 11,930
# Day 142: Reward (in $) = 11,552
# Day 143: Reward (in $) = -5,408
# Day 144: Reward (in $) = -17,296
# Day 145: Reward (in $) = -23,029
# Day 146: Reward (in $) = -952
# Day 147: Reward (in $) = -25,125
# Day 148: Reward (in $) = -6,337
# Day 149: Reward (in $) = -3,512
# Day 150: Reward (in $) = 25,150
# Day 151: Reward (in $) = 243,567
# Day 152: Reward (in $) = 174,458
# Day 153: Reward (in $) = 63,842
# Day 154: Reward (in $) = 1,407
# Day 155: Reward (in $) = -18,556
# Day 156: Reward (in $) = -14,971
# Day 157: Reward (in $) = -56,930
# Day 158: Reward (in $) = -37,075
# Day 159: Reward (in $) = -16,087
# Day 160: Reward (in $) = -53,603
# Day 161: Reward (in $) = -22,159
# Day 162: Reward (in $) = 194,833
# Day 163: Reward (in $) = -7,740
# Day 164: Reward (in $) = -6,471
# Day 165: Reward (in $) = -2,504
# Day 166: Reward (in $) = 1,592
# Day 167: Reward (in $) = 3,860
# Day 168: Reward (in $) = 3,006
# Day 169: Reward (in $) = 3,292
# Day 170: Reward (in $) = -14,093
# Day 171: Reward (in $) = -1,300
# Day 172: Reward (in $) = -2,224
# Day 173: Reward (in $) = 8,634
# Day 174: Reward (in $) = 7,175
# Day 175: Reward (in $) = 8,744
# Day 176: Reward (in $) = -7,104
# Day 177: Reward (in $) = -4,923
# Day 178: Reward (in $) = -2,567
# Day 179: Reward (in $) = -7,051
# Day 180: Reward (in $) = -69
# Day 181: Reward (in $) = -1,488
# Day 182: Reward (in $) = -6,225
# Day 183: Reward (in $) = -31,300
# Day 184: Reward (in $) = -44,845
# Day 185: Reward (in $) = -20,959
# Day 186: Reward (in $) = 6,189
# Day 187: Reward (in $) = 802
# Day 188: Reward (in $) = 2
# Day 189: Reward (in $) = 0
# Day 190: Reward (in $) = -43,650
# Day 191: Reward (in $) = -11,465
# Day 192: Reward (in $) = -11,278
# Day 193: Reward (in $) = -5,184
# Day 194: Reward (in $) = 257
# Day 195: Reward (in $) = 2,521
# Day 196: Reward (in $) = 5,611
# Day 197: Reward (in $) = 6,018
# Day 198: Reward (in $) = 18,422
# Day 199: Reward (in $) = 196
# Day 200: Reward (in $) = -34,121
# Day 201: Reward (in $) = -2,946
# Day 202: Reward (in $) = -438
# Day 203: Reward (in $) = 3,112
# Day 204: Reward (in $) = 202
# Day 205: Reward (in $) = -3,384
# Day 206: Reward (in $) = -136
# Day 207: Reward (in $) = -560
# Day 208: Reward (in $) = -620
# Day 209: Reward (in $) = 5,741
# Day 210: Reward (in $) = 9,627
# Day 211: Reward (in $) = 21,248
# Day 212: Reward (in $) = 24,749
# Day 213: Reward (in $) = -1,950
# Day 214: Reward (in $) = -2,483
# Day 215: Reward (in $) = -31,192
# Day 216: Reward (in $) = 606
# Day 217: Reward (in $) = 1,498
# Day 218: Reward (in $) = 8,715
# Day 219: Reward (in $) = -9,330
# Day 220: Reward (in $) = -1,048
# Day 221: Reward (in $) = -12,551
# Day 222: Reward (in $) = 1,684
# Day 223: Reward (in $) = 54
# Day 224: Reward (in $) = 0
# Day 225: Reward (in $) = -139
# Day 226: Reward (in $) = -16,469
# Day 227: Reward (in $) = -134
# Day 228: Reward (in $) = 3,689
# Day 229: Reward (in $) = 3,039
# Day 230: Reward (in $) = -329
# Day 231: Reward (in $) = 53
# Day 232: Reward (in $) = -4,772
# Day 233: Reward (in $) = -23,017
# Day 234: Reward (in $) = -36,687
# Day 235: Reward (in $) = -17,619
# Day 236: Reward (in $) = 8,028
# Day 237: Reward (in $) = 27,187
# Day 238: Reward (in $) = -321
# Day 239: Reward (in $) = -6,470
# Day 240: Reward (in $) = -2,636
# Day 241: Reward (in $) = -282
# Day 242: Reward (in $) = 2,686
# Day 243: Reward (in $) = 485
# Day 244: Reward (in $) = 2,932
# Day 245: Reward (in $) = -32,145
# Day 246: Reward (in $) = -17,785
# Day 247: Reward (in $) = -2,677
# Day 248: Reward (in $) = -15,057
# Day 249: Reward (in $) = -406
# Day 250: Reward (in $) = -44
# Day 251: Reward (in $) = -53
# Day 252: Reward (in $) = -3,654
# Day 253: Reward (in $) = 60,649
# Day 254: Reward (in $) = -5,909
# Day 255: Reward (in $) = -428
# Day 256: Reward (in $) = -1,709
# Day 257: Reward (in $) = -3,061
# Day 258: Reward (in $) = -10,600
# Day 259: Reward (in $) = -18,638
# Day 260: Reward (in $) = -13,928
# Day 261: Reward (in $) = 31,180
# Day 262: Reward (in $) = 2,505
# Day 263: Reward (in $) = -13,578
# Day 264: Reward (in $) = -1,565
# Day 265: Reward (in $) = -1,550
# Day 266: Reward (in $) = -1,386
# Day 267: Reward (in $) = -3,786
# Day 268: Reward (in $) = -10,000
# Day 269: Reward (in $) = -37,631
# Day 270: Reward (in $) = -31,589
# Day 271: Reward (in $) = -3,863
# Day 272: Reward (in $) = -12,388
# Day 273: Reward (in $) = -19,133
# Day 274: Reward (in $) = 10,116
# Day 275: Reward (in $) = 10,599
# Day 276: Reward (in $) = -9,876
# Day 277: Reward (in $) = 20,089
# Day 278: Reward (in $) = 61,068
# Day 279: Reward (in $) = 9,349
# Day 280: Reward (in $) = 611
# Day 281: Reward (in $) = -5,054
# Day 282: Reward (in $) = 5,621
# Day 283: Reward (in $) = -1,515
# Day 284: Reward (in $) = -14,750
# Day 285: Reward (in $) = 8,605
# Day 286: Reward (in $) = -24,408
# Day 287: Reward (in $) = -29,422
# Day 288: Reward (in $) = 2,071
# Day 289: Reward (in $) = 2,420
# Day 290: Reward (in $) = 4,113
# Day 291: Reward (in $) = -2,848
# Day 292: Reward (in $) = -373
# Day 293: Reward (in $) = 30,135
# Day 294: Reward (in $) = -5,300
# Day 295: Reward (in $) = 2,682
# Day 296: Reward (in $) = -21,557
# Day 297: Reward (in $) = -14,599
# Day 298: Reward (in $) = 57,912
# Day 299: Reward (in $) = -26,709
# Day 300: Reward (in $) = -9,394
# Day 301: Reward (in $) = -3,296
# Day 302: Reward (in $) = -9,673
# Day 303: Reward (in $) = 6,152
# Day 304: Reward (in $) = -12,785
# Day 305: Reward (in $) = -6,733
# Day 306: Reward (in $) = -7,810
# Day 307: Reward (in $) = -3,121
# Day 308: Reward (in $) = -19,685
# Day 309: Reward (in $) = 837
# Day 310: Reward (in $) = -2,136
# Day 311: Reward (in $) = -14,726
# Day 312: Reward (in $) = 24,584
# Day 313: Reward (in $) = -658
# Day 314: Reward (in $) = -26,228
# Day 315: Reward (in $) = -22,162
# Day 316: Reward (in $) = -5,523
# Day 317: Reward (in $) = -15,472
# Day 318: Reward (in $) = -7,711
# Day 319: Reward (in $) = 1,293
# Day 320: Reward (in $) = 7,139
# Day 321: Reward (in $) = 4,620
# Day 322: Reward (in $) = -2,349
# Day 323: Reward (in $) = 3,529
# Day 324: Reward (in $) = 7,033
# Day 325: Reward (in $) = -12,451
# Day 326: Reward (in $) = -4,383
# Day 327: Reward (in $) = -6,316
# Day 328: Reward (in $) = 25,539
# Day 329: Reward (in $) = 15,409
# Day 330: Reward (in $) = 1,591
# Day 331: Reward (in $) = -5,884
# Day 332: Reward (in $) = -20,211
# Day 333: Reward (in $) = -18,787
# Day 334: Reward (in $) = -1,942
# Day 335: Reward (in $) = -9,199
# Day 336: Reward (in $) = -7,794
# Day 337: Reward (in $) = 7,896
# Day 338: Reward (in $) = -4,318
# Day 339: Reward (in $) = -6,714
# Day 340: Reward (in $) = -2,740
# Day 341: Reward (in $) = -23,579
# Day 342: Reward (in $) = -49,363
# Day 343: Reward (in $) = -56,748
# Day 344: Reward (in $) = 76,895
# Day 345: Reward (in $) = 34,717
# Day 346: Reward (in $) = -13,522
# Day 347: Reward (in $) = 2,907
# Day 348: Reward (in $) = -13,906
# Day 349: Reward (in $) = 34,720
# Day 350: Reward (in $) = -2,015
# Day 351: Reward (in $) = 28,023
# Day 352: Reward (in $) = 17,570
# Day 353: Reward (in $) = 0
# Day 354: Reward (in $) = -20,161
# Day 355: Reward (in $) = -27,929
# Day 356: Reward (in $) = -8,719
# Day 357: Reward (in $) = -13,543
# Day 358: Reward (in $) = 653
# Day 359: Reward (in $) = -5,866
# Day 360: Reward (in $) = -14,497
# Day 361: Reward (in $) = -33,307
# Day 362: Reward (in $) = 10,189
# Day 363: Reward (in $) = 123,806
# Day 364: Reward (in $) = 1,642
# Day 365: Reward (in $) = -6,684
# Total money earned over the year (in $) = 1,431,493

# %%
dailyBudget = 150000
quantileOffer =0.70

# Keep track of your rewards in each day, a cumulative reward over the year, and a total reward over the
# year. Also, keep track of the total reward from each option. Store them as dictionaries that are
# indexed by day of the year.
reward = {}
cumulativeReward = {}
totalReward = 0
optionReturn = dict((option, 0) for option in optionNames)

# Implement the trading strategy on each day!

for day in rangeOfDays:

    reward[day] = 0

    # Find the options that your classifier says that should be profitable. Store the profitable option
    # names in chosenOptions.
    chosenOptionNumbers = np.ravel(list(np.nonzero(predictedY.loc[day].values)))
    if np.size(chosenOptionNumbers) == 0:
        continue
    chosenOptions = [optionNames[i] for i in chosenOptionNumbers]

    # Design the portfolio based on average price spreads. Our strategy is that as long as you have not
    # exceeded your daily budget, pick an option from the list of 'chosenOptions' probabilistically, where
    # the probability of choosing it is proportional to exponential(historical rewards of that option). That
    # is, a historically profitable option is chosen more often than one that is not. Keep sampling and
    # decreasing your budget with each bid.

    # Start with an empty portfolio.

    portfolio = dict((option, 0) for option in chosenOptions)

    # Calculate the probabilities of choosing each option among the list 'chosenOptions'. Recall that
    # 'chosenOptions' contains the options that your classifier indicates as being profitable.
    priceSpreads = [1.0 * averagePriceSpread[option] for option in chosenOptions]
    probabilityOptions = [np.exp(p) for p in priceSpreads]
    probabilityOptions /= np.sum(probabilityOptions)

    # Start with your daily budget.
    budget = dailyBudget

    # Sampling among the profitable options and bid based on them.
    while budget > np.median([offerPrices[quantileOffer][option] for option in chosenOptions]):

        optionToBuy = choice(chosenOptions, p=probabilityOptions)

        if budget >= offerPrices[quantileOffer][optionToBuy]:
            portfolio[optionToBuy] += 1
            budget -= offerPrices[quantileOffer][optionToBuy]

    # Compute the reward from the day. Go through each of the options you have decided to buy.
    # If the DA price is lower than the bid price, then your bid is cleared. For each option you
    # have bought, you get a reward equal to the DA - RT price.

    for option in chosenOptions:
        if testPriceDA.at[day, option] < offerPrices[quantileOffer][option]:
            rewardOptionDay = testPriceDART.at[day, option] * portfolio[option]
            optionReturn[option] += rewardOptionDay
            reward[day] += rewardOptionDay

    totalReward += reward[day]

    # Calculate the cumulative reward in millions of dollars.
    cumulativeReward[day] = totalReward/1000000

    print("Day " + str(day) + ": Reward (in $) = " + "{0:,.0f}".format(reward[day]))

print("Total money earned over the year (in $) = " + "{0:,.0f}".format(totalReward))
# Out:
# Day 3: Reward (in $) = -31,996
# Day 4: Reward (in $) = 1,005,334
# Day 5: Reward (in $) = 17,876
# Day 6: Reward (in $) = -1,927
# Day 7: Reward (in $) = -20,924
# Day 8: Reward (in $) = 602
# Day 9: Reward (in $) = -27,499
# Day 10: Reward (in $) = -69,626
# Day 11: Reward (in $) = -43,442
# Day 12: Reward (in $) = -4,021
# Day 13: Reward (in $) = -21,303
# Day 14: Reward (in $) = -25,488
# Day 15: Reward (in $) = 134
# Day 16: Reward (in $) = 35,662
# Day 17: Reward (in $) = -46,211
# Day 18: Reward (in $) = -16,132
# Day 19: Reward (in $) = 360
# Day 20: Reward (in $) = -4,358
# Day 21: Reward (in $) = 17,232
# Day 22: Reward (in $) = 79,591
# Day 23: Reward (in $) = 18,089
# Day 24: Reward (in $) = -56,577
# Day 25: Reward (in $) = -58,773
# Day 26: Reward (in $) = -12,771
# Day 27: Reward (in $) = -4,998
# Day 28: Reward (in $) = -8,236
# Day 29: Reward (in $) = -15,027
# Day 30: Reward (in $) = -23,370
# Day 31: Reward (in $) = -31,382
# Day 32: Reward (in $) = -7,775
# Day 33: Reward (in $) = -39,190
# Day 34: Reward (in $) = 5,451
# Day 35: Reward (in $) = 10,131
# Day 36: Reward (in $) = -19,448
# Day 37: Reward (in $) = -26,311
# Day 38: Reward (in $) = 19,278
# Day 39: Reward (in $) = 12,277
# Day 40: Reward (in $) = -23,992
# Day 41: Reward (in $) = 279
# Day 42: Reward (in $) = -9,846
# Day 43: Reward (in $) = -19,491
# Day 44: Reward (in $) = -14,512
# Day 45: Reward (in $) = -13,293
# Day 46: Reward (in $) = 54,809
# Day 47: Reward (in $) = 34,830
# Day 48: Reward (in $) = -36,310
# Day 49: Reward (in $) = -30,457
# Day 50: Reward (in $) = -35,703
# Day 51: Reward (in $) = -967
# Day 52: Reward (in $) = -17,389
# Day 53: Reward (in $) = -9,617
# Day 54: Reward (in $) = -276
# Day 55: Reward (in $) = -3,268
# Day 56: Reward (in $) = -29,560
# Day 57: Reward (in $) = -19,076
# Day 58: Reward (in $) = -17,411
# Day 59: Reward (in $) = -10,938
# Day 60: Reward (in $) = -7,724
# Day 61: Reward (in $) = -12,496
# Day 62: Reward (in $) = -995
# Day 63: Reward (in $) = -4,467
# Day 64: Reward (in $) = -8,796
# Day 65: Reward (in $) = 25,029
# Day 66: Reward (in $) = 49,889
# Day 67: Reward (in $) = -37,171
# Day 68: Reward (in $) = -43,642
# Day 69: Reward (in $) = -21,818
# Day 70: Reward (in $) = 95,145
# Day 71: Reward (in $) = -4,241
# Day 72: Reward (in $) = -5,853
# Day 73: Reward (in $) = -37,565
# Day 74: Reward (in $) = -32,343
# Day 75: Reward (in $) = -2,797
# Day 76: Reward (in $) = -63,297
# Day 77: Reward (in $) = -10,746
# Day 78: Reward (in $) = -25,989
# Day 79: Reward (in $) = -26,865
# Day 80: Reward (in $) = -27,254
# Day 81: Reward (in $) = 19,914
# Day 82: Reward (in $) = 18,002
# Day 83: Reward (in $) = -7,751
# Day 84: Reward (in $) = -2,768
# Day 85: Reward (in $) = 16,155
# Day 86: Reward (in $) = -19,477
# Day 87: Reward (in $) = 1,819,634
# Day 88: Reward (in $) = 611,055
# Day 89: Reward (in $) = -17,891
# Day 90: Reward (in $) = 7,730
# Day 91: Reward (in $) = -78,307
# Day 92: Reward (in $) = 51,147
# Day 93: Reward (in $) = -423
# Day 94: Reward (in $) = 5,190
# Day 95: Reward (in $) = -16,108
# Day 96: Reward (in $) = 43,352
# Day 97: Reward (in $) = 19,728
# Day 98: Reward (in $) = -5,956
# Day 99: Reward (in $) = -16,640
# Day 100: Reward (in $) = -24,878
# Day 101: Reward (in $) = -15,339
# Day 102: Reward (in $) = -26,515
# Day 103: Reward (in $) = 39,870
# Day 104: Reward (in $) = -21,485
# Day 105: Reward (in $) = -47,768
# Day 106: Reward (in $) = -8,264
# Day 107: Reward (in $) = -16,057
# Day 108: Reward (in $) = 18,054
# Day 109: Reward (in $) = -258
# Day 110: Reward (in $) = -21,874
# Day 111: Reward (in $) = -22,415
# Day 112: Reward (in $) = 74,159
# Day 113: Reward (in $) = -26,722
# Day 114: Reward (in $) = -43,206
# Day 115: Reward (in $) = -82,290
# Day 116: Reward (in $) = 16,656
# Day 117: Reward (in $) = -8,784
# Day 118: Reward (in $) = 3,510
# Day 119: Reward (in $) = 343
# Day 120: Reward (in $) = 10,011
# Day 121: Reward (in $) = 34,886
# Day 122: Reward (in $) = 628
# Day 123: Reward (in $) = -11,250
# Day 124: Reward (in $) = -28,850
# Day 125: Reward (in $) = -21,422
# Day 126: Reward (in $) = -4,432
# Day 127: Reward (in $) = -26,260
# Day 128: Reward (in $) = -22,902
# Day 129: Reward (in $) = -27,534
# Day 130: Reward (in $) = -7,966
# Day 131: Reward (in $) = 9,131
# Day 132: Reward (in $) = 35,626
# Day 133: Reward (in $) = 44,653
# Day 134: Reward (in $) = -34,320
# Day 135: Reward (in $) = -12,309
# Day 136: Reward (in $) = -29,366
# Day 137: Reward (in $) = -32,125
# Day 138: Reward (in $) = -68,131
# Day 139: Reward (in $) = -1,699
# Day 140: Reward (in $) = -43,423
# Day 141: Reward (in $) = 17,702
# Day 142: Reward (in $) = 17,621
# Day 143: Reward (in $) = -8,706
# Day 144: Reward (in $) = -26,591
# Day 145: Reward (in $) = -34,531
# Day 146: Reward (in $) = -1,896
# Day 147: Reward (in $) = -38,781
# Day 148: Reward (in $) = -9,073
# Day 149: Reward (in $) = -5,391
# Day 150: Reward (in $) = 38,385
# Day 151: Reward (in $) = 317,505
# Day 152: Reward (in $) = 256,079
# Day 153: Reward (in $) = 95,571
# Day 154: Reward (in $) = 3,847
# Day 155: Reward (in $) = -27,900
# Day 156: Reward (in $) = -22,314
# Day 157: Reward (in $) = -85,485
# Day 158: Reward (in $) = -55,472
# Day 159: Reward (in $) = -24,207
# Day 160: Reward (in $) = -81,036
# Day 161: Reward (in $) = -32,261
# Day 162: Reward (in $) = 314,028
# Day 163: Reward (in $) = -10,651
# Day 164: Reward (in $) = -9,573
# Day 165: Reward (in $) = -2,634
# Day 166: Reward (in $) = 2,027
# Day 167: Reward (in $) = 6,760
# Day 168: Reward (in $) = 4,650
# Day 169: Reward (in $) = 5,132
# Day 170: Reward (in $) = -22,348
# Day 171: Reward (in $) = -1,590
# Day 172: Reward (in $) = -4,120
# Day 173: Reward (in $) = 13,343
# Day 174: Reward (in $) = 11,132
# Day 175: Reward (in $) = 12,435
# Day 176: Reward (in $) = -10,324
# Day 177: Reward (in $) = -7,400
# Day 178: Reward (in $) = -3,759
# Day 179: Reward (in $) = -10,191
# Day 180: Reward (in $) = 58
# Day 181: Reward (in $) = -2,016
# Day 182: Reward (in $) = -8,568
# Day 183: Reward (in $) = -47,412
# Day 184: Reward (in $) = -67,356
# Day 185: Reward (in $) = -31,755
# Day 186: Reward (in $) = 11,774
# Day 187: Reward (in $) = 1,761
# Day 188: Reward (in $) = 4
# Day 189: Reward (in $) = 0
# Day 190: Reward (in $) = -65,245
# Day 191: Reward (in $) = -17,252
# Day 192: Reward (in $) = -15,935
# Day 193: Reward (in $) = -7,590
# Day 194: Reward (in $) = 487
# Day 195: Reward (in $) = 4,158
# Day 196: Reward (in $) = 8,895
# Day 197: Reward (in $) = 9,082
# Day 198: Reward (in $) = 27,554
# Day 199: Reward (in $) = 389
# Day 200: Reward (in $) = -50,767
# Day 201: Reward (in $) = -3,497
# Day 202: Reward (in $) = -1,247
# Day 203: Reward (in $) = 5,328
# Day 204: Reward (in $) = 270
# Day 205: Reward (in $) = -4,772
# Day 206: Reward (in $) = -123
# Day 207: Reward (in $) = -796
# Day 208: Reward (in $) = -837
# Day 209: Reward (in $) = 8,636
# Day 210: Reward (in $) = 16,215
# Day 211: Reward (in $) = 32,016
# Day 212: Reward (in $) = 38,260
# Day 213: Reward (in $) = -2,722
# Day 214: Reward (in $) = -4,053
# Day 215: Reward (in $) = -46,969
# Day 216: Reward (in $) = 703
# Day 217: Reward (in $) = 2,435
# Day 218: Reward (in $) = 12,709
# Day 219: Reward (in $) = -14,156
# Day 220: Reward (in $) = -1,485
# Day 221: Reward (in $) = -18,430
# Day 222: Reward (in $) = 3,127
# Day 223: Reward (in $) = 68
# Day 224: Reward (in $) = 0
# Day 225: Reward (in $) = -115
# Day 226: Reward (in $) = -24,582
# Day 227: Reward (in $) = -149
# Day 228: Reward (in $) = 6,079
# Day 229: Reward (in $) = 5,155
# Day 230: Reward (in $) = -479
# Day 231: Reward (in $) = 43
# Day 232: Reward (in $) = -7,508
# Day 233: Reward (in $) = -34,180
# Day 234: Reward (in $) = -55,155
# Day 235: Reward (in $) = -24,223
# Day 236: Reward (in $) = 11,771
# Day 237: Reward (in $) = 42,150
# Day 238: Reward (in $) = -400
# Day 239: Reward (in $) = -11,006
# Day 240: Reward (in $) = -4,146
# Day 241: Reward (in $) = -163
# Day 242: Reward (in $) = 3,926
# Day 243: Reward (in $) = 670
# Day 244: Reward (in $) = 4,726
# Day 245: Reward (in $) = -48,373
# Day 246: Reward (in $) = -26,487
# Day 247: Reward (in $) = -3,671
# Day 248: Reward (in $) = -22,746
# Day 249: Reward (in $) = -30
# Day 250: Reward (in $) = 156
# Day 251: Reward (in $) = -82
# Day 252: Reward (in $) = -7,148
# Day 253: Reward (in $) = 89,983
# Day 254: Reward (in $) = -8,320
# Day 255: Reward (in $) = -745
# Day 256: Reward (in $) = -2,746
# Day 257: Reward (in $) = -4,459
# Day 258: Reward (in $) = -15,943
# Day 259: Reward (in $) = -28,020
# Day 260: Reward (in $) = -20,681
# Day 261: Reward (in $) = 46,100
# Day 262: Reward (in $) = 3,883
# Day 263: Reward (in $) = -19,587
# Day 264: Reward (in $) = -2,575
# Day 265: Reward (in $) = -2,311
# Day 266: Reward (in $) = -692
# Day 267: Reward (in $) = -6,172
# Day 268: Reward (in $) = -15,080
# Day 269: Reward (in $) = -56,276
# Day 270: Reward (in $) = -47,611
# Day 271: Reward (in $) = -5,369
# Day 272: Reward (in $) = -18,399
# Day 273: Reward (in $) = -29,164
# Day 274: Reward (in $) = 15,106
# Day 275: Reward (in $) = 15,982
# Day 276: Reward (in $) = -13,795
# Day 277: Reward (in $) = 26,243
# Day 278: Reward (in $) = 92,885
# Day 279: Reward (in $) = 15,312
# Day 280: Reward (in $) = 997
# Day 281: Reward (in $) = -7,574
# Day 282: Reward (in $) = 8,291
# Day 283: Reward (in $) = -1,486
# Day 284: Reward (in $) = -21,175
# Day 285: Reward (in $) = 12,610
# Day 286: Reward (in $) = -36,334
# Day 287: Reward (in $) = -42,134
# Day 288: Reward (in $) = 2,490
# Day 289: Reward (in $) = 3,504
# Day 290: Reward (in $) = 7,221
# Day 291: Reward (in $) = -4,335
# Day 292: Reward (in $) = -945
# Day 293: Reward (in $) = 45,852
# Day 294: Reward (in $) = -7,861
# Day 295: Reward (in $) = 4,407
# Day 296: Reward (in $) = -32,403
# Day 297: Reward (in $) = -22,278
# Day 298: Reward (in $) = 92,280
# Day 299: Reward (in $) = -40,020
# Day 300: Reward (in $) = -13,797
# Day 301: Reward (in $) = -4,475
# Day 302: Reward (in $) = -14,303
# Day 303: Reward (in $) = 8,792
# Day 304: Reward (in $) = -20,016
# Day 305: Reward (in $) = -10,238
# Day 306: Reward (in $) = -11,413
# Day 307: Reward (in $) = -4,528
# Day 308: Reward (in $) = -29,362
# Day 309: Reward (in $) = 2,058
# Day 310: Reward (in $) = -3,328
# Day 311: Reward (in $) = -21,830
# Day 312: Reward (in $) = 31,429
# Day 313: Reward (in $) = -1,029
# Day 314: Reward (in $) = -38,777
# Day 315: Reward (in $) = -32,840
# Day 316: Reward (in $) = -8,179
# Day 317: Reward (in $) = -23,141
# Day 318: Reward (in $) = -11,535
# Day 319: Reward (in $) = 1,471
# Day 320: Reward (in $) = 10,605
# Day 321: Reward (in $) = 6,539
# Day 322: Reward (in $) = -3,241
# Day 323: Reward (in $) = 5,010
# Day 324: Reward (in $) = 10,670
# Day 325: Reward (in $) = -18,864
# Day 326: Reward (in $) = -6,698
# Day 327: Reward (in $) = -9,684
# Day 328: Reward (in $) = 38,778
# Day 329: Reward (in $) = 23,100
# Day 330: Reward (in $) = 3,502
# Day 331: Reward (in $) = -8,795
# Day 332: Reward (in $) = -30,049
# Day 333: Reward (in $) = -28,793
# Day 334: Reward (in $) = -2,279
# Day 335: Reward (in $) = -13,713
# Day 336: Reward (in $) = -11,708
# Day 337: Reward (in $) = 12,296
# Day 338: Reward (in $) = -6,138
# Day 339: Reward (in $) = -10,117
# Day 340: Reward (in $) = -4,261
# Day 341: Reward (in $) = -34,844
# Day 342: Reward (in $) = -74,746
# Day 343: Reward (in $) = -84,478
# Day 344: Reward (in $) = 115,501
# Day 345: Reward (in $) = 51,752
# Day 346: Reward (in $) = -19,889
# Day 347: Reward (in $) = 5,238
# Day 348: Reward (in $) = -20,484
# Day 349: Reward (in $) = 50,543
# Day 350: Reward (in $) = -2,856
# Day 351: Reward (in $) = 41,821
# Day 352: Reward (in $) = 25,593
# Day 353: Reward (in $) = 0
# Day 354: Reward (in $) = -30,030
# Day 355: Reward (in $) = -41,925
# Day 356: Reward (in $) = -13,097
# Day 357: Reward (in $) = -20,166
# Day 358: Reward (in $) = -1
# Day 359: Reward (in $) = -8,842
# Day 360: Reward (in $) = -21,983
# Day 361: Reward (in $) = -49,386
# Day 362: Reward (in $) = 15,129
# Day 363: Reward (in $) = 182,045
# Day 364: Reward (in $) = 3,273
# Day 365: Reward (in $) = -10,747
# Total money earned over the year (in $) = 2,127,473

# %%
dailyBudget = 200000
quantileOffer =0.70

# Keep track of your rewards in each day, a cumulative reward over the year, and a total reward over the
# year. Also, keep track of the total reward from each option. Store them as dictionaries that are
# indexed by day of the year.
reward = {}
cumulativeReward = {}
totalReward = 0
optionReturn = dict((option, 0) for option in optionNames)

# Implement the trading strategy on each day!

for day in rangeOfDays:

    reward[day] = 0

    # Find the options that your classifier says that should be profitable. Store the profitable option
    # names in chosenOptions.
    chosenOptionNumbers = np.ravel(list(np.nonzero(predictedY.loc[day].values)))
    if np.size(chosenOptionNumbers) == 0:
        continue
    chosenOptions = [optionNames[i] for i in chosenOptionNumbers]

    # Design the portfolio based on average price spreads. Our strategy is that as long as you have not
    # exceeded your daily budget, pick an option from the list of 'chosenOptions' probabilistically, where
    # the probability of choosing it is proportional to exponential(historical rewards of that option). That
    # is, a historically profitable option is chosen more often than one that is not. Keep sampling and
    # decreasing your budget with each bid.

    # Start with an empty portfolio.

    portfolio = dict((option, 0) for option in chosenOptions)

    # Calculate the probabilities of choosing each option among the list 'chosenOptions'. Recall that
    # 'chosenOptions' contains the options that your classifier indicates as being profitable.
    priceSpreads = [1.0 * averagePriceSpread[option] for option in chosenOptions]
    probabilityOptions = [np.exp(p) for p in priceSpreads]
    probabilityOptions /= np.sum(probabilityOptions)

    # Start with your daily budget.
    budget = dailyBudget

    # Sampling among the profitable options and bid based on them.
    while budget > np.median([offerPrices[quantileOffer][option] for option in chosenOptions]):

        optionToBuy = choice(chosenOptions, p=probabilityOptions)

        if budget >= offerPrices[quantileOffer][optionToBuy]:
            portfolio[optionToBuy] += 1
            budget -= offerPrices[quantileOffer][optionToBuy]

    # Compute the reward from the day. Go through each of the options you have decided to buy.
    # If the DA price is lower than the bid price, then your bid is cleared. For each option you
    # have bought, you get a reward equal to the DA - RT price.

    for option in chosenOptions:
        if testPriceDA.at[day, option] < offerPrices[quantileOffer][option]:
            rewardOptionDay = testPriceDART.at[day, option] * portfolio[option]
            optionReturn[option] += rewardOptionDay
            reward[day] += rewardOptionDay

    totalReward += reward[day]

    # Calculate the cumulative reward in millions of dollars.
    cumulativeReward[day] = totalReward/1000000

    print("Day " + str(day) + ": Reward (in $) = " + "{0:,.0f}".format(reward[day]))

print("Total money earned over the year (in $) = " + "{0:,.0f}".format(totalReward))
# Out:
# Day 3: Reward (in $) = -42,616
# Day 4: Reward (in $) = 1,271,908
# Day 5: Reward (in $) = 23,922
# Day 6: Reward (in $) = -2,966
# Day 7: Reward (in $) = -28,248
# Day 8: Reward (in $) = 241
# Day 9: Reward (in $) = -35,665
# Day 10: Reward (in $) = -92,860
# Day 11: Reward (in $) = -57,311
# Day 12: Reward (in $) = -5,270
# Day 13: Reward (in $) = -27,657
# Day 14: Reward (in $) = -34,502
# Day 15: Reward (in $) = -689
# Day 16: Reward (in $) = 46,904
# Day 17: Reward (in $) = -62,154
# Day 18: Reward (in $) = -20,487
# Day 19: Reward (in $) = 129
# Day 20: Reward (in $) = -5,196
# Day 21: Reward (in $) = 23,650
# Day 22: Reward (in $) = 108,215
# Day 23: Reward (in $) = 24,391
# Day 24: Reward (in $) = -76,412
# Day 25: Reward (in $) = -78,566
# Day 26: Reward (in $) = -17,625
# Day 27: Reward (in $) = -6,297
# Day 28: Reward (in $) = -10,952
# Day 29: Reward (in $) = -19,908
# Day 30: Reward (in $) = -31,321
# Day 31: Reward (in $) = -41,871
# Day 32: Reward (in $) = -10,291
# Day 33: Reward (in $) = -51,876
# Day 34: Reward (in $) = 7,731
# Day 35: Reward (in $) = 13,602
# Day 36: Reward (in $) = -25,927
# Day 37: Reward (in $) = -34,652
# Day 38: Reward (in $) = 25,884
# Day 39: Reward (in $) = 16,146
# Day 40: Reward (in $) = -31,541
# Day 41: Reward (in $) = 872
# Day 42: Reward (in $) = -13,690
# Day 43: Reward (in $) = -26,319
# Day 44: Reward (in $) = -18,546
# Day 45: Reward (in $) = -18,425
# Day 46: Reward (in $) = 70,588
# Day 47: Reward (in $) = 48,510
# Day 48: Reward (in $) = -48,232
# Day 49: Reward (in $) = -40,556
# Day 50: Reward (in $) = -47,344
# Day 51: Reward (in $) = -676
# Day 52: Reward (in $) = -23,248
# Day 53: Reward (in $) = -13,117
# Day 54: Reward (in $) = -555
# Day 55: Reward (in $) = -3,270
# Day 56: Reward (in $) = -39,429
# Day 57: Reward (in $) = -25,491
# Day 58: Reward (in $) = -23,718
# Day 59: Reward (in $) = -14,877
# Day 60: Reward (in $) = -12,710
# Day 61: Reward (in $) = -16,891
# Day 62: Reward (in $) = -1,783
# Day 63: Reward (in $) = -7,108
# Day 64: Reward (in $) = -12,941
# Day 65: Reward (in $) = 34,088
# Day 66: Reward (in $) = 65,236
# Day 67: Reward (in $) = -48,291
# Day 68: Reward (in $) = -58,701
# Day 69: Reward (in $) = -29,447
# Day 70: Reward (in $) = 122,961
# Day 71: Reward (in $) = -5,220
# Day 72: Reward (in $) = -7,349
# Day 73: Reward (in $) = -48,582
# Day 74: Reward (in $) = -43,641
# Day 75: Reward (in $) = -3,047
# Day 76: Reward (in $) = -84,691
# Day 77: Reward (in $) = -14,387
# Day 78: Reward (in $) = -34,656
# Day 79: Reward (in $) = -35,873
# Day 80: Reward (in $) = -35,155
# Day 81: Reward (in $) = 27,929
# Day 82: Reward (in $) = 23,399
# Day 83: Reward (in $) = -9,747
# Day 84: Reward (in $) = -4,627
# Day 85: Reward (in $) = 19,928
# Day 86: Reward (in $) = -26,084
# Day 87: Reward (in $) = 2,443,846
# Day 88: Reward (in $) = 823,721
# Day 89: Reward (in $) = -21,951
# Day 90: Reward (in $) = 5,858
# Day 91: Reward (in $) = -103,570
# Day 92: Reward (in $) = 69,765
# Day 93: Reward (in $) = -1,330
# Day 94: Reward (in $) = 6,776
# Day 95: Reward (in $) = -22,489
# Day 96: Reward (in $) = 58,375
# Day 97: Reward (in $) = 26,473
# Day 98: Reward (in $) = -7,939
# Day 99: Reward (in $) = -21,706
# Day 100: Reward (in $) = -33,310
# Day 101: Reward (in $) = -19,432
# Day 102: Reward (in $) = -35,346
# Day 103: Reward (in $) = 53,020
# Day 104: Reward (in $) = -29,006
# Day 105: Reward (in $) = -63,132
# Day 106: Reward (in $) = -11,738
# Day 107: Reward (in $) = -21,477
# Day 108: Reward (in $) = 25,425
# Day 109: Reward (in $) = -344
# Day 110: Reward (in $) = -28,196
# Day 111: Reward (in $) = -30,187
# Day 112: Reward (in $) = 98,585
# Day 113: Reward (in $) = -36,841
# Day 114: Reward (in $) = -57,365
# Day 115: Reward (in $) = -109,737
# Day 116: Reward (in $) = 21,849
# Day 117: Reward (in $) = -12,014
# Day 118: Reward (in $) = 4,452
# Day 119: Reward (in $) = 201
# Day 120: Reward (in $) = 14,124
# Day 121: Reward (in $) = 46,472
# Day 122: Reward (in $) = 746
# Day 123: Reward (in $) = -15,136
# Day 124: Reward (in $) = -37,615
# Day 125: Reward (in $) = -28,728
# Day 126: Reward (in $) = -7,589
# Day 127: Reward (in $) = -35,163
# Day 128: Reward (in $) = -30,804
# Day 129: Reward (in $) = -38,156
# Day 130: Reward (in $) = -10,738
# Day 131: Reward (in $) = 12,285
# Day 132: Reward (in $) = 52,131
# Day 133: Reward (in $) = 60,339
# Day 134: Reward (in $) = -45,421
# Day 135: Reward (in $) = -15,793
# Day 136: Reward (in $) = -38,546
# Day 137: Reward (in $) = -43,524
# Day 138: Reward (in $) = -91,204
# Day 139: Reward (in $) = -2,458
# Day 140: Reward (in $) = -48,744
# Day 141: Reward (in $) = 24,037
# Day 142: Reward (in $) = 23,437
# Day 143: Reward (in $) = -11,014
# Day 144: Reward (in $) = -35,441
# Day 145: Reward (in $) = -46,414
# Day 146: Reward (in $) = -2,346
# Day 147: Reward (in $) = -50,933
# Day 148: Reward (in $) = -11,202
# Day 149: Reward (in $) = -6,782
# Day 150: Reward (in $) = 50,811
# Day 151: Reward (in $) = 462,572
# Day 152: Reward (in $) = 346,438
# Day 153: Reward (in $) = 124,721
# Day 154: Reward (in $) = 2,325
# Day 155: Reward (in $) = -36,863
# Day 156: Reward (in $) = -29,468
# Day 157: Reward (in $) = -113,701
# Day 158: Reward (in $) = -73,099
# Day 159: Reward (in $) = -32,307
# Day 160: Reward (in $) = -107,411
# Day 161: Reward (in $) = -43,719
# Day 162: Reward (in $) = 400,242
# Day 163: Reward (in $) = -13,770
# Day 164: Reward (in $) = -12,206
# Day 165: Reward (in $) = -4,765
# Day 166: Reward (in $) = 2,876
# Day 167: Reward (in $) = 9,056
# Day 168: Reward (in $) = 6,525
# Day 169: Reward (in $) = 7,338
# Day 170: Reward (in $) = -29,175
# Day 171: Reward (in $) = -2,600
# Day 172: Reward (in $) = -4,666
# Day 173: Reward (in $) = 16,733
# Day 174: Reward (in $) = 14,946
# Day 175: Reward (in $) = 16,353
# Day 176: Reward (in $) = -14,199
# Day 177: Reward (in $) = -9,382
# Day 178: Reward (in $) = -4,192
# Day 179: Reward (in $) = -14,311
# Day 180: Reward (in $) = -122
# Day 181: Reward (in $) = -2,642
# Day 182: Reward (in $) = -11,395
# Day 183: Reward (in $) = -63,329
# Day 184: Reward (in $) = -89,938
# Day 185: Reward (in $) = -42,312
# Day 186: Reward (in $) = 13,021
# Day 187: Reward (in $) = 2,131
# Day 188: Reward (in $) = 4
# Day 189: Reward (in $) = 0
# Day 190: Reward (in $) = -87,173
# Day 191: Reward (in $) = -22,941
# Day 192: Reward (in $) = -23,173
# Day 193: Reward (in $) = -10,387
# Day 194: Reward (in $) = 509
# Day 195: Reward (in $) = 4,869
# Day 196: Reward (in $) = 11,519
# Day 197: Reward (in $) = 12,184
# Day 198: Reward (in $) = 35,885
# Day 199: Reward (in $) = 660
# Day 200: Reward (in $) = -68,758
# Day 201: Reward (in $) = -5,827
# Day 202: Reward (in $) = -1,500
# Day 203: Reward (in $) = 7,688
# Day 204: Reward (in $) = 366
# Day 205: Reward (in $) = -6,154
# Day 206: Reward (in $) = -303
# Day 207: Reward (in $) = -944
# Day 208: Reward (in $) = -1,131
# Day 209: Reward (in $) = 11,427
# Day 210: Reward (in $) = 20,290
# Day 211: Reward (in $) = 42,605
# Day 212: Reward (in $) = 50,172
# Day 213: Reward (in $) = -3,480
# Day 214: Reward (in $) = -5,109
# Day 215: Reward (in $) = -62,220
# Day 216: Reward (in $) = 1,040
# Day 217: Reward (in $) = 3,104
# Day 218: Reward (in $) = 17,552
# Day 219: Reward (in $) = -18,802
# Day 220: Reward (in $) = -2,125
# Day 221: Reward (in $) = -25,260
# Day 222: Reward (in $) = 4,203
# Day 223: Reward (in $) = 105
# Day 224: Reward (in $) = 0
# Day 225: Reward (in $) = -205
# Day 226: Reward (in $) = -32,645
# Day 227: Reward (in $) = -176
# Day 228: Reward (in $) = 8,422
# Day 229: Reward (in $) = 6,146
# Day 230: Reward (in $) = -691
# Day 231: Reward (in $) = 274
# Day 232: Reward (in $) = -10,048
# Day 233: Reward (in $) = -45,384
# Day 234: Reward (in $) = -72,755
# Day 235: Reward (in $) = -32,593
# Day 236: Reward (in $) = 16,059
# Day 237: Reward (in $) = 55,314
# Day 238: Reward (in $) = -559
# Day 239: Reward (in $) = -14,366
# Day 240: Reward (in $) = -5,435
# Day 241: Reward (in $) = -349
# Day 242: Reward (in $) = 5,666
# Day 243: Reward (in $) = 756
# Day 244: Reward (in $) = 6,588
# Day 245: Reward (in $) = -64,878
# Day 246: Reward (in $) = -35,241
# Day 247: Reward (in $) = -5,338
# Day 248: Reward (in $) = -30,547
# Day 249: Reward (in $) = -589
# Day 250: Reward (in $) = 60
# Day 251: Reward (in $) = -87
# Day 252: Reward (in $) = -8,572
# Day 253: Reward (in $) = 119,457
# Day 254: Reward (in $) = -10,607
# Day 255: Reward (in $) = -779
# Day 256: Reward (in $) = -3,595
# Day 257: Reward (in $) = -5,316
# Day 258: Reward (in $) = -22,284
# Day 259: Reward (in $) = -37,265
# Day 260: Reward (in $) = -28,019
# Day 261: Reward (in $) = 61,950
# Day 262: Reward (in $) = 5,947
# Day 263: Reward (in $) = -26,099
# Day 264: Reward (in $) = -3,502
# Day 265: Reward (in $) = -3,520
# Day 266: Reward (in $) = -1,645
# Day 267: Reward (in $) = -7,937
# Day 268: Reward (in $) = -19,934
# Day 269: Reward (in $) = -75,483
# Day 270: Reward (in $) = -63,941
# Day 271: Reward (in $) = -8,386
# Day 272: Reward (in $) = -25,173
# Day 273: Reward (in $) = -38,658
# Day 274: Reward (in $) = 20,066
# Day 275: Reward (in $) = 21,460
# Day 276: Reward (in $) = -18,035
# Day 277: Reward (in $) = 36,138
# Day 278: Reward (in $) = 123,417
# Day 279: Reward (in $) = 20,879
# Day 280: Reward (in $) = 1,338
# Day 281: Reward (in $) = -10,066
# Day 282: Reward (in $) = 10,966
# Day 283: Reward (in $) = -2,434
# Day 284: Reward (in $) = -29,073
# Day 285: Reward (in $) = 16,651
# Day 286: Reward (in $) = -49,081
# Day 287: Reward (in $) = -57,798
# Day 288: Reward (in $) = 3,715
# Day 289: Reward (in $) = 4,878
# Day 290: Reward (in $) = 8,858
# Day 291: Reward (in $) = -5,737
# Day 292: Reward (in $) = -1,083
# Day 293: Reward (in $) = 60,646
# Day 294: Reward (in $) = -10,828
# Day 295: Reward (in $) = 5,443
# Day 296: Reward (in $) = -43,776
# Day 297: Reward (in $) = -30,064
# Day 298: Reward (in $) = 120,820
# Day 299: Reward (in $) = -53,814
# Day 300: Reward (in $) = -17,904
# Day 301: Reward (in $) = -6,244
# Day 302: Reward (in $) = -19,491
# Day 303: Reward (in $) = 13,083
# Day 304: Reward (in $) = -26,548
# Day 305: Reward (in $) = -13,299
# Day 306: Reward (in $) = -15,121
# Day 307: Reward (in $) = -5,361
# Day 308: Reward (in $) = -39,156
# Day 309: Reward (in $) = 3,509
# Day 310: Reward (in $) = -4,839
# Day 311: Reward (in $) = -29,135
# Day 312: Reward (in $) = 40,943
# Day 313: Reward (in $) = -1,612
# Day 314: Reward (in $) = -51,607
# Day 315: Reward (in $) = -43,419
# Day 316: Reward (in $) = -10,594
# Day 317: Reward (in $) = -30,489
# Day 318: Reward (in $) = -15,435
# Day 319: Reward (in $) = 2,181
# Day 320: Reward (in $) = 14,435
# Day 321: Reward (in $) = 8,609
# Day 322: Reward (in $) = -4,539
# Day 323: Reward (in $) = 7,004
# Day 324: Reward (in $) = 14,438
# Day 325: Reward (in $) = -24,864
# Day 326: Reward (in $) = -8,768
# Day 327: Reward (in $) = -12,738
# Day 328: Reward (in $) = 51,881
# Day 329: Reward (in $) = 30,338
# Day 330: Reward (in $) = 4,664
# Day 331: Reward (in $) = -12,746
# Day 332: Reward (in $) = -40,257
# Day 333: Reward (in $) = -37,128
# Day 334: Reward (in $) = -3,002
# Day 335: Reward (in $) = -18,292
# Day 336: Reward (in $) = -15,805
# Day 337: Reward (in $) = 16,384
# Day 338: Reward (in $) = -8,002
# Day 339: Reward (in $) = -13,501
# Day 340: Reward (in $) = -5,683
# Day 341: Reward (in $) = -46,689
# Day 342: Reward (in $) = -100,621
# Day 343: Reward (in $) = -112,920
# Day 344: Reward (in $) = 149,618
# Day 345: Reward (in $) = 68,780
# Day 346: Reward (in $) = -27,030
# Day 347: Reward (in $) = 6,238
# Day 348: Reward (in $) = -27,597
# Day 349: Reward (in $) = 68,113
# Day 350: Reward (in $) = -3,950
# Day 351: Reward (in $) = 55,735
# Day 352: Reward (in $) = 34,782
# Day 353: Reward (in $) = 0
# Day 354: Reward (in $) = -39,930
# Day 355: Reward (in $) = -56,037
# Day 356: Reward (in $) = -17,442
# Day 357: Reward (in $) = -26,666
# Day 358: Reward (in $) = 1,120
# Day 359: Reward (in $) = -11,877
# Day 360: Reward (in $) = -29,704
# Day 361: Reward (in $) = -66,990
# Day 362: Reward (in $) = 19,537
# Day 363: Reward (in $) = 248,136
# Day 364: Reward (in $) = 3,973
# Day 365: Reward (in $) = -13,480
# Total money earned over the year (in $) = 2,809,937

# %%
dailyBudget = 300000
quantileOffer =0.70

# Keep track of your rewards in each day, a cumulative reward over the year, and a total reward over the
# year. Also, keep track of the total reward from each option. Store them as dictionaries that are
# indexed by day of the year.
reward = {}
cumulativeReward = {}
totalReward = 0
optionReturn = dict((option, 0) for option in optionNames)

# Implement the trading strategy on each day!

for day in rangeOfDays:

    reward[day] = 0

    # Find the options that your classifier says that should be profitable. Store the profitable option
    # names in chosenOptions.
    chosenOptionNumbers = np.ravel(list(np.nonzero(predictedY.loc[day].values)))
    if np.size(chosenOptionNumbers) == 0:
        continue
    chosenOptions = [optionNames[i] for i in chosenOptionNumbers]

    # Design the portfolio based on average price spreads. Our strategy is that as long as you have not
    # exceeded your daily budget, pick an option from the list of 'chosenOptions' probabilistically, where
    # the probability of choosing it is proportional to exponential(historical rewards of that option). That
    # is, a historically profitable option is chosen more often than one that is not. Keep sampling and
    # decreasing your budget with each bid.

    # Start with an empty portfolio.

    portfolio = dict((option, 0) for option in chosenOptions)

    # Calculate the probabilities of choosing each option among the list 'chosenOptions'. Recall that
    # 'chosenOptions' contains the options that your classifier indicates as being profitable.
    priceSpreads = [1.0 * averagePriceSpread[option] for option in chosenOptions]
    probabilityOptions = [np.exp(p) for p in priceSpreads]
    probabilityOptions /= np.sum(probabilityOptions)

    # Start with your daily budget.
    budget = dailyBudget

    # Sampling among the profitable options and bid based on them.
    while budget > np.median([offerPrices[quantileOffer][option] for option in chosenOptions]):

        optionToBuy = choice(chosenOptions, p=probabilityOptions)

        if budget >= offerPrices[quantileOffer][optionToBuy]:
            portfolio[optionToBuy] += 1
            budget -= offerPrices[quantileOffer][optionToBuy]

    # Compute the reward from the day. Go through each of the options you have decided to buy.
    # If the DA price is lower than the bid price, then your bid is cleared. For each option you
    # have bought, you get a reward equal to the DA - RT price.

    for option in chosenOptions:
        if testPriceDA.at[day, option] < offerPrices[quantileOffer][option]:
            rewardOptionDay = testPriceDART.at[day, option] * portfolio[option]
            optionReturn[option] += rewardOptionDay
            reward[day] += rewardOptionDay

    totalReward += reward[day]

    # Calculate the cumulative reward in millions of dollars.
    cumulativeReward[day] = totalReward/1000000

    print("Day " + str(day) + ": Reward (in $) = " + "{0:,.0f}".format(reward[day]))

print("Total money earned over the year (in $) = " + "{0:,.0f}".format(totalReward))
# Out:
# Day 3: Reward (in $) = -64,908
# Day 4: Reward (in $) = 1,912,258
# Day 5: Reward (in $) = 35,845
# Day 6: Reward (in $) = -3,734
# Day 7: Reward (in $) = -41,220
# Day 8: Reward (in $) = -288
# Day 9: Reward (in $) = -53,392
# Day 10: Reward (in $) = -139,011
# Day 11: Reward (in $) = -88,080
# Day 12: Reward (in $) = -8,059
# Day 13: Reward (in $) = -42,282
# Day 14: Reward (in $) = -50,854
# Day 15: Reward (in $) = -1,097
# Day 16: Reward (in $) = 71,885
# Day 17: Reward (in $) = -92,776
# Day 18: Reward (in $) = -30,992
# Day 19: Reward (in $) = 207
# Day 20: Reward (in $) = -7,460
# Day 21: Reward (in $) = 35,278
# Day 22: Reward (in $) = 165,620
# Day 23: Reward (in $) = 36,786
# Day 24: Reward (in $) = -114,155
# Day 25: Reward (in $) = -118,077
# Day 26: Reward (in $) = -26,124
# Day 27: Reward (in $) = -10,130
# Day 28: Reward (in $) = -16,453
# Day 29: Reward (in $) = -29,868
# Day 30: Reward (in $) = -46,542
# Day 31: Reward (in $) = -62,818
# Day 32: Reward (in $) = -15,734
# Day 33: Reward (in $) = -76,565
# Day 34: Reward (in $) = 11,482
# Day 35: Reward (in $) = 19,003
# Day 36: Reward (in $) = -38,708
# Day 37: Reward (in $) = -52,190
# Day 38: Reward (in $) = 38,936
# Day 39: Reward (in $) = 24,736
# Day 40: Reward (in $) = -46,401
# Day 41: Reward (in $) = 3,596
# Day 42: Reward (in $) = -19,833
# Day 43: Reward (in $) = -39,022
# Day 44: Reward (in $) = -28,133
# Day 45: Reward (in $) = -26,932
# Day 46: Reward (in $) = 109,138
# Day 47: Reward (in $) = 75,104
# Day 48: Reward (in $) = -70,940
# Day 49: Reward (in $) = -61,397
# Day 50: Reward (in $) = -71,610
# Day 51: Reward (in $) = -1,035
# Day 52: Reward (in $) = -34,742
# Day 53: Reward (in $) = -19,789
# Day 54: Reward (in $) = -1,169
# Day 55: Reward (in $) = -5,184
# Day 56: Reward (in $) = -58,877
# Day 57: Reward (in $) = -37,752
# Day 58: Reward (in $) = -36,220
# Day 59: Reward (in $) = -22,322
# Day 60: Reward (in $) = -15,746
# Day 61: Reward (in $) = -24,015
# Day 62: Reward (in $) = -2,285
# Day 63: Reward (in $) = -9,125
# Day 64: Reward (in $) = -18,055
# Day 65: Reward (in $) = 50,696
# Day 66: Reward (in $) = 97,155
# Day 67: Reward (in $) = -72,212
# Day 68: Reward (in $) = -87,348
# Day 69: Reward (in $) = -44,488
# Day 70: Reward (in $) = 186,038
# Day 71: Reward (in $) = -7,770
# Day 72: Reward (in $) = -11,115
# Day 73: Reward (in $) = -73,392
# Day 74: Reward (in $) = -64,890
# Day 75: Reward (in $) = -5,333
# Day 76: Reward (in $) = -125,380
# Day 77: Reward (in $) = -21,564
# Day 78: Reward (in $) = -51,652
# Day 79: Reward (in $) = -54,164
# Day 80: Reward (in $) = -53,360
# Day 81: Reward (in $) = 41,400
# Day 82: Reward (in $) = 33,503
# Day 83: Reward (in $) = -14,024
# Day 84: Reward (in $) = -5,051
# Day 85: Reward (in $) = 29,947
# Day 86: Reward (in $) = -39,196
# Day 87: Reward (in $) = 3,619,297
# Day 88: Reward (in $) = 1,228,736
# Day 89: Reward (in $) = -35,513
# Day 90: Reward (in $) = 7,691
# Day 91: Reward (in $) = -154,914
# Day 92: Reward (in $) = 104,710
# Day 93: Reward (in $) = -1,617
# Day 94: Reward (in $) = 12,095
# Day 95: Reward (in $) = -31,176
# Day 96: Reward (in $) = 82,164
# Day 97: Reward (in $) = 38,149
# Day 98: Reward (in $) = -10,438
# Day 99: Reward (in $) = -32,221
# Day 100: Reward (in $) = -49,340
# Day 101: Reward (in $) = -30,484
# Day 102: Reward (in $) = -52,581
# Day 103: Reward (in $) = 82,749
# Day 104: Reward (in $) = -45,596
# Day 105: Reward (in $) = -94,048
# Day 106: Reward (in $) = -18,084
# Day 107: Reward (in $) = -31,860
# Day 108: Reward (in $) = 39,020
# Day 109: Reward (in $) = -403
# Day 110: Reward (in $) = -42,173
# Day 111: Reward (in $) = -44,798
# Day 112: Reward (in $) = 147,703
# Day 113: Reward (in $) = -54,941
# Day 114: Reward (in $) = -86,140
# Day 115: Reward (in $) = -165,015
# Day 116: Reward (in $) = 34,411
# Day 117: Reward (in $) = -17,349
# Day 118: Reward (in $) = 7,186
# Day 119: Reward (in $) = 855
# Day 120: Reward (in $) = 20,060
# Day 121: Reward (in $) = 70,377
# Day 122: Reward (in $) = 1,267
# Day 123: Reward (in $) = -22,616
# Day 124: Reward (in $) = -56,706
# Day 125: Reward (in $) = -42,753
# Day 126: Reward (in $) = -10,631
# Day 127: Reward (in $) = -53,077
# Day 128: Reward (in $) = -45,566
# Day 129: Reward (in $) = -56,636
# Day 130: Reward (in $) = -16,516
# Day 131: Reward (in $) = 17,982
# Day 132: Reward (in $) = 72,751
# Day 133: Reward (in $) = 88,840
# Day 134: Reward (in $) = -67,805
# Day 135: Reward (in $) = -24,018
# Day 136: Reward (in $) = -57,578
# Day 137: Reward (in $) = -65,163
# Day 138: Reward (in $) = -137,405
# Day 139: Reward (in $) = -2,455
# Day 140: Reward (in $) = -77,077
# Day 141: Reward (in $) = 35,143
# Day 142: Reward (in $) = 35,194
# Day 143: Reward (in $) = -16,559
# Day 144: Reward (in $) = -52,944
# Day 145: Reward (in $) = -67,615
# Day 146: Reward (in $) = -3,671
# Day 147: Reward (in $) = -77,275
# Day 148: Reward (in $) = -17,942
# Day 149: Reward (in $) = -10,368
# Day 150: Reward (in $) = 74,403
# Day 151: Reward (in $) = 734,157
# Day 152: Reward (in $) = 527,972
# Day 153: Reward (in $) = 190,556
# Day 154: Reward (in $) = 6,878
# Day 155: Reward (in $) = -55,675
# Day 156: Reward (in $) = -44,096
# Day 157: Reward (in $) = -170,959
# Day 158: Reward (in $) = -110,329
# Day 159: Reward (in $) = -48,478
# Day 160: Reward (in $) = -160,538
# Day 161: Reward (in $) = -65,103
# Day 162: Reward (in $) = 618,934
# Day 163: Reward (in $) = -20,153
# Day 164: Reward (in $) = -18,424
# Day 165: Reward (in $) = -6,460
# Day 166: Reward (in $) = 3,979
# Day 167: Reward (in $) = 12,782
# Day 168: Reward (in $) = 8,931
# Day 169: Reward (in $) = 10,629
# Day 170: Reward (in $) = -43,407
# Day 171: Reward (in $) = -3,537
# Day 172: Reward (in $) = -6,931
# Day 173: Reward (in $) = 26,631
# Day 174: Reward (in $) = 22,373
# Day 175: Reward (in $) = 24,974
# Day 176: Reward (in $) = -20,065
# Day 177: Reward (in $) = -14,344
# Day 178: Reward (in $) = -6,280
# Day 179: Reward (in $) = -20,720
# Day 180: Reward (in $) = -162
# Day 181: Reward (in $) = -4,096
# Day 182: Reward (in $) = -16,744
# Day 183: Reward (in $) = -95,004
# Day 184: Reward (in $) = -134,775
# Day 185: Reward (in $) = -63,758
# Day 186: Reward (in $) = 20,028
# Day 187: Reward (in $) = 3,014
# Day 188: Reward (in $) = 8
# Day 189: Reward (in $) = 0
# Day 190: Reward (in $) = -130,630
# Day 191: Reward (in $) = -34,089
# Day 192: Reward (in $) = -33,169
# Day 193: Reward (in $) = -14,907
# Day 194: Reward (in $) = 674
# Day 195: Reward (in $) = 7,830
# Day 196: Reward (in $) = 17,860
# Day 197: Reward (in $) = 18,207
# Day 198: Reward (in $) = 54,604
# Day 199: Reward (in $) = 885
# Day 200: Reward (in $) = -102,230
# Day 201: Reward (in $) = -8,414
# Day 202: Reward (in $) = -2,185
# Day 203: Reward (in $) = 11,525
# Day 204: Reward (in $) = 870
# Day 205: Reward (in $) = -9,016
# Day 206: Reward (in $) = -321
# Day 207: Reward (in $) = -1,674
# Day 208: Reward (in $) = -1,544
# Day 209: Reward (in $) = 16,754
# Day 210: Reward (in $) = 32,765
# Day 211: Reward (in $) = 62,805
# Day 212: Reward (in $) = 74,738
# Day 213: Reward (in $) = -5,689
# Day 214: Reward (in $) = -7,901
# Day 215: Reward (in $) = -94,369
# Day 216: Reward (in $) = 1,487
# Day 217: Reward (in $) = 4,774
# Day 218: Reward (in $) = 25,557
# Day 219: Reward (in $) = -28,396
# Day 220: Reward (in $) = -2,832
# Day 221: Reward (in $) = -37,687
# Day 222: Reward (in $) = 5,881
# Day 223: Reward (in $) = 130
# Day 224: Reward (in $) = 0
# Day 225: Reward (in $) = -299
# Day 226: Reward (in $) = -48,935
# Day 227: Reward (in $) = -324
# Day 228: Reward (in $) = 12,260
# Day 229: Reward (in $) = 9,606
# Day 230: Reward (in $) = -1,059
# Day 231: Reward (in $) = 116
# Day 232: Reward (in $) = -14,578
# Day 233: Reward (in $) = -69,164
# Day 234: Reward (in $) = -110,507
# Day 235: Reward (in $) = -50,331
# Day 236: Reward (in $) = 25,195
# Day 237: Reward (in $) = 80,164
# Day 238: Reward (in $) = -848
# Day 239: Reward (in $) = -23,000
# Day 240: Reward (in $) = -8,084
# Day 241: Reward (in $) = -497
# Day 242: Reward (in $) = 7,309
# Day 243: Reward (in $) = 1,343
# Day 244: Reward (in $) = 9,429
# Day 245: Reward (in $) = -97,586
# Day 246: Reward (in $) = -52,828
# Day 247: Reward (in $) = -8,081
# Day 248: Reward (in $) = -45,401
# Day 249: Reward (in $) = -1,105
# Day 250: Reward (in $) = 112
# Day 251: Reward (in $) = -198
# Day 252: Reward (in $) = -8,769
# Day 253: Reward (in $) = 182,209
# Day 254: Reward (in $) = -15,183
# Day 255: Reward (in $) = -1,513
# Day 256: Reward (in $) = -4,568
# Day 257: Reward (in $) = -9,447
# Day 258: Reward (in $) = -32,593
# Day 259: Reward (in $) = -55,494
# Day 260: Reward (in $) = -41,484
# Day 261: Reward (in $) = 93,871
# Day 262: Reward (in $) = 8,800
# Day 263: Reward (in $) = -39,334
# Day 264: Reward (in $) = -5,187
# Day 265: Reward (in $) = -5,132
# Day 266: Reward (in $) = -1,774
# Day 267: Reward (in $) = -11,364
# Day 268: Reward (in $) = -29,970
# Day 269: Reward (in $) = -112,699
# Day 270: Reward (in $) = -95,992
# Day 271: Reward (in $) = -12,041
# Day 272: Reward (in $) = -37,789
# Day 273: Reward (in $) = -57,931
# Day 274: Reward (in $) = 30,085
# Day 275: Reward (in $) = 32,413
# Day 276: Reward (in $) = -27,442
# Day 277: Reward (in $) = 57,883
# Day 278: Reward (in $) = 184,287
# Day 279: Reward (in $) = 31,520
# Day 280: Reward (in $) = 1,665
# Day 281: Reward (in $) = -15,012
# Day 282: Reward (in $) = 17,006
# Day 283: Reward (in $) = -3,717
# Day 284: Reward (in $) = -44,169
# Day 285: Reward (in $) = 24,899
# Day 286: Reward (in $) = -73,959
# Day 287: Reward (in $) = -86,270
# Day 288: Reward (in $) = 5,909
# Day 289: Reward (in $) = 7,516
# Day 290: Reward (in $) = 13,623
# Day 291: Reward (in $) = -8,182
# Day 292: Reward (in $) = -1,651
# Day 293: Reward (in $) = 91,744
# Day 294: Reward (in $) = -14,904
# Day 295: Reward (in $) = 8,296
# Day 296: Reward (in $) = -65,578
# Day 297: Reward (in $) = -44,317
# Day 298: Reward (in $) = 180,839
# Day 299: Reward (in $) = -81,098
# Day 300: Reward (in $) = -28,961
# Day 301: Reward (in $) = -9,247
# Day 302: Reward (in $) = -29,373
# Day 303: Reward (in $) = 20,301
# Day 304: Reward (in $) = -37,647
# Day 305: Reward (in $) = -20,231
# Day 306: Reward (in $) = -23,060
# Day 307: Reward (in $) = -10,354
# Day 308: Reward (in $) = -58,938
# Day 309: Reward (in $) = 4,620
# Day 310: Reward (in $) = -6,735
# Day 311: Reward (in $) = -43,702
# Day 312: Reward (in $) = 56,632
# Day 313: Reward (in $) = -2,250
# Day 314: Reward (in $) = -78,063
# Day 315: Reward (in $) = -65,084
# Day 316: Reward (in $) = -16,213
# Day 317: Reward (in $) = -46,299
# Day 318: Reward (in $) = -22,799
# Day 319: Reward (in $) = 3,351
# Day 320: Reward (in $) = 21,241
# Day 321: Reward (in $) = 13,600
# Day 322: Reward (in $) = -7,299
# Day 323: Reward (in $) = 10,069
# Day 324: Reward (in $) = 21,363
# Day 325: Reward (in $) = -37,529
# Day 326: Reward (in $) = -13,219
# Day 327: Reward (in $) = -19,321
# Day 328: Reward (in $) = 77,048
# Day 329: Reward (in $) = 45,560
# Day 330: Reward (in $) = 6,881
# Day 331: Reward (in $) = -18,917
# Day 332: Reward (in $) = -60,231
# Day 333: Reward (in $) = -56,060
# Day 334: Reward (in $) = -4,321
# Day 335: Reward (in $) = -27,575
# Day 336: Reward (in $) = -23,676
# Day 337: Reward (in $) = 24,068
# Day 338: Reward (in $) = -12,156
# Day 339: Reward (in $) = -20,216
# Day 340: Reward (in $) = -8,538
# Day 341: Reward (in $) = -70,439
# Day 342: Reward (in $) = -150,571
# Day 343: Reward (in $) = -165,770
# Day 344: Reward (in $) = 229,472
# Day 345: Reward (in $) = 105,895
# Day 346: Reward (in $) = -40,600
# Day 347: Reward (in $) = 9,921
# Day 348: Reward (in $) = -40,523
# Day 349: Reward (in $) = 103,355
# Day 350: Reward (in $) = -5,766
# Day 351: Reward (in $) = 83,717
# Day 352: Reward (in $) = 51,240
# Day 353: Reward (in $) = 0
# Day 354: Reward (in $) = -59,647
# Day 355: Reward (in $) = -84,167
# Day 356: Reward (in $) = -26,551
# Day 357: Reward (in $) = -39,660
# Day 358: Reward (in $) = 3,697
# Day 359: Reward (in $) = -17,399
# Day 360: Reward (in $) = -41,626
# Day 361: Reward (in $) = -99,334
# Day 362: Reward (in $) = 31,142
# Day 363: Reward (in $) = 367,746
# Day 364: Reward (in $) = 5,822
# Day 365: Reward (in $) = -20,344
# Total money earned over the year (in $) = 4,276,427

# %% [markdown]
# ### Task 6: Beat the algorithm! (15 points, bonus)
#
# Make changes to increase the profits further! The people with the top 15 total profits will get additional points. Exaplain what did for improvement and how much profits you made. Do not exceed the 250,000 budget!
#
# #### (comments here, add a new code cell below)
# I really do not think of any other modification methods except changing modification of optionToBuy. I simply remove the while loop condition to eliminate the diversity and count everyday. Because of removing while loop, I simply changed next line with if to while loop. This results me $5,030,990 profit which is much higher than previous exercises

# %%
dailyBudget = 250000
quantileOffer =0.70

# Keep track of your rewards in each day, a cumulative reward over the year, and a total reward over the
# year. Also, keep track of the total reward from each option. Store them as dictionaries that are
# indexed by day of the year.
reward = {}
cumulativeReward = {}
totalReward = 0
optionReturn = dict((option, 0) for option in optionNames)

# Implement the trading strategy on each day!

for day in rangeOfDays:

    reward[day] = 0

    # Find the options that your classifier says that should be profitable. Store the profitable option
    # names in chosenOptions.
    chosenOptionNumbers = np.ravel(list(np.nonzero(predictedY.loc[day].values)))
    if np.size(chosenOptionNumbers) == 0:
        continue
    chosenOptions = [optionNames[i] for i in chosenOptionNumbers]

    # Design the portfolio based on average price spreads. Our strategy is that as long as you have not
    # exceeded your daily budget, pick an option from the list of 'chosenOptions' probabilistically, where
    # the probability of choosing it is proportional to exponential(historical rewards of that option). That
    # is, a historically profitable option is chosen more often than one that is not. Keep sampling and
    # decreasing your budget with each bid.

    # Start with an empty portfolio.

    portfolio = dict((option, 0) for option in chosenOptions)

    # Calculate the probabilities of choosing each option among the list 'chosenOptions'. Recall that
    # 'chosenOptions' contains the options that your classifier indicates as being profitable.
    priceSpreads = [1.0 * averagePriceSpread[option] for option in chosenOptions]
    probabilityOptions = [np.exp(p) for p in priceSpreads]
    probabilityOptions /= np.sum(probabilityOptions)

    # Start with your daily budget.
    budget = dailyBudget

    # Sampling among the profitable options and bid based on them.
    optionToBuy = choice(chosenOptions, p=probabilityOptions)
    
    while budget > offerPrices[quantileOffer][optionToBuy]:
        portfolio[optionToBuy] += 1
        budget -= offerPrices[quantileOffer][optionToBuy]

    # Compute the reward from the day. Go through each of the options you have decided to buy.
    # If the DA price is lower than the bid price, then your bid is cleared. For each option you
    # have bought, you get a reward equal to the DA - RT price.

    for option in chosenOptions:
        if testPriceDA.at[day, option] < offerPrices[quantileOffer][option]:
            rewardOptionDay = testPriceDART.at[day, option] * portfolio[option]
            optionReturn[option] += rewardOptionDay
            reward[day] += rewardOptionDay

    totalReward += reward[day]

    # Calculate the cumulative reward in millions of dollars.
    cumulativeReward[day] = totalReward/1000000

    print("Day " + str(day) + ": Reward (in $) = " + "{0:,.0f}".format(reward[day]))

print("Total money earned over the year (in $) = " + "{0:,.0f}".format(totalReward))
# Out:
# Day 3: Reward (in $) = -75,859
# Day 4: Reward (in $) = 4,305,572
# Day 5: Reward (in $) = 83,923
# Day 6: Reward (in $) = 0
# Day 7: Reward (in $) = -42,307
# Day 8: Reward (in $) = 61,326
# Day 9: Reward (in $) = -42,104
# Day 10: Reward (in $) = -90,977
# Day 11: Reward (in $) = -44,066
# Day 12: Reward (in $) = 0
# Day 13: Reward (in $) = -91,688
# Day 14: Reward (in $) = -52,253
# Day 15: Reward (in $) = -5,631
# Day 16: Reward (in $) = 17,263
# Day 17: Reward (in $) = -110,847
# Day 18: Reward (in $) = 0
# Day 19: Reward (in $) = 0
# Day 20: Reward (in $) = 148,006
# Day 21: Reward (in $) = 0
# Day 22: Reward (in $) = -33,198
# Day 23: Reward (in $) = 24,809
# Day 24: Reward (in $) = -112,626
# Day 25: Reward (in $) = -106,960
# Day 26: Reward (in $) = -19,961
# Day 27: Reward (in $) = 24,434
# Day 28: Reward (in $) = -12,348
# Day 29: Reward (in $) = -14,864
# Day 30: Reward (in $) = -39,526
# Day 31: Reward (in $) = -52,601
# Day 32: Reward (in $) = -10,498
# Day 33: Reward (in $) = -29,270
# Day 34: Reward (in $) = -16,304
# Day 35: Reward (in $) = -1,356
# Day 36: Reward (in $) = 7,124
# Day 37: Reward (in $) = -46,513
# Day 38: Reward (in $) = 37,160
# Day 39: Reward (in $) = 29,251
# Day 40: Reward (in $) = -54,222
# Day 41: Reward (in $) = 0
# Day 42: Reward (in $) = -31,451
# Day 43: Reward (in $) = -79,427
# Day 44: Reward (in $) = -69,047
# Day 45: Reward (in $) = -40,685
# Day 46: Reward (in $) = 112,923
# Day 47: Reward (in $) = 5,310
# Day 48: Reward (in $) = -72,879
# Day 49: Reward (in $) = -47,655
# Day 50: Reward (in $) = -30,716
# Day 51: Reward (in $) = -26,889
# Day 52: Reward (in $) = -5,918
# Day 53: Reward (in $) = -21,412
# Day 54: Reward (in $) = -20,168
# Day 55: Reward (in $) = -9,261
# Day 56: Reward (in $) = -72,683
# Day 57: Reward (in $) = -32,323
# Day 58: Reward (in $) = -47,078
# Day 59: Reward (in $) = 6,277
# Day 60: Reward (in $) = -20,429
# Day 61: Reward (in $) = 0
# Day 62: Reward (in $) = 0
# Day 63: Reward (in $) = -32,748
# Day 64: Reward (in $) = -26,140
# Day 65: Reward (in $) = 60,106
# Day 66: Reward (in $) = 24,817
# Day 67: Reward (in $) = -104,497
# Day 68: Reward (in $) = -91,148
# Day 69: Reward (in $) = -3,431
# Day 70: Reward (in $) = 196,596
# Day 71: Reward (in $) = 62,678
# Day 72: Reward (in $) = 254,915
# Day 73: Reward (in $) = -41,403
# Day 74: Reward (in $) = -37,137
# Day 75: Reward (in $) = -3,269
# Day 76: Reward (in $) = -107,462
# Day 77: Reward (in $) = -69,514
# Day 78: Reward (in $) = -15,534
# Day 79: Reward (in $) = -27,931
# Day 80: Reward (in $) = 2,361
# Day 81: Reward (in $) = 182,975
# Day 82: Reward (in $) = 5,448
# Day 83: Reward (in $) = 29,694
# Day 84: Reward (in $) = -3,793
# Day 85: Reward (in $) = -37,526
# Day 86: Reward (in $) = -62,663
# Day 87: Reward (in $) = 418,478
# Day 88: Reward (in $) = 956,313
# Day 89: Reward (in $) = 42,681
# Day 90: Reward (in $) = -68,117
# Day 91: Reward (in $) = -165,407
# Day 92: Reward (in $) = 11,370
# Day 93: Reward (in $) = -1,513
# Day 94: Reward (in $) = 0
# Day 95: Reward (in $) = 0
# Day 96: Reward (in $) = -97,160
# Day 97: Reward (in $) = 9,147
# Day 98: Reward (in $) = 13,712
# Day 99: Reward (in $) = -40,997
# Day 100: Reward (in $) = -49,813
# Day 101: Reward (in $) = -56,123
# Day 102: Reward (in $) = -69,428
# Day 103: Reward (in $) = 190,064
# Day 104: Reward (in $) = -72,939
# Day 105: Reward (in $) = -92,369
# Day 106: Reward (in $) = -51,112
# Day 107: Reward (in $) = -46,884
# Day 108: Reward (in $) = 0
# Day 109: Reward (in $) = 0
# Day 110: Reward (in $) = -63,315
# Day 111: Reward (in $) = -52,526
# Day 112: Reward (in $) = 31,627
# Day 113: Reward (in $) = 0
# Day 114: Reward (in $) = -63,706
# Day 115: Reward (in $) = -21,484
# Day 116: Reward (in $) = -47,214
# Day 117: Reward (in $) = 15,365
# Day 118: Reward (in $) = 5,024
# Day 119: Reward (in $) = -15,242
# Day 120: Reward (in $) = 46,098
# Day 121: Reward (in $) = 82,513
# Day 122: Reward (in $) = 0
# Day 123: Reward (in $) = 0
# Day 124: Reward (in $) = -10,170
# Day 125: Reward (in $) = -25,770
# Day 126: Reward (in $) = 24,046
# Day 127: Reward (in $) = -106,819
# Day 128: Reward (in $) = 33,630
# Day 129: Reward (in $) = -38,800
# Day 130: Reward (in $) = 11,762
# Day 131: Reward (in $) = 18,859
# Day 132: Reward (in $) = 6,026
# Day 133: Reward (in $) = 250,826
# Day 134: Reward (in $) = -55,134
# Day 135: Reward (in $) = -37,258
# Day 136: Reward (in $) = -46,378
# Day 137: Reward (in $) = -60,196
# Day 138: Reward (in $) = -109,596
# Day 139: Reward (in $) = -8,172
# Day 140: Reward (in $) = -72,028
# Day 141: Reward (in $) = 38,240
# Day 142: Reward (in $) = 26,875
# Day 143: Reward (in $) = 16,187
# Day 144: Reward (in $) = -66,583
# Day 145: Reward (in $) = -26,141
# Day 146: Reward (in $) = 0
# Day 147: Reward (in $) = 0
# Day 148: Reward (in $) = -47,698
# Day 149: Reward (in $) = -1,997
# Day 150: Reward (in $) = 42,038
# Day 151: Reward (in $) = 0
# Day 152: Reward (in $) = 1,385,954
# Day 153: Reward (in $) = 85,128
# Day 154: Reward (in $) = 119,953
# Day 155: Reward (in $) = 29,280
# Day 156: Reward (in $) = -17,077
# Day 157: Reward (in $) = -144,580
# Day 158: Reward (in $) = -89,705
# Day 159: Reward (in $) = -41,052
# Day 160: Reward (in $) = -72,648
# Day 161: Reward (in $) = -1,934
# Day 162: Reward (in $) = 110,286
# Day 163: Reward (in $) = 90,521
# Day 164: Reward (in $) = -17,304
# Day 165: Reward (in $) = -84,568
# Day 166: Reward (in $) = 0
# Day 167: Reward (in $) = 196,610
# Day 168: Reward (in $) = 18,043
# Day 169: Reward (in $) = 0
# Day 170: Reward (in $) = -44,495
# Day 171: Reward (in $) = 0
# Day 172: Reward (in $) = -51,194
# Day 173: Reward (in $) = 42,256
# Day 174: Reward (in $) = 62,959
# Day 175: Reward (in $) = 0
# Day 176: Reward (in $) = 0
# Day 177: Reward (in $) = -114,758
# Day 178: Reward (in $) = 0
# Day 179: Reward (in $) = 0
# Day 180: Reward (in $) = 0
# Day 181: Reward (in $) = 0
# Day 182: Reward (in $) = 3,144
# Day 183: Reward (in $) = -16,683
# Day 184: Reward (in $) = -115,965
# Day 185: Reward (in $) = 12,241
# Day 186: Reward (in $) = 0
# Day 187: Reward (in $) = 0
# Day 188: Reward (in $) = 0
# Day 189: Reward (in $) = 0
# Day 190: Reward (in $) = -74,268
# Day 191: Reward (in $) = -17,916
# Day 192: Reward (in $) = -20,871
# Day 193: Reward (in $) = 0
# Day 194: Reward (in $) = 0
# Day 195: Reward (in $) = 8,205
# Day 196: Reward (in $) = 36,669
# Day 197: Reward (in $) = 22,656
# Day 198: Reward (in $) = 38,023
# Day 199: Reward (in $) = 0
# Day 200: Reward (in $) = -118,584
# Day 201: Reward (in $) = 22,517
# Day 202: Reward (in $) = 21,372
# Day 203: Reward (in $) = 0
# Day 204: Reward (in $) = 0
# Day 205: Reward (in $) = 0
# Day 206: Reward (in $) = 0
# Day 207: Reward (in $) = 0
# Day 208: Reward (in $) = 0
# Day 209: Reward (in $) = 0
# Day 210: Reward (in $) = 0
# Day 211: Reward (in $) = 135,954
# Day 212: Reward (in $) = 104,285
# Day 213: Reward (in $) = 0
# Day 214: Reward (in $) = 35,405
# Day 215: Reward (in $) = -95,011
# Day 216: Reward (in $) = 20,354
# Day 217: Reward (in $) = 0
# Day 218: Reward (in $) = 23,704
# Day 219: Reward (in $) = -27,764
# Day 220: Reward (in $) = -37,917
# Day 221: Reward (in $) = -42,431
# Day 222: Reward (in $) = 0
# Day 223: Reward (in $) = 0
# Day 224: Reward (in $) = 0
# Day 225: Reward (in $) = 0
# Day 226: Reward (in $) = 0
# Day 227: Reward (in $) = 0
# Day 228: Reward (in $) = 0
# Day 229: Reward (in $) = 0
# Day 230: Reward (in $) = 0
# Day 231: Reward (in $) = 0
# Day 232: Reward (in $) = -59,976
# Day 233: Reward (in $) = -72,683
# Day 234: Reward (in $) = 65,810
# Day 235: Reward (in $) = 0
# Day 236: Reward (in $) = 4,435
# Day 237: Reward (in $) = -451
# Day 238: Reward (in $) = 33,334
# Day 239: Reward (in $) = 0
# Day 240: Reward (in $) = 88,815
# Day 241: Reward (in $) = 0
# Day 242: Reward (in $) = 0
# Day 243: Reward (in $) = 0
# Day 244: Reward (in $) = 36,747
# Day 245: Reward (in $) = -99,133
# Day 246: Reward (in $) = -128,350
# Day 247: Reward (in $) = 5,763
# Day 248: Reward (in $) = -19,579
# Day 249: Reward (in $) = 0
# Day 250: Reward (in $) = 0
# Day 251: Reward (in $) = 0
# Day 252: Reward (in $) = 0
# Day 253: Reward (in $) = 234,353
# Day 254: Reward (in $) = -15,715
# Day 255: Reward (in $) = 0
# Day 256: Reward (in $) = 0
# Day 257: Reward (in $) = -15,015
# Day 258: Reward (in $) = -28,615
# Day 259: Reward (in $) = -29,423
# Day 260: Reward (in $) = -62,328
# Day 261: Reward (in $) = 51,046
# Day 262: Reward (in $) = 0
# Day 263: Reward (in $) = -71,439
# Day 264: Reward (in $) = 0
# Day 265: Reward (in $) = 0
# Day 266: Reward (in $) = 0
# Day 267: Reward (in $) = 83,156
# Day 268: Reward (in $) = -23,788
# Day 269: Reward (in $) = -80,283
# Day 270: Reward (in $) = -3,592
# Day 271: Reward (in $) = -11,738
# Day 272: Reward (in $) = -4,298
# Day 273: Reward (in $) = -40,555
# Day 274: Reward (in $) = 10,542
# Day 275: Reward (in $) = 21,153
# Day 276: Reward (in $) = -93,012
# Day 277: Reward (in $) = 782
# Day 278: Reward (in $) = -12,167
# Day 279: Reward (in $) = 0
# Day 280: Reward (in $) = 0
# Day 281: Reward (in $) = -10,739
# Day 282: Reward (in $) = 13,933
# Day 283: Reward (in $) = 0
# Day 284: Reward (in $) = 2,845
# Day 285: Reward (in $) = -50,733
# Day 286: Reward (in $) = 1,553
# Day 287: Reward (in $) = -113,411
# Day 288: Reward (in $) = -6,900
# Day 289: Reward (in $) = -196
# Day 290: Reward (in $) = 0
# Day 291: Reward (in $) = 0
# Day 292: Reward (in $) = 0
# Day 293: Reward (in $) = 401,916
# Day 294: Reward (in $) = -75,905
# Day 295: Reward (in $) = 18,858
# Day 296: Reward (in $) = -67,430
# Day 297: Reward (in $) = -36,156
# Day 298: Reward (in $) = 670,450
# Day 299: Reward (in $) = -82,926
# Day 300: Reward (in $) = 16,417
# Day 301: Reward (in $) = -28,631
# Day 302: Reward (in $) = -31,173
# Day 303: Reward (in $) = 17,631
# Day 304: Reward (in $) = 0
# Day 305: Reward (in $) = -5,867
# Day 306: Reward (in $) = -14,709
# Day 307: Reward (in $) = -10,171
# Day 308: Reward (in $) = -56,430
# Day 309: Reward (in $) = -45,276
# Day 310: Reward (in $) = -5,085
# Day 311: Reward (in $) = -35,277
# Day 312: Reward (in $) = 454,300
# Day 313: Reward (in $) = 53,105
# Day 314: Reward (in $) = -69,863
# Day 315: Reward (in $) = -93,964
# Day 316: Reward (in $) = -38,691
# Day 317: Reward (in $) = -66,495
# Day 318: Reward (in $) = -32,689
# Day 319: Reward (in $) = -16,894
# Day 320: Reward (in $) = 65,510
# Day 321: Reward (in $) = 35,449
# Day 322: Reward (in $) = -6,174
# Day 323: Reward (in $) = 42,256
# Day 324: Reward (in $) = -83,183
# Day 325: Reward (in $) = -38,541
# Day 326: Reward (in $) = -13,861
# Day 327: Reward (in $) = -20,589
# Day 328: Reward (in $) = 18,497
# Day 329: Reward (in $) = 80,472
# Day 330: Reward (in $) = 8,788
# Day 331: Reward (in $) = -31,072
# Day 332: Reward (in $) = -56,179
# Day 333: Reward (in $) = -83,484
# Day 334: Reward (in $) = -26,050
# Day 335: Reward (in $) = -20,459
# Day 336: Reward (in $) = -32,413
# Day 337: Reward (in $) = 8,250
# Day 338: Reward (in $) = -9,855
# Day 339: Reward (in $) = -30,204
# Day 340: Reward (in $) = 0
# Day 341: Reward (in $) = -54,987
# Day 342: Reward (in $) = -156,432
# Day 343: Reward (in $) = -198,864
# Day 344: Reward (in $) = 83,410
# Day 345: Reward (in $) = 93,882
# Day 346: Reward (in $) = -71,988
# Day 347: Reward (in $) = -53,735
# Day 348: Reward (in $) = 0
# Day 349: Reward (in $) = 0
# Day 350: Reward (in $) = 0
# Day 351: Reward (in $) = 0
# Day 352: Reward (in $) = 10,580
# Day 353: Reward (in $) = 0
# Day 354: Reward (in $) = -22,786
# Day 355: Reward (in $) = -106,897
# Day 356: Reward (in $) = -82,624
# Day 357: Reward (in $) = -13,292
# Day 358: Reward (in $) = 0
# Day 359: Reward (in $) = -502
# Day 360: Reward (in $) = -82,731
# Day 361: Reward (in $) = -117,380
# Day 362: Reward (in $) = 23,638
# Day 363: Reward (in $) = 383,821
# Day 364: Reward (in $) = 726
# Day 365: Reward (in $) = 4,439
# Total money earned over the year (in $) = 5,030,990

# %% [markdown]
# ### Task 7: Implement a different trading strategy (10 points, bonus)
#
# Implement a different trading strategy, explain it and report its outcomes. If the rewards are comparable to the one discussed in class, and you can clearly explain the logic behind you strategy, you get additional 25 points. If your strategy leads to having profits among the top 20, then you automatically completed Task 6 too!
#
# #### (comments here, add a new code cell below)
